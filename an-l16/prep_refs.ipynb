# %%
import json
from glob import glob
import pandas as pd

# %%
def get_acteur(fn):
    data = json.load(open(fn))
    return {
        'uid': data['acteur']['uid']['#text'],
        'nom': data['acteur']['etatCivil']['ident']['nom'],
        'prenom': data['acteur']['etatCivil']['ident']['prenom'],
        'civ': data['acteur']['etatCivil']['ident']['civ'],
    }

acteurs = pd.DataFrame.from_records([ get_acteur(fn) for fn in glob('data/json/**/PA*.json') ])

acteurs
# Out:
#           uid                nom      prenom  civ
# 0    PA719874   Jacquier-Laforge      Élodie  Mme
# 1    PA722134             Fiévet  Jean-Marie   M.
# 2    PA721482            Valence       David   M.
# 3       PA569       Bonnecarrère    Philippe   M.
# 4    PA722284              Fuchs       Bruno   M.
# ..        ...                ...         ...  ...
# 974  PA775220             Dumont   Françoise  Mme
# 975  PA722344  Julien-Laferrière      Hubert   M.
# 976  PA721024            Genetet        Anne  Mme
# 977  PA722046              Bergé      Aurore  Mme
# 978  PA793940           Cazenave      Thomas   M.
#
# [979 rows x 4 columns]

# %%
acteurs.to_csv('out/acteurs.csv', index=False)

# %%
def get_organe(fn):
    data = json.load(open(fn))['organe']
    return data

organes = pd.DataFrame.from_records([ get_organe(fn) for fn in glob('data/json/**/PO*.json') ])

organes
# Out:
#                                                 @xmlns  \
# 0    http://schemas.assemblee-nationale.fr/referentiel
# 1    http://schemas.assemblee-nationale.fr/referentiel
# 2    http://schemas.assemblee-nationale.fr/referentiel
# 3    http://schemas.assemblee-nationale.fr/referentiel
# 4    http://schemas.assemblee-nationale.fr/referentiel
# ..                                                 ...
# 638  http://schemas.assemblee-nationale.fr/referentiel
# 639  http://schemas.assemblee-nationale.fr/referentiel
# 640  http://schemas.assemblee-nationale.fr/referentiel
# 641  http://schemas.assemblee-nationale.fr/referentiel
# 642  http://schemas.assemblee-nationale.fr/referentiel
#
#                                     @xmlns:xsi  \
# 0    http://www.w3.org/2001/XMLSchema-instance
# 1    http://www.w3.org/2001/XMLSchema-instance
# 2    http://www.w3.org/2001/XMLSchema-instance
# 3    http://www.w3.org/2001/XMLSchema-instance
# 4    http://www.w3.org/2001/XMLSchema-instance
# ..                                         ...
# 638  http://www.w3.org/2001/XMLSchema-instance
# 639  http://www.w3.org/2001/XMLSchema-instance
# 640  http://www.w3.org/2001/XMLSchema-instance
# 641  http://www.w3.org/2001/XMLSchema-instance
# 642  http://www.w3.org/2001/XMLSchema-instance
#
#                             @xsi:type       uid    codeType  \
# 0       OrganeExtraParlementaire_type  PO528198  ORGEXTPARL
# 1            OrganeParlementaire_Type  PO810595          GE
# 2    OrganeParlementaireInternational  PO808026          GA
# 3       OrganeExtraParlementaire_type  PO418452  ORGEXTPARL
# 4    OrganeParlementaireInternational  PO807146          GA
# ..                                ...       ...         ...
# 638  OrganeParlementaireInternational  PO807856          GA
# 639  OrganeParlementaireInternational  PO808196          GA
# 640          OrganeParlementaire_Type  PO808282          GE
# 641          OrganeParlementaire_Type  PO819609     MISINFO
# 642     OrganeExtraParlementaire_type  PO769407  ORGEXTPARL
#
#                                                libelle  \
# 0                    Conseil supérieur des gens de mer
# 1                                             Adoption
# 2                                         France-Haïti
# 3                       Conseil supérieur des archives
# 4                                        France-Soudan
# ..                                                 ...
# 638                                     France-Andorre
# 639                                    France-Belgique
# 640                              Industries de défense
# 641  Mission d'information sur la situation démogra...
# 642  Conseil d'administration de l'Office français ...
#
#                                         libelleEdition  \
# 0                 du Conseil supérieur des gens de mer
# 1                                             ADOPTION
# 2                                      de France-Haïti
# 3                    du Conseil supérieur des archives
# 4                                     de France-Soudan
# ..                                                 ...
# 638                                  de France-Andorre
# 639                                 de France-Belgique
# 640                              INDUSTRIES DE DÉFENSE
# 641  de la mission d'information sur la situation d...
# 642                                               None
#
#                                          libelleAbrege libelleAbrev  \
# 0                                          Gens de mer          291
# 1                                             ADOPTION     ADOPTION
# 2                                                Haïti          HAI
# 3                                             Archives          246
# 4                                               Soudan         SOUD
# ..                                                 ...          ...
# 638                                            Andorre          AND
# 639                                           Belgique          BEL
# 640                              INDUSTRIES DE DÉFENSE   INDUSDEFEN
# 641  Situation démographique des outre-mer et maint...   DEMOGRAPOM
# 642                 Office français de la biodiversité          393
#
#                                                 viMoDe  ...           regime  \
# 0    {'dateDebut': '2011-12-30', 'dateAgrement': No...  ...  5ème République
# 1    {'dateDebut': None, 'dateAgrement': '2022-12-0...  ...  5ème République
# 2    {'dateDebut': None, 'dateAgrement': '2022-06-2...  ...  5ème République
# 3    {'dateDebut': '2008-07-15', 'dateAgrement': No...  ...  5ème République
# 4    {'dateDebut': None, 'dateAgrement': '2022-06-2...  ...  5ème République
# ..                                                 ...  ...              ...
# 638  {'dateDebut': None, 'dateAgrement': '2022-06-2...  ...  5ème République
# 639  {'dateDebut': None, 'dateAgrement': '2022-06-2...  ...  5ème République
# 640  {'dateDebut': None, 'dateAgrement': '2022-12-0...  ...  5ème République
# 641  {'dateDebut': '2022-10-11', 'dateAgrement': No...  ...  5ème République
# 642  {'dateDebut': '2019-07-24', 'dateAgrement': No...  ...  5ème République
#
#      legislature                               regimeJuridique  \
# 0           None      Article L. 5581-1 du code des transports
# 1             16                                           NaN
# 2             16                                           NaN
# 3           None      Article L. 211-2-1 du code du patrimoine
# 4             16                                           NaN
# ..           ...                                           ...
# 638           16                                           NaN
# 639           16                                           NaN
# 640           16                                           NaN
# 641           16                                           NaN
# 642         None  Article L. 131-10 du code de l’environnement
#
#                       siteInternet nombreReunionsAnnuelles  \
# 0                             None                       3
# 1                              NaN                     NaN
# 2                              NaN                     NaN
# 3    https://francearchives.fr/fr/                       2
# 4                              NaN                     NaN
# ..                             ...                     ...
# 638                            NaN                     NaN
# 639                            NaN                     NaN
# 640                            NaN                     NaN
# 641                            NaN                     NaN
# 642                           None                       0
#
#                                            secretariat  \
# 0                                                  NaN
# 1    {'secretaire01': 'M. Pierre-Michel Berillon', ...
# 2    {'secretaire01': 'M. Éric Fournier', 'secretai...
# 3                                                  NaN
# 4         {'secretaire01': None, 'secretaire02': None}
# ..                                                 ...
# 638  {'secretaire01': 'M. Julien Souplet', 'secreta...
# 639  {'secretaire01': 'Mme Claire Moisset', 'secret...
# 640  {'secretaire01': 'M. Bertrand Vial', 'secretai...
# 641       {'secretaire01': None, 'secretaire02': None}
# 642                                                NaN
#
#                     listePays positionPolitique preseance couleurAssociee
# 0                         NaN               NaN       NaN             NaN
# 1                         NaN               NaN       NaN             NaN
# 2    {'paysRef': 'GOP756561'}               NaN       NaN             NaN
# 3                         NaN               NaN       NaN             NaN
# 4    {'paysRef': 'GOP756532'}               NaN       NaN             NaN
# ..                        ...               ...       ...             ...
# 638  {'paysRef': 'GOP756420'}               NaN       NaN             NaN
# 639  {'paysRef': 'GOP756421'}               NaN       NaN             NaN
# 640                       NaN               NaN       NaN             NaN
# 641                       NaN               NaN       NaN             NaN
# 642                       NaN               NaN       NaN             NaN
#
# [643 rows x 22 columns]

# %%
organes.to_csv('out/organes.csv', index=False)
