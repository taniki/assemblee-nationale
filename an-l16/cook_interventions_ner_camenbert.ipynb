# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

import torch

import pandas as pd

# %%
interventions = pd.read_csv('out/interventions.csv')

# %%
device = 0 if torch.cuda.is_available() else -1

# %%
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/camembert-ner")

model = (
    AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/camembert-ner")
    .to("cuda")
)

# %%
paroles = (
    interventions
    .assign(
        texte = lambda df: df.texte.astype(str)
    )
    .query('code_grammaire.isin(["PAROLE_GENERIQUE", "INTERRUPTION_1_10"])')
    .query('~texte.str.contains("parole est")')
)

paroles
# Out:
#         id_syceron    acteur     code_grammaire code_style    stime  \
# 3          2845798  PA719472   PAROLE_GENERIQUE     NORMAL   957.22
# 4          2845799  PA642847  INTERRUPTION_1_10     NORMAL   981.52
# 5          2845800  PA719472   PAROLE_GENERIQUE     NORMAL   983.07
# 6          2845802  PA719118  INTERRUPTION_1_10     NORMAL  1012.55
# 7          2845859  PA793736  INTERRUPTION_1_10     NORMAL  1012.78
# ...            ...       ...                ...        ...      ...
# 156966     2945099  PA795778   PAROLE_GENERIQUE     NORMAL  9466.82
# 156968     2944886  PA794008   PAROLE_GENERIQUE     NORMAL  9487.18
# 156969     2944941  PA793382  INTERRUPTION_1_10     NORMAL  9500.31
# 156970     2944940  PA794008   PAROLE_GENERIQUE     NORMAL  9502.38
# 156971     2944887  PA793382  INTERRUPTION_1_10     NORMAL  9539.76
#
#                                                     texte  \
# 3       Je suis ravi de vous présenter les conclusion...
# 4                                            Un Lorrain !
# 5       Les discussions franches et efficaces que nous...
# 6                                            Très bien !
# 7                                Vous préférez l’ORTF !
# ...                                                   ...
# 156966  ...tandis qu’un mix avec moins d’énergies ren...
# 156968  Je veux dire au Rassemblement national que nou...
# 156969         Honteux ! Vous êtes malhonnête, madame !
# 156970  Nous refusons le sous-amendement que vous prop...
# 156971     Et c’est d’acheter du charbon à l’Allemagne ?
#
#                         seance  mots
# 3       RUANR5L16S2022IDS26244   101
# 4       RUANR5L16S2022IDS26244     3
# 5       RUANR5L16S2022IDS26244   110
# 6       RUANR5L16S2022IDS26244     3
# 7       RUANR5L16S2022IDS26244     4
# ...                        ...   ...
# 156966  RUANR5L16S2023IDS26598    60
# 156968  RUANR5L16S2023IDS26598    66
# 156969  RUANR5L16S2023IDS26598     7
# 156970  RUANR5L16S2023IDS26598    83
# 156971  RUANR5L16S2023IDS26598     8
#
# [123519 rows x 8 columns]

# %%
device
# Out:
# 0

# %%
#nlp = pipeline('ner', model=model, tokenizer=tokenizer, device=device, aggregation_strategy="simple")
nlp = pipeline('ner', model=model, tokenizer=tokenizer, device=device, device_map="auto",  aggregation_strategy="simple")
#nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# %%
# %%time
def get_entities(text):
    entities = nlp(text)
    return [ (e['word'], e['entity_group']) for e in entities ]
    
entities = (
    paroles
    .assign(
        entities = lambda df: nlp(list(df.texte))
    )
)

entities
# Out:
# CPU times: user 7min 41s, sys: 96 ms, total: 7min 41s
# Wall time: 7min 41s
#         id_syceron    acteur     code_grammaire code_style    stime  \
# 3          2845798  PA719472   PAROLE_GENERIQUE     NORMAL   957.22
# 4          2845799  PA642847  INTERRUPTION_1_10     NORMAL   981.52
# 5          2845800  PA719472   PAROLE_GENERIQUE     NORMAL   983.07
# 6          2845802  PA719118  INTERRUPTION_1_10     NORMAL  1012.55
# 7          2845859  PA793736  INTERRUPTION_1_10     NORMAL  1012.78
# ...            ...       ...                ...        ...      ...
# 156966     2945099  PA795778   PAROLE_GENERIQUE     NORMAL  9466.82
# 156968     2944886  PA794008   PAROLE_GENERIQUE     NORMAL  9487.18
# 156969     2944941  PA793382  INTERRUPTION_1_10     NORMAL  9500.31
# 156970     2944940  PA794008   PAROLE_GENERIQUE     NORMAL  9502.38
# 156971     2944887  PA793382  INTERRUPTION_1_10     NORMAL  9539.76
#
#                                                     texte  \
# 3       Je suis ravi de vous présenter les conclusion...
# 4                                            Un Lorrain !
# 5       Les discussions franches et efficaces que nous...
# 6                                            Très bien !
# 7                                Vous préférez l’ORTF !
# ...                                                   ...
# 156966  ...tandis qu’un mix avec moins d’énergies ren...
# 156968  Je veux dire au Rassemblement national que nou...
# 156969         Honteux ! Vous êtes malhonnête, madame !
# 156970  Nous refusons le sous-amendement que vous prop...
# 156971     Et c’est d’acheter du charbon à l’Allemagne ?
#
#                         seance  mots  \
# 3       RUANR5L16S2022IDS26244   101
# 4       RUANR5L16S2022IDS26244     3
# 5       RUANR5L16S2022IDS26244   110
# 6       RUANR5L16S2022IDS26244     3
# 7       RUANR5L16S2022IDS26244     4
# ...                        ...   ...
# 156966  RUANR5L16S2023IDS26598    60
# 156968  RUANR5L16S2023IDS26598    66
# 156969  RUANR5L16S2023IDS26598     7
# 156970  RUANR5L16S2023IDS26598    83
# 156971  RUANR5L16S2023IDS26598     8
#
#                                                  entities
# 3       [{'entity_group': 'LOC', 'score': 0.5331272, '...
# 4       [{'entity_group': 'LOC', 'score': 0.6631856, '...
# 5       [{'entity_group': 'LOC', 'score': 0.92980194, ...
# 6                                                      []
# 7       [{'entity_group': 'ORG', 'score': 0.9869406, '...
# ...                                                   ...
# 156966  [{'entity_group': 'LOC', 'score': 0.9333397, '...
# 156968  [{'entity_group': 'ORG', 'score': 0.98559886, ...
# 156969  [{'entity_group': 'PER', 'score': 0.46364522, ...
# 156970  [{'entity_group': 'LOC', 'score': 0.97599787, ...
# 156971  [{'entity_group': 'LOC', 'score': 0.9112062, '...
#
# [123519 rows x 9 columns]

# %%
# %%time
nlp(list(paroles.sample(1000).texte))
# Out:
# CPU times: user 36.6 s, sys: 8 ms, total: 36.6 s
# Wall time: 36.6 s
# [[{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [{'entity_group': 'PER',
#    'score': 0.99900293,
#    'word': 'Raphaël Schellenberger',
#    'start': 120,
#    'end': 144},
#   {'entity_group': 'LOC',
#    'score': 0.932279,
#    'word': 'la France',
#    'start': 222,
#    'end': 232},
#   {'entity_group': 'ORG',
#    'score': 0.9867693,
#    'word': 'RN',
#    'start': 456,
#    'end': 459},
#   {'entity_group': 'ORG',
#    'score': 0.98748046,
#    'word': 'LR',
#    'start': 462,
#    'end': 465},
#   {'entity_group': 'ORG',
#    'score': 0.839422,
#    'word': 'RE.',
#    'start': 515,
#    'end': 519}],
#  [],
#  [],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.6044164,
#    'word': 'Mais',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.4414477,
#    'word': 'Pour',
#    'start': 0,
#    'end': 4},
#   {'entity_group': 'ORG',
#    'score': 0.9854587,
#    'word': 'sécurité sociale',
#    'start': 17,
#    'end': 36}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'MISC',
#    'score': 0.88401884,
#    'word': 'Si vous voulez',
#    'start': 0,
#    'end': 14}],
#  [{'entity_group': 'ORG',
#    'score': 0.983839,
#    'word': 'RN.',
#    'start': 281,
#    'end': 285}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.998645,
#    'word': 'Alexandre Portier',
#    'start': 445,
#    'end': 463}],
#  [{'entity_group': 'PER',
#    'score': 0.9988056,
#    'word': 'Jaurès',
#    'start': 46,
#    'end': 54},
#   {'entity_group': 'PER',
#    'score': 0.9964729,
#    'word': 'Cormier-Bouligeon',
#    'start': 64,
#    'end': 82}],
#  [{'entity_group': 'LOC',
#    'score': 0.9986814,
#    'word': 'Alpes-Maritimes',
#    'start': 138,
#    'end': 154}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'MISC',
#    'score': 0.9599033,
#    'word': 'Défavorable',
#    'start': 0,
#    'end': 12}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.72288954,
#    'word': 'l',
#    'start': 689,
#    'end': 691},
#   {'entity_group': 'ORG',
#    'score': 0.6485136,
#    'word': 'Assemblée',
#    'start': 692,
#    'end': 702},
#   {'entity_group': 'LOC',
#    'score': 0.50978506,
#    'word': 'nationale',
#    'start': 702,
#    'end': 712},
#   {'entity_group': 'LOC',
#    'score': 0.5954361,
#    'word': 'notre',
#    'start': 994,
#    'end': 1000},
#   {'entity_group': 'ORG',
#    'score': 0.57956845,
#    'word': 'République',
#    'start': 1000,
#    'end': 1012},
#   {'entity_group': 'ORG',
#    'score': 0.9929824,
#    'word': 'RN',
#    'start': 1283,
#    'end': 1286},
#   {'entity_group': 'ORG',
#    'score': 0.99184203,
#    'word': 'RE',
#    'start': 1552,
#    'end': 1555},
#   {'entity_group': 'ORG',
#    'score': 0.99271643,
#    'word': 'LFI-NUPES',
#    'start': 1556,
#    'end': 1566},
#   {'entity_group': 'ORG',
#    'score': 0.9933949,
#    'word': 'Dem',
#    'start': 1567,
#    'end': 1571},
#   {'entity_group': 'ORG',
#    'score': 0.99283975,
#    'word': 'SOC',
#    'start': 1572,
#    'end': 1576},
#   {'entity_group': 'ORG',
#    'score': 0.9939645,
#    'word': 'Écolo-NUPES',
#    'start': 1579,
#    'end': 1592},
#   {'entity_group': 'ORG',
#    'score': 0.99215496,
#    'word': 'HOR',
#    'start': 1635,
#    'end': 1639},
#   {'entity_group': 'ORG',
#    'score': 0.99187726,
#    'word': 'GDR-NUPES',
#    'start': 1642,
#    'end': 1652},
#   {'entity_group': 'ORG',
#    'score': 0.98927945,
#    'word': 'LR',
#    'start': 1737,
#    'end': 1740},
#   {'entity_group': 'ORG',
#    'score': 0.9863052,
#    'word': 'LIOT',
#    'start': 1743,
#    'end': 1748},
#   {'entity_group': 'ORG',
#    'score': 0.99011743,
#    'word': 'HOR',
#    'start': 1790,
#    'end': 1794},
#   {'entity_group': 'ORG',
#    'score': 0.9885379,
#    'word': 'GDR-NUPES',
#    'start': 1797,
#    'end': 1807}],
#  [{'entity_group': 'LOC',
#    'score': 0.9895428,
#    'word': 'Notre-Dame de Paris',
#    'start': 58,
#    'end': 78},
#   {'entity_group': 'LOC',
#    'score': 0.9983587,
#    'word': 'Bure',
#    'start': 429,
#    'end': 434},
#   {'entity_group': 'LOC',
#    'score': 0.7006605,
#    'word': 'Cigéo',
#    'start': 657,
#    'end': 664},
#   {'entity_group': 'PER',
#    'score': 0.998956,
#    'word': 'Jean-Michel Jacques',
#    'start': 1050,
#    'end': 1070},
#   {'entity_group': 'ORG',
#    'score': 0.9932773,
#    'word': 'PPE',
#    'start': 1308,
#    'end': 1312},
#   {'entity_group': 'ORG',
#    'score': 0.9824375,
#    'word': 'LFI-NUPES',
#    'start': 1773,
#    'end': 1783}],
#  [{'entity_group': 'LOC',
#    'score': 0.87039065,
#    'word': 'bâtiments de France',
#    'start': 302,
#    'end': 323},
#   {'entity_group': 'ORG',
#    'score': 0.9801355,
#    'word': 'Cour des comptes',
#    'start': 481,
#    'end': 498},
#   {'entity_group': 'LOC',
#    'score': 0.8375173,
#    'word': 'bâtiments de France',
#    'start': 563,
#    'end': 584},
#   {'entity_group': 'LOC',
#    'score': 0.9761379,
#    'word': 'État',
#    'start': 734,
#    'end': 739}],
#  [{'entity_group': 'LOC',
#    'score': 0.6112647,
#    'word': 'Français',
#    'start': 209,
#    'end': 219},
#   {'entity_group': 'ORG',
#    'score': 0.82331353,
#    'word': 'NUPES',
#    'start': 303,
#    'end': 309},
#   {'entity_group': 'ORG',
#    'score': 0.9906799,
#    'word': 'LR',
#    'start': 371,
#    'end': 374},
#   {'entity_group': 'ORG',
#    'score': 0.92070657,
#    'word': 'Gouvernement',
#    'start': 380,
#    'end': 393},
#   {'entity_group': 'ORG',
#    'score': 0.9717614,
#    'word': 'RE',
#    'start': 436,
#    'end': 439},
#   {'entity_group': 'ORG',
#    'score': 0.98008716,
#    'word': 'LR',
#    'start': 442,
#    'end': 445},
#   {'entity_group': 'ORG',
#    'score': 0.98803896,
#    'word': 'RN',
#    'start': 494,
#    'end': 497},
#   {'entity_group': 'ORG',
#    'score': 0.9903453,
#    'word': 'LR',
#    'start': 560,
#    'end': 563},
#   {'entity_group': 'ORG',
#    'score': 0.786133,
#    'word': 'Gouvernement',
#    'start': 878,
#    'end': 891},
#   {'entity_group': 'PER',
#    'score': 0.90445185,
#    'word': '. Maillard',
#    'start': 1044,
#    'end': 1054},
#   {'entity_group': 'LOC',
#    'score': 0.58373296,
#    'word': 'l',
#    'start': 1093,
#    'end': 1095},
#   {'entity_group': 'ORG',
#    'score': 0.9265908,
#    'word': 'Assemblée',
#    'start': 1096,
#    'end': 1106},
#   {'entity_group': 'ORG',
#    'score': 0.69866884,
#    'word': 'Gouvernement',
#    'start': 1180,
#    'end': 1193},
#   {'entity_group': 'ORG',
#    'score': 0.9857962,
#    'word': 'RN',
#    'start': 1251,
#    'end': 1254}],
#  [{'entity_group': 'ORG',
#    'score': 0.7550609,
#    'word': 'assemblée',
#    'start': 24,
#    'end': 35},
#   {'entity_group': 'MISC',
#    'score': 0.3771811,
#    'word': 'loi',
#    'start': 59,
#    'end': 63}],
#  [{'entity_group': 'PER',
#    'score': 0.65723085,
#    'word': 'Mme la ministre',
#    'start': 32,
#    'end': 48},
#   {'entity_group': 'LOC',
#    'score': 0.9949616,
#    'word': 'mer Méditerranée',
#    'start': 120,
#    'end': 139},
#   {'entity_group': 'PER',
#    'score': 0.7173412,
#    'word': 'Mme la ministre',
#    'start': 370,
#    'end': 386}],
#  [{'entity_group': 'LOC',
#    'score': 0.95164394,
#    'word': 'Fournas',
#    'start': 59,
#    'end': 67},
#   {'entity_group': 'ORG',
#    'score': 0.9846468,
#    'word': 'LFI-NUPES',
#    'start': 207,
#    'end': 217},
#   {'entity_group': 'ORG',
#    'score': 0.9938391,
#    'word': 'Écolo-NUPES',
#    'start': 220,
#    'end': 233},
#   {'entity_group': 'ORG',
#    'score': 0.9804803,
#    'word': 'LFI-NUPES',
#    'start': 333,
#    'end': 343},
#   {'entity_group': 'ORG',
#    'score': 0.96735317,
#    'word': 'RE',
#    'start': 375,
#    'end': 378},
#   {'entity_group': 'ORG',
#    'score': 0.9940412,
#    'word': 'NUPES',
#    'start': 418,
#    'end': 424}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.8941448,
#    'word': 'la France',
#    'start': 93,
#    'end': 103},
#   {'entity_group': 'MISC',
#    'score': 0.9930762,
#    'word': 'Grenelle de l',
#    'start': 140,
#    'end': 154},
#   {'entity_group': 'MISC',
#    'score': 0.99244374,
#    'word': 'environnement',
#    'start': 155,
#    'end': 168},
#   {'entity_group': 'PER',
#    'score': 0.99165726,
#    'word': 'Sarkozy',
#    'start': 182,
#    'end': 190},
#   {'entity_group': 'LOC',
#    'score': 0.8101109,
#    'word': 'Europe',
#    'start': 425,
#    'end': 432},
#   {'entity_group': 'LOC',
#    'score': 0.99010956,
#    'word': 'Espagne',
#    'start': 476,
#    'end': 483},
#   {'entity_group': 'LOC',
#    'score': 0.8005741,
#    'word': 'État',
#    'start': 529,
#    'end': 534}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.46839008,
#    'word': 'Gouvernement',
#    'start': 223,
#    'end': 236},
#   {'entity_group': 'ORG',
#    'score': 0.9313069,
#    'word': 'Assemblée',
#    'start': 381,
#    'end': 391}],
#  [{'entity_group': 'PER',
#    'score': 0.54453534,
#    'word': 'Monsieur',
#    'start': 0,
#    'end': 8}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.8047084,
#    'word': 'Comcyber',
#    'start': 320,
#    'end': 329}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.58348465,
#    'word': 'Ils',
#    'start': 0,
#    'end': 3}],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9878181,
#    'word': 'LFI-NUPES',
#    'start': 144,
#    'end': 154},
#   {'entity_group': 'ORG',
#    'score': 0.8336089,
#    'word': 'RE',
#    'start': 195,
#    'end': 198},
#   {'entity_group': 'LOC',
#    'score': 0.9199928,
#    'word': 'la France',
#    'start': 273,
#    'end': 283},
#   {'entity_group': 'MISC',
#    'score': 0.9898379,
#    'word': 'Révolution française',
#    'start': 536,
#    'end': 559},
#   {'entity_group': 'MISC',
#    'score': 0.9906504,
#    'word': 'Ancien Régime',
#    'start': 568,
#    'end': 582},
#   {'entity_group': 'ORG',
#    'score': 0.979083,
#    'word': 'CAC40',
#    'start': 989,
#    'end': 995},
#   {'entity_group': 'ORG',
#    'score': 0.98781955,
#    'word': 'LFI-NUPES',
#    'start': 1088,
#    'end': 1098},
#   {'entity_group': 'ORG',
#    'score': 0.9905392,
#    'word': 'Écolo-NUPES',
#    'start': 1101,
#    'end': 1114},
#   {'entity_group': 'PER',
#    'score': 0.99357784,
#    'word': 'Macron',
#    'start': 1147,
#    'end': 1154}],
#  [{'entity_group': 'ORG',
#    'score': 0.9934395,
#    'word': 'RE',
#    'start': 98,
#    'end': 101},
#   {'entity_group': 'ORG',
#    'score': 0.9936559,
#    'word': 'Dem',
#    'start': 102,
#    'end': 106},
#   {'entity_group': 'ORG',
#    'score': 0.99156857,
#    'word': 'HOR',
#    'start': 109,
#    'end': 113},
#   {'entity_group': 'ORG',
#    'score': 0.99324495,
#    'word': 'RE',
#    'start': 358,
#    'end': 361},
#   {'entity_group': 'ORG',
#    'score': 0.99357414,
#    'word': 'Dem',
#    'start': 362,
#    'end': 366},
#   {'entity_group': 'ORG',
#    'score': 0.99233186,
#    'word': 'HOR',
#    'start': 369,
#    'end': 373},
#   {'entity_group': 'ORG',
#    'score': 0.99386775,
#    'word': 'LFI-NUPES',
#    'start': 422,
#    'end': 432},
#   {'entity_group': 'ORG',
#    'score': 0.9912454,
#    'word': 'SOC',
#    'start': 433,
#    'end': 437},
#   {'entity_group': 'ORG',
#    'score': 0.9944107,
#    'word': 'Écolo-NUPES',
#    'start': 438,
#    'end': 451},
#   {'entity_group': 'ORG',
#    'score': 0.99320096,
#    'word': 'GDR-NUPES',
#    'start': 454,
#    'end': 464},
#   {'entity_group': 'PER',
#    'score': 0.999053,
#    'word': 'Bruno Le Maire',
#    'start': 947,
#    'end': 962}],
#  [{'entity_group': 'PER',
#    'score': 0.9986558,
#    'word': 'Aurélien Saintoul',
#    'start': 226,
#    'end': 245}],
#  [{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'LOC',
#    'score': 0.9952369,
#    'word': 'océan Indien',
#    'start': 167,
#    'end': 180},
#   {'entity_group': 'MISC',
#    'score': 0.52183264,
#    'word': 'Français',
#    'start': 214,
#    'end': 224},
#   {'entity_group': 'LOC',
#    'score': 0.99864674,
#    'word': 'La Réunion',
#    'start': 261,
#    'end': 273},
#   {'entity_group': 'LOC',
#    'score': 0.998587,
#    'word': 'Mayotte',
#    'start': 279,
#    'end': 287},
#   {'entity_group': 'LOC',
#    'score': 0.986724,
#    'word': 'Terres australes et antarctiques françaises',
#    'start': 521,
#    'end': 566},
#   {'entity_group': 'LOC',
#    'score': 0.90265465,
#    'word': 'la France',
#    'start': 614,
#    'end': 624},
#   {'entity_group': 'LOC',
#    'score': 0.9954049,
#    'word': 'détroit d',
#    'start': 661,
#    'end': 672},
#   {'entity_group': 'LOC',
#    'score': 0.9987268,
#    'word': 'Ormuz',
#    'start': 673,
#    'end': 678},
#   {'entity_group': 'LOC',
#    'score': 0.99796087,
#    'word': 'cap de Bonne-Espérance',
#    'start': 681,
#    'end': 705},
#   {'entity_group': 'LOC',
#    'score': 0.9951715,
#    'word': 'Somalie',
#    'start': 765,
#    'end': 773},
#   {'entity_group': 'MISC',
#    'score': 0.5487416,
#    'word': 'Yémen',
#    'start': 799,
#    'end': 806},
#   {'entity_group': 'LOC',
#    'score': 0.99541235,
#    'word': 'Comores',
#    'start': 860,
#    'end': 868},
#   {'entity_group': 'LOC',
#    'score': 0.99834335,
#    'word': 'Mayotte',
#    'start': 890,
#    'end': 898},
#   {'entity_group': 'LOC',
#    'score': 0.9987476,
#    'word': 'La Réunion',
#    'start': 904,
#    'end': 916},
#   {'entity_group': 'LOC',
#    'score': 0.99687505,
#    'word': 'océan Indien',
#    'start': 1001,
#    'end': 1015},
#   {'entity_group': 'LOC',
#    'score': 0.92634326,
#    'word': 'La France',
#    'start': 1091,
#    'end': 1101},
#   {'entity_group': 'LOC',
#    'score': 0.91123086,
#    'word': 'la France',
#    'start': 1349,
#    'end': 1359},
#   {'entity_group': 'LOC',
#    'score': 0.9933931,
#    'word': 'États-Unis',
#    'start': 1366,
#    'end': 1378},
#   {'entity_group': 'ORG',
#    'score': 0.9809562,
#    'word': 'Union européenne',
#    'start': 1531,
#    'end': 1548},
#   {'entity_group': 'LOC',
#    'score': 0.93237257,
#    'word': 'La France',
#    'start': 1816,
#    'end': 1825},
#   {'entity_group': 'LOC',
#    'score': 0.99606264,
#    'word': 'océan Indien',
#    'start': 1846,
#    'end': 1859},
#   {'entity_group': 'MISC',
#    'score': 0.86559486,
#    'word': 'mission Atalante',
#    'start': 1921,
#    'end': 1938},
#   {'entity_group': 'ORG',
#    'score': 0.9910891,
#    'word': 'Commission de l',
#    'start': 1999,
#    'end': 2015},
#   {'entity_group': 'ORG',
#    'score': 0.99106896,
#    'word': 'océan Indien',
#    'start': 2016,
#    'end': 2029},
#   {'entity_group': 'ORG',
#    'score': 0.98858196,
#    'word': 'Association des États riverains de l’océan Indien',
#    'start': 2038,
#    'end': 2089},
#   {'entity_group': 'ORG',
#    'score': 0.9884745,
#    'word': 'Iora',
#    'start': 2091,
#    'end': 2095},
#   {'entity_group': 'ORG',
#    'score': 0.9892282,
#    'word': 'COI',
#    'start': 2222,
#    'end': 2226},
#   {'entity_group': 'ORG',
#    'score': 0.9250692,
#    'word': 'Parlement',
#    'start': 2250,
#    'end': 2260},
#   {'entity_group': 'LOC',
#    'score': 0.99290466,
#    'word': 'océan Indien',
#    'start': 2301,
#    'end': 2314}],
#  [{'entity_group': 'ORG',
#    'score': 0.9930992,
#    'word': 'RE',
#    'start': 197,
#    'end': 200},
#   {'entity_group': 'ORG',
#    'score': 0.9926301,
#    'word': 'RE',
#    'start': 347,
#    'end': 350}],
#  [{'entity_group': 'ORG',
#    'score': 0.9861903,
#    'word': 'Dem.',
#    'start': 378,
#    'end': 383},
#   {'entity_group': 'ORG',
#    'score': 0.9941389,
#    'word': 'LFI-NUPES',
#    'start': 430,
#    'end': 440},
#   {'entity_group': 'ORG',
#    'score': 0.99059284,
#    'word': 'SOC',
#    'start': 441,
#    'end': 445},
#   {'entity_group': 'ORG',
#    'score': 0.9945113,
#    'word': 'Écolo-NUPES',
#    'start': 446,
#    'end': 459},
#   {'entity_group': 'ORG',
#    'score': 0.99391603,
#    'word': 'GDR-NUPES',
#    'start': 462,
#    'end': 472}],
#  [{'entity_group': 'ORG',
#    'score': 0.99293095,
#    'word': 'Les Républicains',
#    'start': 38,
#    'end': 56},
#   {'entity_group': 'ORG',
#    'score': 0.9872087,
#    'word': 'Rassemblement national',
#    'start': 252,
#    'end': 275},
#   {'entity_group': 'LOC',
#    'score': 0.9223909,
#    'word': 'la France',
#    'start': 296,
#    'end': 306},
#   {'entity_group': 'ORG',
#    'score': 0.99415404,
#    'word': 'RN',
#    'start': 349,
#    'end': 352}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.98672265,
#    'word': 'Haut Conseil',
#    'start': 102,
#    'end': 115},
#   {'entity_group': 'ORG',
#    'score': 0.8391784,
#    'word': 'Union économique et monétaire',
#    'start': 416,
#    'end': 447},
#   {'entity_group': 'LOC',
#    'score': 0.63314205,
#    'word': 'Gouvernement',
#    'start': 570,
#    'end': 583}],
#  [{'entity_group': 'ORG',
#    'score': 0.9749973,
#    'word': 'Union européenne',
#    'start': 7,
#    'end': 24}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9938398,
#    'word': 'RN',
#    'start': 88,
#    'end': 91},
#   {'entity_group': 'ORG',
#    'score': 0.9939196,
#    'word': 'LR',
#    'start': 209,
#    'end': 212}],
#  [{'entity_group': 'ORG',
#    'score': 0.99122834,
#    'word': 'Écologiste',
#    'start': 674,
#    'end': 686}],
#  [{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.608368,
#    'word': 'État',
#    'start': 34,
#    'end': 39}],
#  [{'entity_group': 'PER',
#    'score': 0.98996645,
#    'word': 'Kamardine',
#    'start': 20,
#    'end': 30},
#   {'entity_group': 'LOC',
#    'score': 0.9962681,
#    'word': 'Mayotte',
#    'start': 59,
#    'end': 67},
#   {'entity_group': 'PER',
#    'score': 0.85320956,
#    'word': '. Ciotti',
#    'start': 198,
#    'end': 206}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.78735095,
#    'word': 'M. le',
#    'start': 312,
#    'end': 318},
#   {'entity_group': 'LOC',
#    'score': 0.9099684,
#    'word': 'la France',
#    'start': 640,
#    'end': 650},
#   {'entity_group': 'MISC',
#    'score': 0.94138914,
#    'word': 'PLF',
#    'start': 1028,
#    'end': 1031},
#   {'entity_group': 'MISC',
#    'score': 0.9829293,
#    'word': 'PLF',
#    'start': 1366,
#    'end': 1370}],
#  [{'entity_group': 'MISC',
#    'score': 0.9599033,
#    'word': 'Défavorable',
#    'start': 0,
#    'end': 12}],
#  [{'entity_group': 'PER',
#    'score': 0.7080248,
#    'word': 'M. Benoit',
#    'start': 96,
#    'end': 106}],
#  [{'entity_group': 'ORG',
#    'score': 0.993291,
#    'word': 'Ve République',
#    'start': 70,
#    'end': 85}],
#  [{'entity_group': 'ORG',
#    'score': 0.99281305,
#    'word': 'RE',
#    'start': 143,
#    'end': 146},
#   {'entity_group': 'ORG',
#    'score': 0.9881829,
#    'word': 'LFI-NUPES',
#    'start': 339,
#    'end': 349},
#   {'entity_group': 'ORG',
#    'score': 0.99321306,
#    'word': 'RE',
#    'start': 526,
#    'end': 529},
#   {'entity_group': 'ORG',
#    'score': 0.9920851,
#    'word': 'Dem',
#    'start': 530,
#    'end': 534},
#   {'entity_group': 'ORG',
#    'score': 0.86943704,
#    'word': 'HOR.',
#    'start': 537,
#    'end': 542}],
#  [{'entity_group': 'PER',
#    'score': 0.8725079,
#    'word': 'M. Braun',
#    'start': 41,
#    'end': 50}],
#  [{'entity_group': 'PER',
#    'score': 0.99184716,
#    'word': 'Martinet',
#    'start': 26,
#    'end': 35}],
#  [{'entity_group': 'PER',
#    'score': 0.9827318,
#    'word': 'Président de la République',
#    'start': 139,
#    'end': 168},
#   {'entity_group': 'PER',
#    'score': 0.9987052,
#    'word': 'Benjamin Lucas',
#    'start': 407,
#    'end': 422}],
#  [{'entity_group': 'ORG',
#    'score': 0.9938958,
#    'word': 'LR',
#    'start': 228,
#    'end': 231},
#   {'entity_group': 'ORG',
#    'score': 0.9943803,
#    'word': 'RN',
#    'start': 234,
#    'end': 237}],
#  [{'entity_group': 'PER',
#    'score': 0.94555914,
#    'word': 'M. le ministre',
#    'start': 24,
#    'end': 39}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.99185574,
#    'word': 'LFI-NUPES',
#    'start': 152,
#    'end': 162}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.9023074,
#    'word': 'M. le rapporteur général',
#    'start': 128,
#    'end': 155}],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9899478,
#    'word': 'RN',
#    'start': 350,
#    'end': 353},
#   {'entity_group': 'LOC',
#    'score': 0.76024985,
#    'word': 'Français',
#    'start': 516,
#    'end': 526},
#   {'entity_group': 'LOC',
#    'score': 0.9832613,
#    'word': 'Belgique',
#    'start': 543,
#    'end': 552},
#   {'entity_group': 'LOC',
#    'score': 0.9896938,
#    'word': 'Grèce',
#    'start': 556,
#    'end': 563}],
#  [{'entity_group': 'PER',
#    'score': 0.9953029,
#    'word': 'Mattei',
#    'start': 8,
#    'end': 15},
#   {'entity_group': 'MISC',
#    'score': 0.5072676,
#    'word': 'Constitution',
#    'start': 302,
#    'end': 315}],
#  [{'entity_group': 'MISC',
#    'score': 0.8783877,
#    'word': 'PLFSS',
#    'start': 227,
#    'end': 233}],
#  [],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.92783755,
#    'word': 'Les',
#    'start': 0,
#    'end': 3}],
#  [{'entity_group': 'ORG',
#    'score': 0.99427617,
#    'word': 'Écolo-NUPES',
#    'start': 484,
#    'end': 497},
#   {'entity_group': 'ORG',
#    'score': 0.9942589,
#    'word': 'LFI-NUPES',
#    'start': 540,
#    'end': 550},
#   {'entity_group': 'ORG',
#    'score': 0.9892369,
#    'word': 'SOC',
#    'start': 551,
#    'end': 555},
#   {'entity_group': 'ORG',
#    'score': 0.9935805,
#    'word': 'GDR-NUPES',
#    'start': 558,
#    'end': 568}],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.99089557,
#    'word': 'LFI-NUPES',
#    'start': 115,
#    'end': 125}],
#  [{'entity_group': 'PER',
#    'score': 0.992908,
#    'word': 'Ménard',
#    'start': 6,
#    'end': 14}],
#  [{'entity_group': 'PER',
#    'score': 0.77858424,
#    'word': 'M. le rapporteur',
#    'start': 677,
#    'end': 694},
#   {'entity_group': 'ORG',
#    'score': 0.9751127,
#    'word': 'LR.',
#    'start': 771,
#    'end': 775}],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'LOC',
#    'score': 0.98117954,
#    'word': 'État',
#    'start': 272,
#    'end': 277},
#   {'entity_group': 'MISC',
#    'score': 0.96218866,
#    'word': 'Fanfare',
#    'start': 300,
#    'end': 308},
#   {'entity_group': 'LOC',
#    'score': 0.98154646,
#    'word': 'État',
#    'start': 730,
#    'end': 735},
#   {'entity_group': 'MISC',
#    'score': 0.9248569,
#    'word': 'plan Fanfare',
#    'start': 766,
#    'end': 779}],
#  [{'entity_group': 'ORG',
#    'score': 0.9930769,
#    'word': 'RN',
#    'start': 141,
#    'end': 144},
#   {'entity_group': 'ORG',
#    'score': 0.9868182,
#    'word': 'LFI-NUPES',
#    'start': 185,
#    'end': 195},
#   {'entity_group': 'ORG',
#    'score': 0.9912742,
#    'word': 'Écolo-NUPES',
#    'start': 198,
#    'end': 211}],
#  [{'entity_group': 'ORG',
#    'score': 0.6178042,
#    'word': 'commission des affaires sociales',
#    'start': 110,
#    'end': 143}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [{'entity_group': 'ORG',
#    'score': 0.9947978,
#    'word': 'LFI-NUPES',
#    'start': 393,
#    'end': 403},
#   {'entity_group': 'ORG',
#    'score': 0.9950714,
#    'word': 'LFI-NUPES',
#    'start': 869,
#    'end': 879},
#   {'entity_group': 'ORG',
#    'score': 0.9872879,
#    'word': 'RE',
#    'start': 920,
#    'end': 923},
#   {'entity_group': 'ORG',
#    'score': 0.99484235,
#    'word': 'LFI-NUPES',
#    'start': 1134,
#    'end': 1144}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.45856437,
#    'word': 'l',
#    'start': 209,
#    'end': 211},
#   {'entity_group': 'ORG',
#    'score': 0.68478036,
#    'word': 'intérieur',
#    'start': 212,
#    'end': 222},
#   {'entity_group': 'ORG',
#    'score': 0.5541274,
#    'word': 'écologie',
#    'start': 245,
#    'end': 254}],
#  [],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.65300053,
#    'word': 'Il',
#    'start': 0,
#    'end': 2}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9234617,
#    'word': 'de France',
#    'start': 33,
#    'end': 43}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.99642533,
#    'word': 'Macron',
#    'start': 30,
#    'end': 37}],
#  [{'entity_group': 'PER',
#    'score': 0.99883205,
#    'word': 'Caroline Abadie',
#    'start': 105,
#    'end': 121}],
#  [{'entity_group': 'PER',
#    'score': 0.99482906,
#    'word': 'Paul Christophe',
#    'start': 268,
#    'end': 284}],
#  [{'entity_group': 'MISC',
#    'score': 0.9599033,
#    'word': 'Défavorable',
#    'start': 0,
#    'end': 12}],
#  [{'entity_group': 'MISC',
#    'score': 0.8069169,
#    'word': 'Favorable',
#    'start': 0,
#    'end': 9}],
#  [{'entity_group': 'PER',
#    'score': 0.82801795,
#    'word': 'Taverne',
#    'start': 714,
#    'end': 722}],
#  [{'entity_group': 'MISC',
#    'score': 0.9599033,
#    'word': 'Défavorable',
#    'start': 0,
#    'end': 12}],
#  [{'entity_group': 'ORG',
#    'score': 0.9932517,
#    'word': 'Les Républicains',
#    'start': 446,
#    'end': 464}],
#  [{'entity_group': 'MISC',
#    'score': 0.54005945,
#    'word': 'Si',
#    'start': 0,
#    'end': 2}],
#  [{'entity_group': 'PER',
#    'score': 0.50120234,
#    'word': 'la',
#    'start': 13,
#    'end': 16}],
#  [{'entity_group': 'PER',
#    'score': 0.9954775,
#    'word': 'Vigier',
#    'start': 46,
#    'end': 53},
#   {'entity_group': 'ORG',
#    'score': 0.9762762,
#    'word': 'Socialistes et apparentés',
#    'start': 64,
#    'end': 91},
#   {'entity_group': 'ORG',
#    'score': 0.9823087,
#    'word': 'LFI-NUPES',
#    'start': 548,
#    'end': 558},
#   {'entity_group': 'ORG',
#    'score': 0.9889344,
#    'word': 'Écolo-NUPES',
#    'start': 590,
#    'end': 603},
#   {'entity_group': 'LOC',
#    'score': 0.57726204,
#    'word': 'Conseil constitutionnel',
#    'start': 784,
#    'end': 808},
#   {'entity_group': 'ORG',
#    'score': 0.9950159,
#    'word': 'OIT',
#    'start': 946,
#    'end': 949},
#   {'entity_group': 'ORG',
#    'score': 0.99232084,
#    'word': 'Organisation internationale du travail',
#    'start': 951,
#    'end': 990},
#   {'entity_group': 'ORG',
#    'score': 0.9859232,
#    'word': 'Union européenne',
#    'start': 1015,
#    'end': 1032},
#   {'entity_group': 'LOC',
#    'score': 0.99575686,
#    'word': 'Cour de cassation',
#    'start': 1146,
#    'end': 1164}],
#  [{'entity_group': 'LOC',
#    'score': 0.4852667,
#    'word': 'Français',
#    'start': 14,
#    'end': 24}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.91710126,
#    'word': 'la France',
#    'start': 24,
#    'end': 34},
#   {'entity_group': 'MISC',
#    'score': 0.5206134,
#    'word': 'République',
#    'start': 194,
#    'end': 206}],
#  [{'entity_group': 'LOC',
#    'score': 0.5926981,
#    'word': 'code de l',
#    'start': 73,
#    'end': 83},
#   {'entity_group': 'LOC',
#    'score': 0.4018732,
#    'word': 'éducation',
#    'start': 84,
#    'end': 94}],
#  [{'entity_group': 'LOC',
#    'score': 0.50010556,
#    'word': 'Il',
#    'start': 0,
#    'end': 2}],
#  [{'entity_group': 'LOC',
#    'score': 0.7633441,
#    'word': 'Gouvernement',
#    'start': 77,
#    'end': 90}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.98597676,
#    'word': 'Conseil de Paris',
#    'start': 119,
#    'end': 136},
#   {'entity_group': 'MISC',
#    'score': 0.99529135,
#    'word': 'Jeux olympiques et paralympiques',
#    'start': 155,
#    'end': 188}],
#  [{'entity_group': 'LOC',
#    'score': 0.8253762,
#    'word': 'de la Loire',
#    'start': 66,
#    'end': 78},
#   {'entity_group': 'LOC',
#    'score': 0.95568526,
#    'word': 'centrale nucléaire de Dampierre',
#    'start': 144,
#    'end': 177},
#   {'entity_group': 'LOC',
#    'score': 0.8738003,
#    'word': 'la Loire',
#    'start': 190,
#    'end': 199}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9933078,
#    'word': 'Espagne',
#    'start': 57,
#    'end': 65},
#   {'entity_group': 'LOC',
#    'score': 0.9960431,
#    'word': 'Portugal',
#    'start': 71,
#    'end': 80}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.74171025,
#    'word': 'On',
#    'start': 0,
#    'end': 2}],
#  [{'entity_group': 'ORG',
#    'score': 0.89151645,
#    'word': 'groupe Démocrate',
#    'start': 472,
#    'end': 490},
#   {'entity_group': 'PER',
#    'score': 0.9988132,
#    'word': 'François Bayrou',
#    'start': 751,
#    'end': 768},
#   {'entity_group': 'MISC',
#    'score': 0.6651835,
#    'word': 'histoire',
#    'start': 1236,
#    'end': 1244},
#   {'entity_group': 'LOC',
#    'score': 0.7412685,
#    'word': 'de France',
#    'start': 1244,
#    'end': 1254},
#   {'entity_group': 'MISC',
#    'score': 0.98411405,
#    'word': 'Grand Siècle',
#    'start': 1300,
#    'end': 1314},
#   {'entity_group': 'PER',
#    'score': 0.9980079,
#    'word': 'Louis XIV',
#    'start': 1317,
#    'end': 1327},
#   {'entity_group': 'LOC',
#    'score': 0.83765894,
#    'word': 'Europe',
#    'start': 1390,
#    'end': 1396},
#   {'entity_group': 'LOC',
#    'score': 0.9396434,
#    'word': 'la France',
#    'start': 1688,
#    'end': 1698},
#   {'entity_group': 'LOC',
#    'score': 0.9502721,
#    'word': 'la France',
#    'start': 1838,
#    'end': 1848},
#   {'entity_group': 'ORG',
#    'score': 0.97907394,
#    'word': 'Union européenne',
#    'start': 1965,
#    'end': 1982},
#   {'entity_group': 'LOC',
#    'score': 0.95515245,
#    'word': 'Allemagne',
#    'start': 1994,
#    'end': 2003}],
#  [{'entity_group': 'MISC',
#    'score': 0.706842,
#    'word': 'internet',
#    'start': 295,
#    'end': 304},
#   {'entity_group': 'PER',
#    'score': 0.9259248,
#    'word': 'M. le rapporteur',
#    'start': 838,
#    'end': 855},
#   {'entity_group': 'ORG',
#    'score': 0.9879134,
#    'word': 'Gauche démocrate et républicaine-NUPES',
#    'start': 2160,
#    'end': 2201}],
#  [{'entity_group': 'LOC',
#    'score': 0.6323639,
#    'word': 'l',
#    'start': 60,
#    'end': 62},
#   {'entity_group': 'LOC',
#    'score': 0.6071745,
#    'word': 'Europe',
#    'start': 63,
#    'end': 69},
#   {'entity_group': 'MISC',
#    'score': 0.9461902,
#    'word': 'covid-19',
#    'start': 141,
#    'end': 150}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.57884264,
#    'word': 'la République',
#    'start': 14,
#    'end': 29},
#   {'entity_group': 'ORG',
#    'score': 0.67283857,
#    'word': 'Parlement',
#    'start': 49,
#    'end': 59}],
#  [{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9308331,
#    'word': 'de France',
#    'start': 68,
#    'end': 78}],
#  [],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.49851865,
#    'word': 'Monsieur',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'MISC',
#    'score': 0.9958022,
#    'word': 'Barkhane',
#    'start': 118,
#    'end': 127},
#   {'entity_group': 'MISC',
#    'score': 0.99303037,
#    'word': 'opération Barkhane',
#    'start': 348,
#    'end': 367}],
#  [],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9290556,
#    'word': 'assurance maladie',
#    'start': 123,
#    'end': 140}],
#  [{'entity_group': 'LOC',
#    'score': 0.8915708,
#    'word': 'la France',
#    'start': 27,
#    'end': 37},
#   {'entity_group': 'LOC',
#    'score': 0.70988595,
#    'word': 'l',
#    'start': 504,
#    'end': 506},
#   {'entity_group': 'ORG',
#    'score': 0.7415603,
#    'word': 'Assemblée',
#    'start': 507,
#    'end': 517},
#   {'entity_group': 'ORG',
#    'score': 0.81234187,
#    'word': 'LFI-NUPES',
#    'start': 1292,
#    'end': 1302},
#   {'entity_group': 'ORG',
#    'score': 0.93525815,
#    'word': 'RN.',
#    'start': 1342,
#    'end': 1346}],
#  [{'entity_group': 'LOC',
#    'score': 0.6266374,
#    'word': 'Cette',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'PER',
#    'score': 0.6471888,
#    'word': 'la présidente',
#    'start': 54,
#    'end': 69}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9875041,
#    'word': 'LFI-NUPES',
#    'start': 203,
#    'end': 213},
#   {'entity_group': 'PER',
#    'score': 0.9018326,
#    'word': '. Darmanin',
#    'start': 217,
#    'end': 227}],
#  [{'entity_group': 'LOC',
#    'score': 0.6153874,
#    'word': 'Cette',
#    'start': 0,
#    'end': 5}],
#  [{'entity_group': 'MISC',
#    'score': 0.9494142,
#    'word': 'drame de Calais',
#    'start': 326,
#    'end': 342},
#   {'entity_group': 'LOC',
#    'score': 0.99672514,
#    'word': 'Manche',
#    'start': 403,
#    'end': 410},
#   {'entity_group': 'ORG',
#    'score': 0.97028506,
#    'word': 'RE',
#    'start': 679,
#    'end': 682},
#   {'entity_group': 'ORG',
#    'score': 0.94559425,
#    'word': 'Dem.',
#    'start': 685,
#    'end': 690},
#   {'entity_group': 'PER',
#    'score': 0.9987313,
#    'word': 'Estelle Youssouffa',
#    'start': 696,
#    'end': 715}],
#  [],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.74642646,
#    'word': 'Ça',
#    'start': 0,
#    'end': 3}],
#  [{'entity_group': 'LOC',
#    'score': 0.9760523,
#    'word': 'État',
#    'start': 362,
#    'end': 367}],
#  [{'entity_group': 'LOC',
#    'score': 0.9439839,
#    'word': 'État',
#    'start': 1060,
#    'end': 1065},
#   {'entity_group': 'ORG',
#    'score': 0.9871334,
#    'word': 'LFI-NUPES',
#    'start': 1929,
#    'end': 1939}],
#  [{'entity_group': 'PER',
#    'score': 0.99868506,
#    'word': 'Soudais',
#    'start': 57,
#    'end': 65},
#   {'entity_group': 'ORG',
#    'score': 0.94826543,
#    'word': 'HOR',
#    'start': 251,
#    'end': 255},
#   {'entity_group': 'ORG',
#    'score': 0.9601944,
#    'word': 'RE',
#    'start': 256,
#    'end': 259},
#   {'entity_group': 'ORG',
#    'score': 0.9834119,
#    'word': 'LR',
#    'start': 260,
#    'end': 263},
#   {'entity_group': 'ORG',
#    'score': 0.95819086,
#    'word': 'Dem.',
#    'start': 266,
#    'end': 271}],
#  [{'entity_group': 'PER',
#    'score': 0.7765485,
#    'word': 'M. le ministre',
#    'start': 171,
#    'end': 186},
#   {'entity_group': 'LOC',
#    'score': 0.9974778,
#    'word': 'Rome',
#    'start': 261,
#    'end': 266},
#   {'entity_group': 'LOC',
#    'score': 0.9978891,
#    'word': 'Londres',
#    'start': 269,
#    'end': 277},
#   {'entity_group': 'ORG',
#    'score': 0.9905578,
#    'word': 'RN',
#    'start': 374,
#    'end': 377}],
#  [{'entity_group': 'ORG',
#    'score': 0.99234945,
#    'word': 'LFI-NUPES',
#    'start': 278,
#    'end': 288},
#   {'entity_group': 'ORG',
#    'score': 0.99085367,
#    'word': 'SOC',
#    'start': 289,
#    'end': 293},
#   {'entity_group': 'ORG',
#    'score': 0.99362147,
#    'word': 'Écolo-NUPES',
#    'start': 294,
#    'end': 307},
#   {'entity_group': 'ORG',
#    'score': 0.99308616,
#    'word': 'GDR-NUPES',
#    'start': 310,
#    'end': 320},
#   {'entity_group': 'ORG',
#    'score': 0.99283916,
#    'word': 'RN',
#    'start': 361,
#    'end': 364}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.998419,
#    'word': 'François Braun',
#    'start': 11,
#    'end': 27},
#   {'entity_group': 'LOC',
#    'score': 0.9975381,
#    'word': 'Cher',
#    'start': 285,
#    'end': 290},
#   {'entity_group': 'LOC',
#    'score': 0.93335855,
#    'word': 'la France',
#    'start': 474,
#    'end': 484},
#   {'entity_group': 'LOC',
#    'score': 0.76751053,
#    'word': 'Gouvernement',
#    'start': 504,
#    'end': 517},
#   {'entity_group': 'LOC',
#    'score': 0.99852055,
#    'word': 'Centre-Val de Loire',
#    'start': 818,
#    'end': 838},
#   {'entity_group': 'LOC',
#    'score': 0.99841523,
#    'word': 'Cher',
#    'start': 902,
#    'end': 907},
#   {'entity_group': 'LOC',
#    'score': 0.9985244,
#    'word': 'Vierzon',
#    'start': 911,
#    'end': 919},
#   {'entity_group': 'PER',
#    'score': 0.8278672,
#    'word': 'Padhue',
#    'start': 976,
#    'end': 983},
#   {'entity_group': 'LOC',
#    'score': 0.99101233,
#    'word': 'France',
#    'start': 1232,
#    'end': 1239},
#   {'entity_group': 'LOC',
#    'score': 0.74101967,
#    'word': 'Gouvernement',
#    'start': 1487,
#    'end': 1500},
#   {'entity_group': 'MISC',
#    'score': 0.5444663,
#    'word': 'loi',
#    'start': 1531,
#    'end': 1535},
#   {'entity_group': 'MISC',
#    'score': 0.6588912,
#    'word': 'financement',
#    'start': 1538,
#    'end': 1550},
#   {'entity_group': 'MISC',
#    'score': 0.57268476,
#    'word': 'sécurité',
#    'start': 1556,
#    'end': 1566},
#   {'entity_group': 'MISC',
#    'score': 0.8552702,
#    'word': 'PLFSS',
#    'start': 1577,
#    'end': 1582},
#   {'entity_group': 'MISC',
#    'score': 0.90424514,
#    'word': 'PLFSS',
#    'start': 1696,
#    'end': 1702}],
#  [{'entity_group': 'MISC',
#    'score': 0.52399844,
#    'word': 'Oh',
#    'start': 0,
#    'end': 2}],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'LOC',
#    'score': 0.44943178,
#    'word': 'S',
#    'start': 0,
#    'end': 1},
#   {'entity_group': 'PER',
#    'score': 0.96464485,
#    'word': 'Mme la rapporteure',
#    'start': 26,
#    'end': 45}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.98530143,
#    'word': 'RE',
#    'start': 335,
#    'end': 338},
#   {'entity_group': 'ORG',
#    'score': 0.98860526,
#    'word': 'SOC',
#    'start': 384,
#    'end': 388}],
#  [{'entity_group': 'MISC',
#    'score': 0.5401194,
#    'word': 'Français',
#    'start': 41,
#    'end': 51},
#   {'entity_group': 'LOC',
#    'score': 0.6030538,
#    'word': 'Gouvernement',
#    'start': 126,
#    'end': 139},
#   {'entity_group': 'ORG',
#    'score': 0.98437154,
#    'word': 'LFI-NUPES',
#    'start': 361,
#    'end': 371}],
#  [{'entity_group': 'ORG',
#    'score': 0.9921375,
#    'word': 'LR',
#    'start': 311,
#    'end': 314},
#   {'entity_group': 'ORG',
#    'score': 0.99420184,
#    'word': 'RN',
#    'start': 347,
#    'end': 350},
#   {'entity_group': 'ORG',
#    'score': 0.9920589,
#    'word': 'SOC',
#    'start': 363,
#    'end': 367}],
#  [{'entity_group': 'ORG',
#    'score': 0.5499076,
#    'word': 'défense',
#    'start': 206,
#    'end': 215}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9910431,
#    'word': 'RN',
#    'start': 147,
#    'end': 150},
#   {'entity_group': 'LOC',
#    'score': 0.9877828,
#    'word': 'Espagne',
#    'start': 288,
#    'end': 296},
#   {'entity_group': 'LOC',
#    'score': 0.9888455,
#    'word': 'Portugal',
#    'start': 302,
#    'end': 311}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'ORG',
#    'score': 0.9938272,
#    'word': 'OpinionWay',
#    'start': 78,
#    'end': 89},
#   {'entity_group': 'LOC',
#    'score': 0.8157839,
#    'word': 'Français',
#    'start': 122,
#    'end': 132}],
#  [{'entity_group': 'MISC',
#    'score': 0.97458965,
#    'word': 'Ça',
#    'start': 0,
#    'end': 3}],
#  [{'entity_group': 'ORG',
#    'score': 0.99505025,
#    'word': 'NUPES',
#    'start': 416,
#    'end': 422},
#   {'entity_group': 'ORG',
#    'score': 0.98717326,
#    'word': 'LFI-NUPES',
#    'start': 594,
#    'end': 604}],
#  [{'entity_group': 'ORG',
#    'score': 0.993292,
#    'word': 'LFI-NUPES',
#    'start': 117,
#    'end': 127},
#   {'entity_group': 'ORG',
#    'score': 0.9914106,
#    'word': 'SOC',
#    'start': 128,
#    'end': 132},
#   {'entity_group': 'ORG',
#    'score': 0.99427354,
#    'word': 'Écolo-NUPES',
#    'start': 133,
#    'end': 146},
#   {'entity_group': 'ORG',
#    'score': 0.99362934,
#    'word': 'GDR-NUPES',
#    'start': 149,
#    'end': 159}],
#  [],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9793636,
#    'word': 'France',
#    'start': 2,
#    'end': 9}],
#  [{'entity_group': 'ORG',
#    'score': 0.9052637,
#    'word': 'Assemblée',
#    'start': 176,
#    'end': 186},
#   {'entity_group': 'LOC',
#    'score': 0.44371998,
#    'word': 'Gouvernement',
#    'start': 271,
#    'end': 284},
#   {'entity_group': 'PER',
#    'score': 0.9986558,
#    'word': 'Chikirou',
#    'start': 429,
#    'end': 438},
#   {'entity_group': 'PER',
#    'score': 0.99864835,
#    'word': 'Chikirou',
#    'start': 496,
#    'end': 505},
#   {'entity_group': 'ORG',
#    'score': 0.9448738,
#    'word': 'LFI-NUPES',
#    'start': 634,
#    'end': 644}],
#  [],
#  [],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.45704967,
#    'word': 'On',
#    'start': 0,
#    'end': 2}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.8124558,
#    'word': 'loi pour la liberté de choisir son avenir professionnel',
#    'start': 10,
#    'end': 67},
#   {'entity_group': 'ORG',
#    'score': 0.59916687,
#    'word': 'ministre de l',
#    'start': 576,
#    'end': 590},
#   {'entity_group': 'ORG',
#    'score': 0.5186433,
#    'word': 'enseignement supérieur et',
#    'start': 591,
#    'end': 617},
#   {'entity_group': 'PER',
#    'score': 0.99902785,
#    'word': 'Sylvie Retailleau',
#    'start': 633,
#    'end': 651},
#   {'entity_group': 'PER',
#    'score': 0.89171046,
#    'word': 'Première ministre Élisabeth Borne',
#    'start': 1444,
#    'end': 1480},
#   {'entity_group': 'LOC',
#    'score': 0.97600615,
#    'word': 'France',
#    'start': 1787,
#    'end': 1794},
#   {'entity_group': 'PER',
#    'score': 0.99885035,
#    'word': 'Sylvain Maillard',
#    'start': 2121,
#    'end': 2138},
#   {'entity_group': 'ORG',
#    'score': 0.5126766,
#    'word': 'Opco',
#    'start': 2611,
#    'end': 2616}],
#  [{'entity_group': 'MISC',
#    'score': 0.9599033,
#    'word': 'Défavorable',
#    'start': 0,
#    'end': 12}],
#  [{'entity_group': 'ORG',
#    'score': 0.96459097,
#    'word': 'Conseil d’État',
#    'start': 63,
#    'end': 79},
#   {'entity_group': 'MISC',
#    'score': 0.8205708,
#    'word': 'LPM',
#    'start': 149,
#    'end': 153}],
#  [{'entity_group': 'PER',
#    'score': 0.99317616,
#    'word': 'Zulesi',
#    'start': 92,
#    'end': 99},
#   {'entity_group': 'LOC',
#    'score': 0.99600315,
#    'word': 'Fécamp',
#    'start': 127,
#    'end': 135},
#   {'entity_group': 'LOC',
#    'score': 0.9682741,
#    'word': 'France',
#    'start': 562,
#    'end': 569},
#   {'entity_group': 'LOC',
#    'score': 0.70497704,
#    'word': 'Europe',
#    'start': 691,
#    'end': 698},
#   {'entity_group': 'PER',
#    'score': 0.98782694,
#    'word': 'Nury',
#    'start': 741,
#    'end': 746},
#   {'entity_group': 'ORG',
#    'score': 0.5783807,
#    'word': 'Conseil d',
#    'start': 947,
#    'end': 957},
#   {'entity_group': 'ORG',
#    'score': 0.5205107,
#    'word': 'État',
#    'start': 958,
#    'end': 963}],
#  [{'entity_group': 'ORG',
#    'score': 0.9941432,
#    'word': 'LFI-NUPES',
#    'start': 149,
#    'end': 159}],
#  [{'entity_group': 'MISC',
#    'score': 0.6514741,
#    'word': 'Scan',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9936584,
#    'word': 'CAC40',
#    'start': 107,
#    'end': 113},
#   {'entity_group': 'LOC',
#    'score': 0.9979977,
#    'word': 'Martigues',
#    'start': 386,
#    'end': 396},
#   {'entity_group': 'PER',
#    'score': 0.91925836,
#    'word': 'Eulalie',
#    'start': 434,
#    'end': 442}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9946892,
#    'word': 'LFI',
#    'start': 32,
#    'end': 36}],
#  [],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.40036216,
#    'word': 'Ugo',
#    'start': 0,
#    'end': 3},
#   {'entity_group': 'LOC',
#    'score': 0.9833661,
#    'word': 'Beauvau',
#    'start': 23,
#    'end': 31}],
#  [],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9933013,
#    'word': 'Arcep',
#    'start': 148,
#    'end': 153},
#   {'entity_group': 'ORG',
#    'score': 0.98093385,
#    'word': 'Défenseure des droits',
#    'start': 230,
#    'end': 253},
#   {'entity_group': 'ORG',
#    'score': 0.9922974,
#    'word': 'Mediapart',
#    'start': 837,
#    'end': 847},
#   {'entity_group': 'LOC',
#    'score': 0.9586625,
#    'word': 'Matignon',
#    'start': 909,
#    'end': 918},
#   {'entity_group': 'LOC',
#    'score': 0.653962,
#    'word': 'CNCTR',
#    'start': 1043,
#    'end': 1049}],
#  [{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [{'entity_group': 'ORG',
#    'score': 0.50980985,
#    'word': 'assemblée',
#    'start': 467,
#    'end': 478}],
#  [{'entity_group': 'LOC',
#    'score': 0.99856263,
#    'word': 'Carnoules',
#    'start': 87,
#    'end': 97},
#   {'entity_group': 'LOC',
#    'score': 0.99840117,
#    'word': 'Gardanne',
#    'start': 100,
#    'end': 109},
#   {'entity_group': 'LOC',
#    'score': 0.8018936,
#    'word': 'Gouvernement',
#    'start': 146,
#    'end': 159},
#   {'entity_group': 'ORG',
#    'score': 0.8899838,
#    'word': 'Assemblée nationale',
#    'start': 172,
#    'end': 192},
#   {'entity_group': 'LOC',
#    'score': 0.99810576,
#    'word': 'Centre Var',
#    'start': 644,
#    'end': 655},
#   {'entity_group': 'LOC',
#    'score': 0.98545516,
#    'word': 'Provence verte',
#    'start': 686,
#    'end': 701},
#   {'entity_group': 'LOC',
#    'score': 0.99795324,
#    'word': 'Toulon Provence Méditerranée',
#    'start': 984,
#    'end': 1015},
#   {'entity_group': 'LOC',
#    'score': 0.9987297,
#    'word': 'Aix-Marseille-Provence',
#    'start': 1021,
#    'end': 1043},
#   {'entity_group': 'LOC',
#    'score': 0.9988373,
#    'word': 'Carnoules',
#    'start': 1096,
#    'end': 1106},
#   {'entity_group': 'LOC',
#    'score': 0.9988499,
#    'word': 'Brignoles',
#    'start': 1107,
#    'end': 1117},
#   {'entity_group': 'LOC',
#    'score': 0.9988727,
#    'word': 'Saint-Maximin-la-Sainte-Baume',
#    'start': 1118,
#    'end': 1148},
#   {'entity_group': 'LOC',
#    'score': 0.9988309,
#    'word': 'Gardanne',
#    'start': 1151,
#    'end': 1160},
#   {'entity_group': 'LOC',
#    'score': 0.99883217,
#    'word': 'Marseille',
#    'start': 1205,
#    'end': 1215},
#   {'entity_group': 'LOC',
#    'score': 0.9988554,
#    'word': 'Aix-en-Provence',
#    'start': 1218,
#    'end': 1234},
#   {'entity_group': 'LOC',
#    'score': 0.99880385,
#    'word': 'Toulon',
#    'start': 1249,
#    'end': 1256},
#   {'entity_group': 'LOC',
#    'score': 0.9988117,
#    'word': 'Nice',
#    'start': 1259,
#    'end': 1264},
#   {'entity_group': 'LOC',
#    'score': 0.9988657,
#    'word': 'Aix-en-Provence',
#    'start': 1416,
#    'end': 1432},
#   {'entity_group': 'LOC',
#    'score': 0.9988117,
#    'word': 'Marseille',
#    'start': 1433,
#    'end': 1443},
#   {'entity_group': 'LOC',
#    'score': 0.9987446,
#    'word': 'Toulon',
#    'start': 1446,
#    'end': 1453},
#   {'entity_group': 'LOC',
#    'score': 0.9947921,
#    'word': 'ligne Carnoules-Gardanne',
#    'start': 1508,
#    'end': 1533},
#   {'entity_group': 'LOC',
#    'score': 0.97504914,
#    'word': 'région Provence-Alpes-Côte d',
#    'start': 1723,
#    'end': 1754},
#   {'entity_group': 'LOC',
#    'score': 0.9986965,
#    'word': 'Azur',
#    'start': 1755,
#    'end': 1759},
#   {'entity_group': 'LOC',
#    'score': 0.9944055,
#    'word': 'Varois',
#    'start': 1887,
#    'end': 1894},
#   {'entity_group': 'LOC',
#    'score': 0.99879074,
#    'word': 'Carnoules',
#    'start': 2169,
#    'end': 2179},
#   {'entity_group': 'LOC',
#    'score': 0.9987587,
#    'word': 'Gardanne',
#    'start': 2182,
#    'end': 2191},
#   {'entity_group': 'LOC',
#    'score': 0.9985596,
#    'word': 'Centre Var',
#    'start': 2235,
#    'end': 2246}],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.99401206,
#    'word': 'Les Républicains',
#    'start': 176,
#    'end': 194}],
#  [{'entity_group': 'MISC',
#    'score': 0.6881662,
#    'word': 'Français',
#    'start': 79,
#    'end': 89},
#   {'entity_group': 'PER',
#    'score': 0.9984928,
#    'word': 'Raquel Garrido',
#    'start': 220,
#    'end': 235}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.99885124,
#    'word': 'Arthur Delaporte',
#    'start': 67,
#    'end': 84},
#   {'entity_group': 'ORG',
#    'score': 0.81714433,
#    'word': 'ministre des solidarités, de l',
#    'start': 184,
#    'end': 216},
#   {'entity_group': 'ORG',
#    'score': 0.7866737,
#    'word': 'autonomie',
#    'start': 217,
#    'end': 226},
#   {'entity_group': 'PER',
#    'score': 0.9990612,
#    'word': 'Jean-Christophe Combe',
#    'start': 260,
#    'end': 282}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.99896747,
#    'word': 'Laurence Vichnievsky',
#    'start': 198,
#    'end': 219},
#   {'entity_group': 'ORG',
#    'score': 0.98964,
#    'word': 'Conseil d',
#    'start': 463,
#    'end': 473},
#   {'entity_group': 'ORG',
#    'score': 0.98898673,
#    'word': 'État',
#    'start': 474,
#    'end': 479}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9919435,
#    'word': 'Rassemblement national',
#    'start': 2,
#    'end': 25}],
#  [{'entity_group': 'PER',
#    'score': 0.84090006,
#    'word': 'M. le ministre',
#    'start': 45,
#    'end': 60}],
#  [{'entity_group': 'ORG',
#    'score': 0.9911669,
#    'word': 'LFI-NUPES',
#    'start': 9,
#    'end': 19},
#   {'entity_group': 'MISC',
#    'score': 0.9887042,
#    'word': 'MaPrimeRénov’',
#    'start': 101,
#    'end': 116},
#   {'entity_group': 'PER',
#    'score': 0.99236304,
#    'word': 'Amiel',
#    'start': 911,
#    'end': 917},
#   {'entity_group': 'MISC',
#    'score': 0.9917523,
#    'word': 'MaPrimeRénov’',
#    'start': 958,
#    'end': 973},
#   {'entity_group': 'MISC',
#    'score': 0.9874351,
#    'word': 'MaPrimeRénov’ Sérénité',
#    'start': 1000,
#    'end': 1026},
#   {'entity_group': 'ORG',
#    'score': 0.9884862,
#    'word': 'LFI-NUPES',
#    'start': 1979,
#    'end': 1989},
#   {'entity_group': 'ORG',
#    'score': 0.9577874,
#    'word': 'SOC',
#    'start': 1992,
#    'end': 1996}],
#  [{'entity_group': 'ORG',
#    'score': 0.99170595,
#    'word': 'SOC',
#    'start': 342,
#    'end': 346}],
#  [{'entity_group': 'LOC',
#    'score': 0.68613297,
#    'word': 'l',
#    'start': 416,
#    'end': 418},
#   {'entity_group': 'LOC',
#    'score': 0.68366265,
#    'word': 'Assemblée nationale',
#    'start': 419,
#    'end': 439},
#   {'entity_group': 'LOC',
#    'score': 0.96642905,
#    'word': 'Sénat',
#    'start': 445,
#    'end': 452},
#   {'entity_group': 'PER',
#    'score': 0.9989419,
#    'word': 'Gabriel Attal',
#    'start': 604,
#    'end': 618},
#   {'entity_group': 'PER',
#    'score': 0.9988554,
#    'word': 'Christophe Béchu',
#    'start': 621,
#    'end': 639},
#   {'entity_group': 'PER',
# ...
#    'start': 236,
#    'end': 253},
#   {'entity_group': 'LOC',
#    'score': 0.92779905,
#    'word': 'La France',
#    'start': 685,
#    'end': 694},
#   {'entity_group': 'MISC',
#    'score': 0.9866972,
#    'word': 'Health Data Hub',
#    'start': 1709,
#    'end': 1725},
#   {'entity_group': 'MISC',
#    'score': 0.98449254,
#    'word': 'HDH',
#    'start': 1727,
#    'end': 1730}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.9989238,
#    'word': 'Heinrich Bruning',
#    'start': 141,
#    'end': 159},
#   {'entity_group': 'PER',
#    'score': 0.998218,
#    'word': 'Camille Chautemps',
#    'start': 165,
#    'end': 183},
#   {'entity_group': 'MISC',
#    'score': 0.9962603,
#    'word': 'Wikipédia',
#    'start': 277,
#    'end': 288},
#   {'entity_group': 'ORG',
#    'score': 0.99424857,
#    'word': 'LFI-NUPES',
#    'start': 559,
#    'end': 569},
#   {'entity_group': 'ORG',
#    'score': 0.9947421,
#    'word': 'Écolo-NUPES',
#    'start': 570,
#    'end': 583},
#   {'entity_group': 'ORG',
#    'score': 0.99404085,
#    'word': 'GDR-NUPES',
#    'start': 586,
#    'end': 596}],
#  [{'entity_group': 'MISC',
#    'score': 0.7165126,
#    'word': 'Tant',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9795553,
#    'word': 'RE',
#    'start': 499,
#    'end': 502},
#   {'entity_group': 'ORG',
#    'score': 0.9502973,
#    'word': 'Dem.',
#    'start': 505,
#    'end': 510}],
#  [{'entity_group': 'ORG',
#    'score': 0.8692956,
#    'word': 'Renaissance',
#    'start': 408,
#    'end': 420},
#   {'entity_group': 'ORG',
#    'score': 0.9350934,
#    'word': 'Assemblée nationale',
#    'start': 426,
#    'end': 446},
#   {'entity_group': 'LOC',
#    'score': 0.89428127,
#    'word': 'Centre d',
#    'start': 1096,
#    'end': 1105},
#   {'entity_group': 'LOC',
#    'score': 0.68643165,
#    'word': 'information sur les droits des femmes et des familles',
#    'start': 1106,
#    'end': 1159},
#   {'entity_group': 'LOC',
#    'score': 0.80400467,
#    'word': 'CIDFF',
#    'start': 1161,
#    'end': 1166},
#   {'entity_group': 'LOC',
#    'score': 0.9900477,
#    'word': 'Nîmes',
#    'start': 1170,
#    'end': 1177}],
#  [],
#  [],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9986451,
#    'word': 'Seine-Saint-Denis',
#    'start': 180,
#    'end': 198},
#   {'entity_group': 'PER',
#    'score': 0.999069,
#    'word': 'Ugo Bernalicis',
#    'start': 273,
#    'end': 288},
#   {'entity_group': 'MISC',
#    'score': 0.9930393,
#    'word': 'JO',
#    'start': 415,
#    'end': 418},
#   {'entity_group': 'MISC',
#    'score': 0.99394363,
#    'word': 'Jeux',
#    'start': 517,
#    'end': 522},
#   {'entity_group': 'MISC',
#    'score': 0.7775822,
#    'word': 'Big Brother',
#    'start': 571,
#    'end': 583},
#   {'entity_group': 'ORG',
#    'score': 0.9679788,
#    'word': 'LFI-NUPES',
#    'start': 632,
#    'end': 642}],
#  [{'entity_group': 'ORG',
#    'score': 0.99254286,
#    'word': 'LFI-NUPES',
#    'start': 127,
#    'end': 137}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.9599033,
#    'word': 'Défavorable',
#    'start': 0,
#    'end': 12}],
#  [{'entity_group': 'PER',
#    'score': 0.9989152,
#    'word': 'Éric Ciotti',
#    'start': 40,
#    'end': 53},
#   {'entity_group': 'ORG',
#    'score': 0.9823353,
#    'word': 'les Républicains',
#    'start': 121,
#    'end': 139}],
#  [{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [{'entity_group': 'ORG',
#    'score': 0.99369687,
#    'word': 'Écologiste-NUPES',
#    'start': 9,
#    'end': 27},
#   {'entity_group': 'PER',
#    'score': 0.99784505,
#    'word': 'Dharréville',
#    'start': 53,
#    'end': 66},
#   {'entity_group': 'PER',
#    'score': 0.998627,
#    'word': 'Ségolène Amiot',
#    'start': 457,
#    'end': 474},
#   {'entity_group': 'PER',
#    'score': 0.99825144,
#    'word': 'Bergé',
#    'start': 551,
#    'end': 557},
#   {'entity_group': 'ORG',
#    'score': 0.99246424,
#    'word': 'Écolo-NUPES',
#    'start': 750,
#    'end': 763},
#   {'entity_group': 'ORG',
#    'score': 0.9824645,
#    'word': 'LFI-NUPES',
#    'start': 805,
#    'end': 815},
#   {'entity_group': 'ORG',
#    'score': 0.9785496,
#    'word': 'GDR-NUPES',
#    'start': 818,
#    'end': 828}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.59871626,
#    'word': 'Gouvernement',
#    'start': 18,
#    'end': 31}],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.99291253,
#    'word': 'LIOT',
#    'start': 183,
#    'end': 188},
#   {'entity_group': 'ORG',
#    'score': 0.9936697,
#    'word': 'RN',
#    'start': 189,
#    'end': 192},
#   {'entity_group': 'ORG',
#    'score': 0.99344665,
#    'word': 'LFI-NUPES',
#    'start': 193,
#    'end': 203},
#   {'entity_group': 'ORG',
#    'score': 0.99359244,
#    'word': 'SOC',
#    'start': 204,
#    'end': 208},
#   {'entity_group': 'ORG',
#    'score': 0.99400437,
#    'word': 'Écolo-NUPES',
#    'start': 209,
#    'end': 222},
#   {'entity_group': 'ORG',
#    'score': 0.9934929,
#    'word': 'GDR-NUPES',
#    'start': 225,
#    'end': 235},
#   {'entity_group': 'ORG',
#    'score': 0.9886536,
#    'word': 'LR',
#    'start': 267,
#    'end': 270},
#   {'entity_group': 'MISC',
#    'score': 0.5252624,
#    'word': 'Constitution',
#    'start': 354,
#    'end': 367},
#   {'entity_group': 'ORG',
#    'score': 0.9922546,
#    'word': 'LIOT',
#    'start': 669,
#    'end': 674},
#   {'entity_group': 'ORG',
#    'score': 0.9936179,
#    'word': 'RN',
#    'start': 675,
#    'end': 678},
#   {'entity_group': 'ORG',
#    'score': 0.99323285,
#    'word': 'LFI-NUPES',
#    'start': 679,
#    'end': 689},
#   {'entity_group': 'ORG',
#    'score': 0.9931829,
#    'word': 'SOC',
#    'start': 690,
#    'end': 694},
#   {'entity_group': 'ORG',
#    'score': 0.9936989,
#    'word': 'Écolo-NUPES',
#    'start': 695,
#    'end': 708},
#   {'entity_group': 'ORG',
#    'score': 0.9931389,
#    'word': 'GDR-NUPES',
#    'start': 711,
#    'end': 721},
#   {'entity_group': 'PER',
#    'score': 0.8659842,
#    'word': 'Madame la Première ministre',
#    'start': 723,
#    'end': 751},
#   {'entity_group': 'ORG',
#    'score': 0.9928365,
#    'word': 'LIOT',
#    'start': 1050,
#    'end': 1055},
#   {'entity_group': 'ORG',
#    'score': 0.99314785,
#    'word': 'LFI-NUPES',
#    'start': 1056,
#    'end': 1066},
#   {'entity_group': 'ORG',
#    'score': 0.99346167,
#    'word': 'SOC',
#    'start': 1067,
#    'end': 1071},
#   {'entity_group': 'ORG',
#    'score': 0.9937576,
#    'word': 'Écolo-NUPES',
#    'start': 1072,
#    'end': 1085},
#   {'entity_group': 'ORG',
#    'score': 0.9933241,
#    'word': 'GDR-NUPES',
#    'start': 1088,
#    'end': 1098},
#   {'entity_group': 'ORG',
#    'score': 0.64143926,
#    'word': 'Constitution',
#    'start': 1194,
#    'end': 1207}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.99869174,
#    'word': 'Descrozaille',
#    'start': 275,
#    'end': 288}],
#  [{'entity_group': 'LOC',
#    'score': 0.992172,
#    'word': 'Lyon',
#    'start': 90,
#    'end': 95},
#   {'entity_group': 'PER',
#    'score': 0.9987021,
#    'word': 'Danièle Obono',
#    'start': 175,
#    'end': 190}],
#  [{'entity_group': 'ORG',
#    'score': 0.993016,
#    'word': 'Écologiste',
#    'start': 173,
#    'end': 185},
#   {'entity_group': 'ORG',
#    'score': 0.9919842,
#    'word': 'La France insoumise',
#    'start': 200,
#    'end': 220},
#   {'entity_group': 'ORG',
#    'score': 0.9953277,
#    'word': 'Otan',
#    'start': 227,
#    'end': 231}],
#  [{'entity_group': 'PER',
#    'score': 0.99531174,
#    'word': 'Mitigé',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'MISC',
#    'score': 0.45793658,
#    'word': 'C',
#    'start': 0,
#    'end': 1}],
#  [{'entity_group': 'LOC',
#    'score': 0.75175667,
#    'word': 'Géorgiens',
#    'start': 81,
#    'end': 92},
#   {'entity_group': 'LOC',
#    'score': 0.91926575,
#    'word': 'Tbilissi',
#    'start': 100,
#    'end': 109},
#   {'entity_group': 'ORG',
#    'score': 0.9931473,
#    'word': 'RE',
#    'start': 229,
#    'end': 232},
#   {'entity_group': 'PER',
#    'score': 0.99868375,
#    'word': 'Zelensky',
#    'start': 291,
#    'end': 300},
#   {'entity_group': 'ORG',
#    'score': 0.9876865,
#    'word': 'Union européenne',
#    'start': 341,
#    'end': 358},
#   {'entity_group': 'LOC',
#    'score': 0.94557655,
#    'word': 'Maïdan',
#    'start': 482,
#    'end': 490},
#   {'entity_group': 'ORG',
#    'score': 0.9927366,
#    'word': 'RE',
#    'start': 561,
#    'end': 564},
#   {'entity_group': 'ORG',
#    'score': 0.98462766,
#    'word': 'Dem.',
#    'start': 567,
#    'end': 572},
#   {'entity_group': 'ORG',
#    'score': 0.77333796,
#    'word': 'RN.',
#    'start': 612,
#    'end': 616}],
#  [],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.9849572,
#    'word': 'Lachaud',
#    'start': 8,
#    'end': 16}],
#  [],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.95515513,
#    'word': 'État',
#    'start': 284,
#    'end': 289},
#   {'entity_group': 'LOC',
#    'score': 0.96881706,
#    'word': 'État',
#    'start': 459,
#    'end': 464},
#   {'entity_group': 'LOC',
#    'score': 0.9759862,
#    'word': 'État',
#    'start': 483,
#    'end': 488}],
#  [],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.3831706,
#    'word': 'Ça',
#    'start': 0,
#    'end': 3}],
#  [{'entity_group': 'ORG',
#    'score': 0.9758632,
#    'word': 'RE',
#    'start': 343,
#    'end': 346},
#   {'entity_group': 'PER',
#    'score': 0.9989245,
#    'word': 'François Ruffin',
#    'start': 619,
#    'end': 636}],
#  [{'entity_group': 'PER',
#    'score': 0.9988548,
#    'word': 'Karine Lebon',
#    'start': 450,
#    'end': 463},
#   {'entity_group': 'MISC',
#    'score': 0.77036446,
#    'word': 'Airbnb',
#    'start': 820,
#    'end': 827},
#   {'entity_group': 'MISC',
#    'score': 0.5014354,
#    'word': 'De',
#    'start': 1115,
#    'end': 1117}],
#  [{'entity_group': 'MISC',
#    'score': 0.44191757,
#    'word': 'Honteux',
#    'start': 0,
#    'end': 7}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9194863,
#    'word': 'HOR',
#    'start': 120,
#    'end': 124},
#   {'entity_group': 'ORG',
#    'score': 0.9307225,
#    'word': 'RE',
#    'start': 125,
#    'end': 128},
#   {'entity_group': 'ORG',
#    'score': 0.89715105,
#    'word': 'Dem.',
#    'start': 131,
#    'end': 136},
#   {'entity_group': 'ORG',
#    'score': 0.53005475,
#    'word': 'Europe',
#    'start': 252,
#    'end': 258}],
#  [{'entity_group': 'ORG',
#    'score': 0.99330425,
#    'word': 'Académie française',
#    'start': 32,
#    'end': 52}],
#  [],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'LOC',
#    'score': 0.6601471,
#    'word': 'Gouvernement',
#    'start': 34,
#    'end': 47},
#   {'entity_group': 'MISC',
#    'score': 0.38946027,
#    'word': 'REP',
#    'start': 822,
#    'end': 826}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9909842,
#    'word': 'Dem',
#    'start': 444,
#    'end': 448},
#   {'entity_group': 'ORG',
#    'score': 0.7512084,
#    'word': 'RE.',
#    'start': 451,
#    'end': 455}],
#  [],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9847109,
#    'word': 'bande de Gaza',
#    'start': 133,
#    'end': 147},
#   {'entity_group': 'MISC',
#    'score': 0.9710015,
#    'word': 'Palestiniens',
#    'start': 185,
#    'end': 198}],
#  [{'entity_group': 'LOC',
#    'score': 0.8908537,
#    'word': 'La senne',
#    'start': 0,
#    'end': 8}],
#  [{'entity_group': 'ORG',
#    'score': 0.9809317,
#    'word': 'LR',
#    'start': 296,
#    'end': 299},
#   {'entity_group': 'LOC',
#    'score': 0.95454997,
#    'word': 'La France',
#    'start': 301,
#    'end': 311}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.98890096,
#    'word': 'LFI-NUPES',
#    'start': 116,
#    'end': 126},
#   {'entity_group': 'ORG',
#    'score': 0.9928288,
#    'word': 'RN',
#    'start': 166,
#    'end': 169}],
#  [{'entity_group': 'ORG',
#    'score': 0.6239464,
#    'word': 'commission',
#    'start': 21,
#    'end': 32}],
#  [{'entity_group': 'ORG',
#    'score': 0.99016047,
#    'word': 'LR',
#    'start': 332,
#    'end': 335}],
#  [{'entity_group': 'PER',
#    'score': 0.9987825,
#    'word': 'Luc Lamirault',
#    'start': 186,
#    'end': 200},
#   {'entity_group': 'LOC',
#    'score': 0.9987759,
#    'word': 'Eure-et-Loir',
#    'start': 457,
#    'end': 470},
#   {'entity_group': 'LOC',
#    'score': 0.9867906,
#    'word': 'France',
#    'start': 745,
#    'end': 752},
#   {'entity_group': 'LOC',
#    'score': 0.93695575,
#    'word': 'Allemands',
#    'start': 943,
#    'end': 953},
#   {'entity_group': 'ORG',
#    'score': 0.99287736,
#    'word': 'Commission de régulation de l',
#    'start': 1540,
#    'end': 1571},
#   {'entity_group': 'ORG',
#    'score': 0.99243176,
#    'word': 'énergie',
#    'start': 1572,
#    'end': 1580},
#   {'entity_group': 'ORG',
#    'score': 0.99292004,
#    'word': 'CRE',
#    'start': 1582,
#    'end': 1585},
#   {'entity_group': 'LOC',
#    'score': 0.99811846,
#    'word': 'Grand Est',
#    'start': 1990,
#    'end': 2000},
#   {'entity_group': 'LOC',
#    'score': 0.99866164,
#    'word': 'Centre-Val de Loire',
#    'start': 2086,
#    'end': 2106}],
#  [{'entity_group': 'MISC',
#    'score': 0.6936145,
#    'word': 'Si',
#    'start': 0,
#    'end': 2}],
#  [{'entity_group': 'ORG',
#    'score': 0.979881,
#    'word': 'Commission européenne',
#    'start': 324,
#    'end': 347},
#   {'entity_group': 'ORG',
#    'score': 0.98170215,
#    'word': 'Cour des comptes',
#    'start': 360,
#    'end': 377},
#   {'entity_group': 'LOC',
#    'score': 0.95870996,
#    'word': 'Françaises',
#    'start': 490,
#    'end': 502},
#   {'entity_group': 'LOC',
#    'score': 0.9119312,
#    'word': 'Français',
#    'start': 509,
#    'end': 519},
#   {'entity_group': 'PER',
#    'score': 0.99906033,
#    'word': 'Hadrien Clouet',
#    'start': 526,
#    'end': 541},
#   {'entity_group': 'PER',
#    'score': 0.9988334,
#    'word': 'Benjamin Lucas',
#    'start': 542,
#    'end': 557},
#   {'entity_group': 'PER',
#    'score': 0.99890053,
#    'word': 'Marcellin Nadeau',
#    'start': 560,
#    'end': 577},
#   {'entity_group': 'ORG',
#    'score': 0.9053588,
#    'word': 'Socialistes et apparentés',
#    'start': 602,
#    'end': 629},
#   {'entity_group': 'LOC',
#    'score': 0.69878614,
#    'word': 'Français',
#    'start': 740,
#    'end': 750},
#   {'entity_group': 'ORG',
#    'score': 0.9829237,
#    'word': 'Conseil national de la refondation',
#    'start': 956,
#    'end': 991},
#   {'entity_group': 'LOC',
#    'score': 0.46745306,
#    'word': 'Gouvernement',
#    'start': 1078,
#    'end': 1091},
#   {'entity_group': 'ORG',
#    'score': 0.8861052,
#    'word': 'CNEN',
#    'start': 1242,
#    'end': 1247},
#   {'entity_group': 'ORG',
#    'score': 0.7171397,
#    'word': 'Conseil national',
#    'start': 1249,
#    'end': 1266},
#   {'entity_group': 'LOC',
#    'score': 0.47455028,
#    'word': 'Gouvernement',
#    'start': 1592,
#    'end': 1605},
#   {'entity_group': 'ORG',
#    'score': 0.99349916,
#    'word': 'Ve République',
#    'start': 1779,
#    'end': 1794},
#   {'entity_group': 'LOC',
#    'score': 0.88217026,
#    'word': 'France',
#    'start': 1843,
#    'end': 1850},
#   {'entity_group': 'ORG',
#    'score': 0.9868204,
#    'word': 'Haut Conseil des finances publiques',
#    'start': 2236,
#    'end': 2272},
#   {'entity_group': 'LOC',
#    'score': 0.4822931,
#    'word': 'Gouvernement',
#    'start': 2275,
#    'end': 2288}],
#  [{'entity_group': 'ORG',
#    'score': 0.52064395,
#    'word': 'Constitution',
#    'start': 181,
#    'end': 194}],
#  [{'entity_group': 'ORG',
#    'score': 0.98763084,
#    'word': 'Horizons',
#    'start': 20,
#    'end': 29},
#   {'entity_group': 'MISC',
#    'score': 0.9952218,
#    'word': 'Déclaration des droits de l',
#    'start': 1554,
#    'end': 1583},
#   {'entity_group': 'MISC',
#    'score': 0.99261695,
#    'word': 'homme et du citoyen',
#    'start': 1584,
#    'end': 1603},
#   {'entity_group': 'ORG',
#    'score': 0.9927994,
#    'word': 'LFI-NUPES',
#    'start': 2232,
#    'end': 2242},
#   {'entity_group': 'ORG',
#    'score': 0.9924426,
#    'word': 'GDR-NUPES',
#    'start': 2243,
#    'end': 2253},
#   {'entity_group': 'ORG',
#    'score': 0.9935697,
#    'word': 'Écolo-NUPES',
#    'start': 2256,
#    'end': 2269}],
#  [{'entity_group': 'ORG',
#    'score': 0.9898991,
#    'word': 'LR',
#    'start': 525,
#    'end': 528}],
#  [{'entity_group': 'LOC',
#    'score': 0.9807591,
#    'word': 'France',
#    'start': 148,
#    'end': 155},
#   {'entity_group': 'ORG',
#    'score': 0.99078393,
#    'word': 'La France insoumise',
#    'start': 566,
#    'end': 586},
#   {'entity_group': 'PER',
#    'score': 0.99613327,
#    'word': 'Portes',
#    'start': 761,
#    'end': 768},
#   {'entity_group': 'LOC',
#    'score': 0.9984719,
#    'word': 'Val-d’Oise',
#    'start': 1098,
#    'end': 1109},
#   {'entity_group': 'ORG',
#    'score': 0.9914576,
#    'word': 'College of Policing',
#    'start': 2065,
#    'end': 2085},
#   {'entity_group': 'LOC',
#    'score': 0.95235735,
#    'word': '-Manche',
#    'start': 2175,
#    'end': 2182}],
#  ...]

# %%
paroles_entities = (
    entities
    #.assign(entities = entities)
    [['id_syceron', 'acteur', 'entities']]
    .explode('entities')
    .dropna(subset="entities")
    .assign(
        entity = lambda df: df.entities.apply(lambda x: x['word']),
        label = lambda df: df.entities.apply(lambda x: x['entity_group']),
        score = lambda df: df.entities.apply(lambda x: x['score']),
    )
)

paroles_entities
# Out:
#         id_syceron    acteur  \
# 3          2845798  PA719472
# 3          2845798  PA719472
# 3          2845798  PA719472
# 3          2845798  PA719472
# 3          2845798  PA719472
# ...            ...       ...
# 156969     2944941  PA793382
# 156970     2944940  PA794008
# 156970     2944940  PA794008
# 156970     2944940  PA794008
# 156971     2944887  PA793382
#
#                                                  entities  \
# 3       {'entity_group': 'LOC', 'score': 0.5331272, 'w...
# 3       {'entity_group': 'ORG', 'score': 0.8141303, 'w...
# 3       {'entity_group': 'LOC', 'score': 0.8394284, 'w...
# 3       {'entity_group': 'ORG', 'score': 0.73330164, '...
# 3       {'entity_group': 'ORG', 'score': 0.6866712, 'w...
# ...                                                   ...
# 156969  {'entity_group': 'PER', 'score': 0.59652823, '...
# 156970  {'entity_group': 'LOC', 'score': 0.97599787, '...
# 156970  {'entity_group': 'LOC', 'score': 0.9880072, 'w...
# 156970  {'entity_group': 'ORG', 'score': 0.98948157, '...
# 156971  {'entity_group': 'LOC', 'score': 0.9112062, 'w...
#
#                      entity label     score
# 3                         l   LOC  0.533127
# 3       Assemblée nationale   ORG  0.814130
# 3                     Sénat   LOC  0.839428
# 3                       Dem   ORG  0.733302
# 3                       HOR   ORG  0.686671
# ...                     ...   ...       ...
# 156969               madame   PER  0.596528
# 156970               France   LOC  0.975998
# 156970               Russie   LOC  0.988007
# 156970          Écolo-NUPES   ORG  0.989482
# 156971            Allemagne   LOC  0.911206
#
# [242539 rows x 6 columns]

# %%
paroles_entities.query('entity.str.contains("Mélenchon")')
# Out:
#         id_syceron    acteur  \
# 209        2846112  PA719118
# 1658       3106851  PA795386
# 2747       2894021  PA720468
# 2840       2894266  PA331582
# 3701       2940924  PA773443
# ...            ...       ...
# 152794     3019865  PA793464
# 153786     2829324  PA718850
# 154414     2819674  PA720286
# 154425     2819773  PA720892
# 155056     2881339  PA607846
#
#                                                  entities              entity  \
# 209     {'entity_group': 'PER', 'score': 0.99541086, '...           Mélenchon
# 1658    {'entity_group': 'PER', 'score': 0.99909717, '...  Jean-Luc Mélenchon
# 2747    {'entity_group': 'PER', 'score': 0.99897784, '...  Jean-Luc Mélenchon
# 2840    {'entity_group': 'PER', 'score': 0.9988296, 'w...  Jean-Luc Mélenchon
# 3701    {'entity_group': 'PER', 'score': 0.8622595, 'w...         . Mélenchon
# ...                                                   ...                 ...
# 152794  {'entity_group': 'PER', 'score': 0.9784897, 'w...           Mélenchon
# 153786  {'entity_group': 'PER', 'score': 0.998731, 'wo...  Jean-Luc Mélenchon
# 154414  {'entity_group': 'PER', 'score': 0.8236387, 'w...         . Mélenchon
# 154425  {'entity_group': 'PER', 'score': 0.99897826, '...  Jean-Luc Mélenchon
# 155056  {'entity_group': 'PER', 'score': 0.9973748, 'w...           Mélenchon
#
#        label     score
# 209      PER  0.995411
# 1658     PER  0.999097
# 2747     PER  0.998978
# 2840     PER  0.998830
# 3701     PER  0.862260
# ...      ...       ...
# 152794   PER  0.978490
# 153786   PER  0.998731
# 154414   PER  0.823639
# 154425   PER  0.998978
# 155056   PER  0.997375
#
# [322 rows x 6 columns]

# %%
paroles_entities.query('label == "PER"').entity.value_counts().head(30)
# Out:
# Président de la République     1499
# Emmanuel Macron                 748
# Première ministre               551
# Benjamin Lucas                  445
# Marine Le Pen                   422
# Macron                          412
# Monsieur                        351
# Madame la Première ministre     337
# M. le ministre                  312
# Bruno Le Maire                  286
# la Première ministre            255
# État                            250
# Mme la Première ministre        231
# M. le rapporteur                213
# Gouvernement                    195
# Mme la rapporteure              195
# Bernalicis                      193
# M. le                           173
# François Hollande               167
# M.                              156
# Le Pen                          156
# .                               156
# Madame                          153
# Jumel                           151
# Mme la ministre                 151
# Antoine Léaument                136
# Jean-Luc Mélenchon              134
# Monsieur le ministre            126
# Léaument                        125
# Sandra Regol                    123
# Name: entity, dtype: int64

# %%
paroles_entities.query('label == "ORG"').entity.value_counts().head(30)
# Out:
# LFI-NUPES                    12993
# RE                            8609
# Écolo-NUPES                   5117
# RN                            4806
# commission                    3927
# GDR-NUPES                     3403
# SOC                           3391
# Dem                           2851
# LR                            2812
# Parlement                     1861
# Dem.                          1741
# Rassemblement national        1730
# HOR                           1705
# Union européenne              1455
# RN.                           1315
# Gouvernement                  1269
# NUPES                         1195
# Assemblée nationale           1072
# Assemblée                     1045
# EDF                            886
# Europe                         838
# Les Républicains               804
# État                           656
# LIOT                           626
# Conseil d                      576
# La France insoumise            558
# l                              553
# HOR.                           449
# Cour des comptes               443
# Socialistes et apparentés      411
# Name: entity, dtype: int64

# %%
paroles_entities.to_csv('out/interventions_entities_camenbert.csv', index=False)
