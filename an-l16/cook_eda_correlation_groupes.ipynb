# %%
import pandas as pd

# %%
organes = (pd.read_csv('out/organes.csv'))
votes = pd.read_csv('out/votes.csv')

# %%
nupes = (
    organes
    .query('libelle.str.contains("NUPES") or libelle.str.contains("France insoumise")')
)

nupes
# Out:
#                                                 @xmlns  \
# 133  http://schemas.assemblee-nationale.fr/referentiel
# 262  http://schemas.assemblee-nationale.fr/referentiel
# 291  http://schemas.assemblee-nationale.fr/referentiel
# 598  http://schemas.assemblee-nationale.fr/referentiel
#
#                                     @xmlns:xsi             @xsi:type  \
# 133  http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type
# 262  http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type
# 291  http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type
# 598  http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type
#
#           uid codeType                                            libelle  \
# 133  PO800490       GP  La France insoumise - Nouvelle Union Populaire...
# 262  PO800496       GP  Socialistes et apparentés (membre de l’intergr...
# 291  PO800526       GP                                 Écologiste - NUPES
# 598  PO800502       GP           Gauche démocrate et républicaine - NUPES
#
#                                         libelleEdition  libelleAbrege  \
# 133  du groupe La France insoumise - Nouvelle Union...    LFI - NUPES
# 262  du groupe Socialistes et apparentés (membre de...            SOC
# 291                       du groupe Écologiste - NUPES  Ecolo - NUPES
# 598  du groupe de la Gauche démocrate et républicai...    GDR - NUPES
#
#     libelleAbrev                                             viMoDe  ...  \
# 133    LFI-NUPES  {'dateDebut': '2022-06-28', 'dateAgrement': No...  ...
# 262          SOC  {'dateDebut': '2022-06-28', 'dateAgrement': No...  ...
# 291        ECOLO  {'dateDebut': '2022-06-28', 'dateAgrement': No...  ...
# 598    GDR-NUPES  {'dateDebut': '2022-06-28', 'dateAgrement': No...  ...
#
#               regime  legislature  \
# 133  5ème République         16.0
# 262  5ème République         16.0
# 291  5ème République         16.0
# 598  5ème République         16.0
#
#                                       secretariat  listePays regimeJuridique  \
# 133  {'secretaire01': None, 'secretaire02': None}        NaN             NaN
# 262  {'secretaire01': None, 'secretaire02': None}        NaN             NaN
# 291  {'secretaire01': None, 'secretaire02': None}        NaN             NaN
# 598  {'secretaire01': None, 'secretaire02': None}        NaN             NaN
#
#     siteInternet nombreReunionsAnnuelles positionPolitique  preseance  \
# 133          NaN                     NaN        Opposition        3.0
# 262          NaN                     NaN        Opposition        6.0
# 291          NaN                     NaN        Opposition        8.0
# 598          NaN                     NaN        Opposition        9.0
#
#     couleurAssociee
# 133         #E42313
# 262         #DF84B5
# 291         #77AA79
# 598         #991414
#
# [4 rows x 22 columns]

# %%
alignements = (
    votes
#    .query('organe.isin(@nupes.uid)')
    .groupby(['scrutin', 'organe'])
    .agg({
        'groupe_majorite': 'first'
    })
    .reset_index()
    .assign(
        organe = lambda df: df.join(organes.set_index('uid'), on='organe')[['libelle']]
    )
    .pivot_table(
        index="scrutin",
        columns="organe",
        values="groupe_majorite",
        aggfunc= lambda x: x
    )
)

alignements
# Out:
# organe         Démocrate (MoDem et Indépendants)  \
# scrutin
# VTANR5L16V1                                  NaN
# VTANR5L16V10                              contre
# VTANR5L16V100                             contre
# VTANR5L16V1000                            contre
# VTANR5L16V1001                            contre
# ...                                          ...
# VTANR5L16V995                             contre
# VTANR5L16V996                             contre
# VTANR5L16V997                             contre
# VTANR5L16V998                             contre
# VTANR5L16V999                             contre
#
# organe         Gauche démocrate et républicaine - NUPES  \
# scrutin
# VTANR5L16V1                                        pour
# VTANR5L16V10                                     contre
# VTANR5L16V100                                      pour
# VTANR5L16V1000                                     pour
# VTANR5L16V1001                                     pour
# ...                                                 ...
# VTANR5L16V995                                      pour
# VTANR5L16V996                                      pour
# VTANR5L16V997                                      pour
# VTANR5L16V998                                      pour
# VTANR5L16V999                                      pour
#
# organe         Horizons et apparentés  \
# scrutin
# VTANR5L16V1                       NaN
# VTANR5L16V10                   contre
# VTANR5L16V100                  contre
# VTANR5L16V1000                 contre
# VTANR5L16V1001                 contre
# ...                               ...
# VTANR5L16V995                  contre
# VTANR5L16V996                  contre
# VTANR5L16V997                  contre
# VTANR5L16V998                  contre
# VTANR5L16V999                  contre
#
# organe         La France insoumise - Nouvelle Union Populaire écologique et sociale  \
# scrutin
# VTANR5L16V1                                                  pour
# VTANR5L16V10                                           abstention
# VTANR5L16V100                                                pour
# VTANR5L16V1000                                               pour
# VTANR5L16V1001                                               pour
# ...                                                           ...
# VTANR5L16V995                                                pour
# VTANR5L16V996                                                pour
# VTANR5L16V997                                                pour
# VTANR5L16V998                                                pour
# VTANR5L16V999                                                pour
#
# organe         Les Républicains  \
# scrutin
# VTANR5L16V1                 NaN
# VTANR5L16V10             contre
# VTANR5L16V100            contre
# VTANR5L16V1000           contre
# VTANR5L16V1001           contre
# ...                         ...
# VTANR5L16V995            contre
# VTANR5L16V996            contre
# VTANR5L16V997            contre
# VTANR5L16V998            contre
# VTANR5L16V999            contre
#
# organe         Libertés, Indépendants, Outre-mer et Territoires Non inscrit  \
# scrutin
# VTANR5L16V1                                                 NaN        pour
# VTANR5L16V10                                             contre        pour
# VTANR5L16V100                                              pour      contre
# VTANR5L16V1000                                             pour      contre
# VTANR5L16V1001                                             pour      contre
# ...                                                         ...         ...
# VTANR5L16V995                                              pour         NaN
# VTANR5L16V996                                              pour        pour
# VTANR5L16V997                                              pour        pour
# VTANR5L16V998                                              pour  abstention
# VTANR5L16V999                                              pour      contre
#
# organe         Rassemblement National Renaissance  \
# scrutin
# VTANR5L16V1                       NaN         NaN
# VTANR5L16V10                     pour      contre
# VTANR5L16V100                  contre      contre
# VTANR5L16V1000                 contre      contre
# VTANR5L16V1001                 contre      contre
# ...                               ...         ...
# VTANR5L16V995              abstention      contre
# VTANR5L16V996                    pour      contre
# VTANR5L16V997                    pour      contre
# VTANR5L16V998                    pour      contre
# VTANR5L16V999                  contre      contre
#
# organe         Socialistes et apparentés (membre de l’intergroupe NUPES)  \
# scrutin
# VTANR5L16V1                                                  pour
# VTANR5L16V10                                               contre
# VTANR5L16V100                                                pour
# VTANR5L16V1000                                               pour
# VTANR5L16V1001                                               pour
# ...                                                           ...
# VTANR5L16V995                                                pour
# VTANR5L16V996                                                pour
# VTANR5L16V997                                                pour
# VTANR5L16V998                                                pour
# VTANR5L16V999                                                pour
#
# organe         Écologiste - NUPES
# scrutin
# VTANR5L16V1                  pour
# VTANR5L16V10               contre
# VTANR5L16V100                pour
# VTANR5L16V1000               pour
# VTANR5L16V1001               pour
# ...                           ...
# VTANR5L16V995                pour
# VTANR5L16V996                pour
# VTANR5L16V997                pour
# VTANR5L16V998                pour
# VTANR5L16V999                pour
#
# [1504 rows x 11 columns]

# %%
def get_covotes(df, groupe):
    return (
        df
        .T
        .fillna('non votant')
        .pipe( lambda df: (
            df
            .eq(df.loc[groupe])
        ))
        .sum(axis=1)
        .to_frame()
        .rename(columns={0: groupe})
    )

covotes = pd.concat([ get_covotes(alignements, g).T for g in alignements.T.index ])

covotes
# Out:
# organe                                              Démocrate (MoDem et Indépendants)  \
# Démocrate (MoDem et Indépendants)                                                1504
# Gauche démocrate et républicaine - NUPES                                          357
# Horizons et apparentés                                                           1405
# La France insoumise - Nouvelle Union Populaire ...                                353
# Les Républicains                                                                  910
# Libertés, Indépendants, Outre-mer et Territoires                                  602
# Non inscrit                                                                       570
# Rassemblement National                                                            464
# Renaissance                                                                      1452
# Socialistes et apparentés (membre de l’intergro...                                498
# Écologiste - NUPES                                                                457
#
# organe                                              Gauche démocrate et républicaine - NUPES  \
# Démocrate (MoDem et Indépendants)                                                        357
# Gauche démocrate et républicaine - NUPES                                                1504
# Horizons et apparentés                                                                   348
# La France insoumise - Nouvelle Union Populaire ...                                      1058
# Les Républicains                                                                         442
# Libertés, Indépendants, Outre-mer et Territoires                                         750
# Non inscrit                                                                              515
# Rassemblement National                                                                   548
# Renaissance                                                                              342
# Socialistes et apparentés (membre de l’intergro...                                      1019
# Écologiste - NUPES                                                                      1085
#
# organe                                              Horizons et apparentés  \
# Démocrate (MoDem et Indépendants)                                     1405
# Gauche démocrate et républicaine - NUPES                               348
# Horizons et apparentés                                                1504
# La France insoumise - Nouvelle Union Populaire ...                     331
# Les Républicains                                                       902
# Libertés, Indépendants, Outre-mer et Territoires                       589
# Non inscrit                                                            597
# Rassemblement National                                                 452
# Renaissance                                                           1405
# Socialistes et apparentés (membre de l’intergro...                     481
# Écologiste - NUPES                                                     436
#
# organe                                              La France insoumise - Nouvelle Union Populaire écologique et sociale  \
# Démocrate (MoDem et Indépendants)                                                                 353
# Gauche démocrate et républicaine - NUPES                                                         1058
# Horizons et apparentés                                                                            331
# La France insoumise - Nouvelle Union Populaire ...                                               1504
# Les Républicains                                                                                  407
# Libertés, Indépendants, Outre-mer et Territoires                                                  686
# Non inscrit                                                                                       414
# Rassemblement National                                                                            535
# Renaissance                                                                                       336
# Socialistes et apparentés (membre de l’intergro...                                               1113
# Écologiste - NUPES                                                                               1200
#
# organe                                              Les Républicains  \
# Démocrate (MoDem et Indépendants)                                910
# Gauche démocrate et républicaine - NUPES                         442
# Horizons et apparentés                                           902
# La France insoumise - Nouvelle Union Populaire ...               407
# Les Républicains                                                1504
# Libertés, Indépendants, Outre-mer et Territoires                 642
# Non inscrit                                                      828
# Rassemblement National                                           800
# Renaissance                                                      899
# Socialistes et apparentés (membre de l’intergro...               489
# Écologiste - NUPES                                               435
#
# organe                                              Libertés, Indépendants, Outre-mer et Territoires  \
# Démocrate (MoDem et Indépendants)                                                                602
# Gauche démocrate et républicaine - NUPES                                                         750
# Horizons et apparentés                                                                           589
# La France insoumise - Nouvelle Union Populaire ...                                               686
# Les Républicains                                                                                 642
# Libertés, Indépendants, Outre-mer et Territoires                                                1504
# Non inscrit                                                                                      664
# Rassemblement National                                                                           635
# Renaissance                                                                                      590
# Socialistes et apparentés (membre de l’intergro...                                               778
# Écologiste - NUPES                                                                               747
#
# organe                                              Non inscrit  \
# Démocrate (MoDem et Indépendants)                           570
# Gauche démocrate et républicaine - NUPES                    515
# Horizons et apparentés                                      597
# La France insoumise - Nouvelle Union Populaire ...          414
# Les Républicains                                            828
# Libertés, Indépendants, Outre-mer et Territoires            664
# Non inscrit                                                1504
# Rassemblement National                                      747
# Renaissance                                                 549
# Socialistes et apparentés (membre de l’intergro...          477
# Écologiste - NUPES                                          440
#
# organe                                              Rassemblement National  \
# Démocrate (MoDem et Indépendants)                                      464
# Gauche démocrate et républicaine - NUPES                               548
# Horizons et apparentés                                                 452
# La France insoumise - Nouvelle Union Populaire ...                     535
# Les Républicains                                                       800
# Libertés, Indépendants, Outre-mer et Territoires                       635
# Non inscrit                                                            747
# Rassemblement National                                                1504
# Renaissance                                                            456
# Socialistes et apparentés (membre de l’intergro...                     552
# Écologiste - NUPES                                                     529
#
# organe                                              Renaissance  \
# Démocrate (MoDem et Indépendants)                          1452
# Gauche démocrate et républicaine - NUPES                    342
# Horizons et apparentés                                     1405
# La France insoumise - Nouvelle Union Populaire ...          336
# Les Républicains                                            899
# Libertés, Indépendants, Outre-mer et Territoires            590
# Non inscrit                                                 549
# Rassemblement National                                      456
# Renaissance                                                1504
# Socialistes et apparentés (membre de l’intergro...          482
# Écologiste - NUPES                                          447
#
# organe                                              Socialistes et apparentés (membre de l’intergroupe NUPES)  \
# Démocrate (MoDem et Indépendants)                                                                 498
# Gauche démocrate et républicaine - NUPES                                                         1019
# Horizons et apparentés                                                                            481
# La France insoumise - Nouvelle Union Populaire ...                                               1113
# Les Républicains                                                                                  489
# Libertés, Indépendants, Outre-mer et Territoires                                                  778
# Non inscrit                                                                                       477
# Rassemblement National                                                                            552
# Renaissance                                                                                       482
# Socialistes et apparentés (membre de l’intergro...                                               1504
# Écologiste - NUPES                                                                               1184
#
# organe                                              Écologiste - NUPES
# Démocrate (MoDem et Indépendants)                                  457
# Gauche démocrate et républicaine - NUPES                          1085
# Horizons et apparentés                                             436
# La France insoumise - Nouvelle Union Populaire ...                1200
# Les Républicains                                                   435
# Libertés, Indépendants, Outre-mer et Territoires                   747
# Non inscrit                                                        440
# Rassemblement National                                             529
# Renaissance                                                        447
# Socialistes et apparentés (membre de l’intergro...                1184
# Écologiste - NUPES                                                1504

# %%
import numpy as np

# %%
import scipy
import scipy.cluster.hierarchy as sch

def cluster_corr(corr_array, inplace=False):
    """
    Rearranges the correlation matrix, corr_array, so that groups of highly 
    correlated variables are next to eachother 
    
    Parameters
    ----------
    corr_array : pandas.DataFrame or numpy.ndarray
        a NxN correlation matrix 
        
    Returns
    -------
    pandas.DataFrame or numpy.ndarray
        a NxN correlation matrix with the columns and rows rearranged
    """
    pairwise_distances = sch.distance.pdist(corr_array)
    linkage = sch.linkage(pairwise_distances, method='complete')
    cluster_distance_threshold = pairwise_distances.max()/2
    idx_to_cluster_array = sch.fcluster(linkage, cluster_distance_threshold, 
                                        criterion='distance')
    idx = np.argsort(idx_to_cluster_array)
    
    if not inplace:
        corr_array = corr_array.copy()
    
    if isinstance(corr_array, pd.DataFrame):
        return corr_array.iloc[idx, :].T.iloc[idx, :]
    return corr_array[idx, :][:, idx]

# %%
(
    cluster_corr(covotes)
    .div(
        len(alignements.index), axis=0
    )
    .replace(1, np.nan)
    .style
        .format('{:,.1%}'.format)
        .background_gradient(
            cmap='PiYG',
            vmin=0,
            vmax=1
        )
)
# Out:
# <style type="text/css">
# #T_4a540_row0_col0, #T_4a540_row1_col1, #T_4a540_row2_col2, #T_4a540_row3_col3, #T_4a540_row4_col4, #T_4a540_row5_col5, #T_4a540_row6_col6, #T_4a540_row7_col7, #T_4a540_row8_col8, #T_4a540_row9_col9, #T_4a540_row10_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4a540_row0_col1, #T_4a540_row1_col0, #T_4a540_row1_col3, #T_4a540_row3_col1 {
#   background-color: #3f811e;
#   color: #f1f1f1;
# }
# #T_4a540_row0_col2, #T_4a540_row2_col0 {
#   background-color: #e4f4cd;
#   color: #000000;
# }
# #T_4a540_row0_col3, #T_4a540_row3_col0 {
#   background-color: #33721c;
#   color: #f1f1f1;
# }
# #T_4a540_row0_col4, #T_4a540_row0_col5, #T_4a540_row4_col0, #T_4a540_row5_col0 {
#   background-color: #e58dbe;
#   color: #f1f1f1;
# }
# #T_4a540_row0_col6, #T_4a540_row6_col0 {
#   background-color: #f5c2e0;
#   color: #000000;
# }
# #T_4a540_row0_col7, #T_4a540_row3_col9, #T_4a540_row7_col0, #T_4a540_row9_col3 {
#   background-color: #f1b7da;
#   color: #000000;
# }
# #T_4a540_row0_col8, #T_4a540_row8_col0 {
#   background-color: #fbd8eb;
#   color: #000000;
# }
# #T_4a540_row0_col9, #T_4a540_row9_col0 {
#   background-color: #f2b8db;
#   color: #000000;
# }
# #T_4a540_row0_col10, #T_4a540_row10_col0 {
#   background-color: #fde0ef;
#   color: #000000;
# }
# #T_4a540_row1_col2, #T_4a540_row2_col1, #T_4a540_row2_col3, #T_4a540_row3_col2 {
#   background-color: #e6f5d0;
#   color: #000000;
# }
# #T_4a540_row1_col4, #T_4a540_row4_col1 {
#   background-color: #e48bbc;
#   color: #f1f1f1;
# }
# #T_4a540_row1_col5, #T_4a540_row5_col1 {
#   background-color: #e283b7;
#   color: #f1f1f1;
# }
# #T_4a540_row1_col6, #T_4a540_row6_col1, #T_4a540_row6_col8, #T_4a540_row8_col6 {
#   background-color: #f3bdde;
#   color: #000000;
# }
# #T_4a540_row1_col7, #T_4a540_row2_col7, #T_4a540_row7_col1, #T_4a540_row7_col2, #T_4a540_row7_col8, #T_4a540_row8_col7 {
#   background-color: #efb0d6;
#   color: #000000;
# }
# #T_4a540_row1_col8, #T_4a540_row8_col1 {
#   background-color: #fddeee;
#   color: #000000;
# }
# #T_4a540_row1_col9, #T_4a540_row3_col7, #T_4a540_row7_col3, #T_4a540_row9_col1 {
#   background-color: #f1b5d9;
#   color: #000000;
# }
# #T_4a540_row1_col10, #T_4a540_row3_col10, #T_4a540_row10_col1, #T_4a540_row10_col3 {
#   background-color: #fcdded;
#   color: #000000;
# }
# #T_4a540_row2_col4, #T_4a540_row4_col2 {
#   background-color: #f0b2d7;
#   color: #000000;
# }
# #T_4a540_row2_col5, #T_4a540_row5_col2 {
#   background-color: #eba3cd;
#   color: #000000;
# }
# #T_4a540_row2_col6, #T_4a540_row6_col2 {
#   background-color: #f4c1df;
#   color: #000000;
# }
# #T_4a540_row2_col8, #T_4a540_row8_col2 {
#   background-color: #eff6e4;
#   color: #000000;
# }
# #T_4a540_row2_col9, #T_4a540_row9_col2 {
#   background-color: #f1f6ea;
#   color: #000000;
# }
# #T_4a540_row2_col10, #T_4a540_row10_col2 {
#   background-color: #fbe6f1;
#   color: #000000;
# }
# #T_4a540_row3_col4, #T_4a540_row4_col3 {
#   background-color: #e388ba;
#   color: #f1f1f1;
# }
# #T_4a540_row3_col5, #T_4a540_row5_col3 {
#   background-color: #e286b8;
#   color: #f1f1f1;
# }
# #T_4a540_row3_col6, #T_4a540_row6_col3 {
#   background-color: #f4bfdf;
#   color: #000000;
# }
# #T_4a540_row3_col8, #T_4a540_row4_col9, #T_4a540_row6_col9, #T_4a540_row8_col3, #T_4a540_row9_col4, #T_4a540_row9_col6 {
#   background-color: #f9d1e8;
#   color: #000000;
# }
# #T_4a540_row4_col5, #T_4a540_row5_col4 {
#   background-color: #b5df82;
#   color: #000000;
# }
# #T_4a540_row4_col6, #T_4a540_row6_col4 {
#   background-color: #c2e596;
#   color: #000000;
# }
# #T_4a540_row4_col7, #T_4a540_row7_col4 {
#   background-color: #acd977;
#   color: #000000;
# }
# #T_4a540_row4_col8, #T_4a540_row8_col4 {
#   background-color: #f6c7e3;
#   color: #000000;
# }
# #T_4a540_row4_col10, #T_4a540_row7_col10, #T_4a540_row8_col9, #T_4a540_row9_col8, #T_4a540_row10_col4, #T_4a540_row10_col7 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_4a540_row5_col6, #T_4a540_row6_col5 {
#   background-color: #a1d26a;
#   color: #000000;
# }
# #T_4a540_row5_col7, #T_4a540_row7_col5 {
#   background-color: #7fbc41;
#   color: #000000;
# }
# #T_4a540_row5_col8, #T_4a540_row8_col5 {
#   background-color: #eca6cf;
#   color: #000000;
# }
# #T_4a540_row5_col9, #T_4a540_row9_col5 {
#   background-color: #f8cee6;
#   color: #000000;
# }
# #T_4a540_row5_col10, #T_4a540_row10_col5 {
#   background-color: #faedf3;
#   color: #000000;
# }
# #T_4a540_row6_col7, #T_4a540_row7_col6 {
#   background-color: #86c049;
#   color: #000000;
# }
# #T_4a540_row6_col10, #T_4a540_row10_col6 {
#   background-color: #f4f7f0;
#   color: #000000;
# }
# #T_4a540_row7_col9, #T_4a540_row9_col7 {
#   background-color: #f7cce5;
#   color: #000000;
# }
# #T_4a540_row8_col10, #T_4a540_row10_col8 {
#   background-color: #faeaf2;
#   color: #000000;
# }
# #T_4a540_row9_col10, #T_4a540_row10_col9 {
#   background-color: #fce5f1;
#   color: #000000;
# }
# </style>
# <table id="T_4a540">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a540_level0_col0" class="col_heading level0 col0" >Démocrate (MoDem et Indépendants)</th>
#       <th id="T_4a540_level0_col1" class="col_heading level0 col1" >Horizons et apparentés</th>
#       <th id="T_4a540_level0_col2" class="col_heading level0 col2" >Les Républicains</th>
#       <th id="T_4a540_level0_col3" class="col_heading level0 col3" >Renaissance</th>
#       <th id="T_4a540_level0_col4" class="col_heading level0 col4" >Gauche démocrate et républicaine - NUPES</th>
#       <th id="T_4a540_level0_col5" class="col_heading level0 col5" >La France insoumise - Nouvelle Union Populaire écologique et sociale</th>
#       <th id="T_4a540_level0_col6" class="col_heading level0 col6" >Socialistes et apparentés (membre de l’intergroupe NUPES)</th>
#       <th id="T_4a540_level0_col7" class="col_heading level0 col7" >Écologiste - NUPES</th>
#       <th id="T_4a540_level0_col8" class="col_heading level0 col8" >Non inscrit</th>
#       <th id="T_4a540_level0_col9" class="col_heading level0 col9" >Rassemblement National</th>
#       <th id="T_4a540_level0_col10" class="col_heading level0 col10" >Libertés, Indépendants, Outre-mer et Territoires</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >organe</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a540_level0_row0" class="row_heading level0 row0" >Démocrate (MoDem et Indépendants)</th>
#       <td id="T_4a540_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_4a540_row0_col1" class="data row0 col1" >93.4%</td>
#       <td id="T_4a540_row0_col2" class="data row0 col2" >60.5%</td>
#       <td id="T_4a540_row0_col3" class="data row0 col3" >96.5%</td>
#       <td id="T_4a540_row0_col4" class="data row0 col4" >23.7%</td>
#       <td id="T_4a540_row0_col5" class="data row0 col5" >23.5%</td>
#       <td id="T_4a540_row0_col6" class="data row0 col6" >33.1%</td>
#       <td id="T_4a540_row0_col7" class="data row0 col7" >30.4%</td>
#       <td id="T_4a540_row0_col8" class="data row0 col8" >37.9%</td>
#       <td id="T_4a540_row0_col9" class="data row0 col9" >30.9%</td>
#       <td id="T_4a540_row0_col10" class="data row0 col10" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4a540_level0_row1" class="row_heading level0 row1" >Horizons et apparentés</th>
#       <td id="T_4a540_row1_col0" class="data row1 col0" >93.4%</td>
#       <td id="T_4a540_row1_col1" class="data row1 col1" >nan%</td>
#       <td id="T_4a540_row1_col2" class="data row1 col2" >60.0%</td>
#       <td id="T_4a540_row1_col3" class="data row1 col3" >93.4%</td>
#       <td id="T_4a540_row1_col4" class="data row1 col4" >23.1%</td>
#       <td id="T_4a540_row1_col5" class="data row1 col5" >22.0%</td>
#       <td id="T_4a540_row1_col6" class="data row1 col6" >32.0%</td>
#       <td id="T_4a540_row1_col7" class="data row1 col7" >29.0%</td>
#       <td id="T_4a540_row1_col8" class="data

# %%
(
    cluster_corr(
        covotes
        .div(
            len(alignements.index), axis=0
        )
    )
    .replace(1, np.nan)
    .style
        .format('{:,.1%}'.format)
        .background_gradient(
            cmap='PiYG',
            vmin=0,
            vmax=1
        )
)
# Out:
# <style type="text/css">
# #T_22f16_row0_col0, #T_22f16_row1_col1, #T_22f16_row2_col2, #T_22f16_row3_col3, #T_22f16_row4_col4, #T_22f16_row5_col5, #T_22f16_row6_col6, #T_22f16_row7_col7, #T_22f16_row8_col8, #T_22f16_row9_col9, #T_22f16_row10_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_22f16_row0_col1, #T_22f16_row1_col0, #T_22f16_row1_col3, #T_22f16_row3_col1 {
#   background-color: #3f811e;
#   color: #f1f1f1;
# }
# #T_22f16_row0_col2, #T_22f16_row2_col0 {
#   background-color: #e4f4cd;
#   color: #000000;
# }
# #T_22f16_row0_col3, #T_22f16_row3_col0 {
#   background-color: #33721c;
#   color: #f1f1f1;
# }
# #T_22f16_row0_col4, #T_22f16_row0_col5, #T_22f16_row4_col0, #T_22f16_row5_col0 {
#   background-color: #e58dbe;
#   color: #f1f1f1;
# }
# #T_22f16_row0_col6, #T_22f16_row6_col0 {
#   background-color: #f5c2e0;
#   color: #000000;
# }
# #T_22f16_row0_col7, #T_22f16_row3_col9, #T_22f16_row7_col0, #T_22f16_row9_col3 {
#   background-color: #f1b7da;
#   color: #000000;
# }
# #T_22f16_row0_col8, #T_22f16_row8_col0 {
#   background-color: #fbd8eb;
#   color: #000000;
# }
# #T_22f16_row0_col9, #T_22f16_row9_col0 {
#   background-color: #f2b8db;
#   color: #000000;
# }
# #T_22f16_row0_col10, #T_22f16_row10_col0 {
#   background-color: #fde0ef;
#   color: #000000;
# }
# #T_22f16_row1_col2, #T_22f16_row2_col1, #T_22f16_row2_col3, #T_22f16_row3_col2 {
#   background-color: #e6f5d0;
#   color: #000000;
# }
# #T_22f16_row1_col4, #T_22f16_row4_col1 {
#   background-color: #e48bbc;
#   color: #f1f1f1;
# }
# #T_22f16_row1_col5, #T_22f16_row5_col1 {
#   background-color: #e283b7;
#   color: #f1f1f1;
# }
# #T_22f16_row1_col6, #T_22f16_row6_col1, #T_22f16_row6_col8, #T_22f16_row8_col6 {
#   background-color: #f3bdde;
#   color: #000000;
# }
# #T_22f16_row1_col7, #T_22f16_row2_col7, #T_22f16_row7_col1, #T_22f16_row7_col2, #T_22f16_row7_col8, #T_22f16_row8_col7 {
#   background-color: #efb0d6;
#   color: #000000;
# }
# #T_22f16_row1_col8, #T_22f16_row8_col1 {
#   background-color: #fddeee;
#   color: #000000;
# }
# #T_22f16_row1_col9, #T_22f16_row3_col7, #T_22f16_row7_col3, #T_22f16_row9_col1 {
#   background-color: #f1b5d9;
#   color: #000000;
# }
# #T_22f16_row1_col10, #T_22f16_row3_col10, #T_22f16_row10_col1, #T_22f16_row10_col3 {
#   background-color: #fcdded;
#   color: #000000;
# }
# #T_22f16_row2_col4, #T_22f16_row4_col2 {
#   background-color: #f0b2d7;
#   color: #000000;
# }
# #T_22f16_row2_col5, #T_22f16_row5_col2 {
#   background-color: #eba3cd;
#   color: #000000;
# }
# #T_22f16_row2_col6, #T_22f16_row6_col2 {
#   background-color: #f4c1df;
#   color: #000000;
# }
# #T_22f16_row2_col8, #T_22f16_row8_col2 {
#   background-color: #eff6e4;
#   color: #000000;
# }
# #T_22f16_row2_col9, #T_22f16_row9_col2 {
#   background-color: #f1f6ea;
#   color: #000000;
# }
# #T_22f16_row2_col10, #T_22f16_row10_col2 {
#   background-color: #fbe6f1;
#   color: #000000;
# }
# #T_22f16_row3_col4, #T_22f16_row4_col3 {
#   background-color: #e388ba;
#   color: #f1f1f1;
# }
# #T_22f16_row3_col5, #T_22f16_row5_col3 {
#   background-color: #e286b8;
#   color: #f1f1f1;
# }
# #T_22f16_row3_col6, #T_22f16_row6_col3 {
#   background-color: #f4bfdf;
#   color: #000000;
# }
# #T_22f16_row3_col8, #T_22f16_row4_col9, #T_22f16_row6_col9, #T_22f16_row8_col3, #T_22f16_row9_col4, #T_22f16_row9_col6 {
#   background-color: #f9d1e8;
#   color: #000000;
# }
# #T_22f16_row4_col5, #T_22f16_row5_col4 {
#   background-color: #b5df82;
#   color: #000000;
# }
# #T_22f16_row4_col6, #T_22f16_row6_col4 {
#   background-color: #c2e596;
#   color: #000000;
# }
# #T_22f16_row4_col7, #T_22f16_row7_col4 {
#   background-color: #acd977;
#   color: #000000;
# }
# #T_22f16_row4_col8, #T_22f16_row8_col4 {
#   background-color: #f6c7e3;
#   color: #000000;
# }
# #T_22f16_row4_col10, #T_22f16_row7_col10, #T_22f16_row8_col9, #T_22f16_row9_col8, #T_22f16_row10_col4, #T_22f16_row10_col7 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_22f16_row5_col6, #T_22f16_row6_col5 {
#   background-color: #a1d26a;
#   color: #000000;
# }
# #T_22f16_row5_col7, #T_22f16_row7_col5 {
#   background-color: #7fbc41;
#   color: #000000;
# }
# #T_22f16_row5_col8, #T_22f16_row8_col5 {
#   background-color: #eca6cf;
#   color: #000000;
# }
# #T_22f16_row5_col9, #T_22f16_row9_col5 {
#   background-color: #f8cee6;
#   color: #000000;
# }
# #T_22f16_row5_col10, #T_22f16_row10_col5 {
#   background-color: #faedf3;
#   color: #000000;
# }
# #T_22f16_row6_col7, #T_22f16_row7_col6 {
#   background-color: #86c049;
#   color: #000000;
# }
# #T_22f16_row6_col10, #T_22f16_row10_col6 {
#   background-color: #f4f7f0;
#   color: #000000;
# }
# #T_22f16_row7_col9, #T_22f16_row9_col7 {
#   background-color: #f7cce5;
#   color: #000000;
# }
# #T_22f16_row8_col10, #T_22f16_row10_col8 {
#   background-color: #faeaf2;
#   color: #000000;
# }
# #T_22f16_row9_col10, #T_22f16_row10_col9 {
#   background-color: #fce5f1;
#   color: #000000;
# }
# </style>
# <table id="T_22f16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22f16_level0_col0" class="col_heading level0 col0" >Démocrate (MoDem et Indépendants)</th>
#       <th id="T_22f16_level0_col1" class="col_heading level0 col1" >Horizons et apparentés</th>
#       <th id="T_22f16_level0_col2" class="col_heading level0 col2" >Les Républicains</th>
#       <th id="T_22f16_level0_col3" class="col_heading level0 col3" >Renaissance</th>
#       <th id="T_22f16_level0_col4" class="col_heading level0 col4" >Gauche démocrate et républicaine - NUPES</th>
#       <th id="T_22f16_level0_col5" class="col_heading level0 col5" >La France insoumise - Nouvelle Union Populaire écologique et sociale</th>
#       <th id="T_22f16_level0_col6" class="col_heading level0 col6" >Socialistes et apparentés (membre de l’intergroupe NUPES)</th>
#       <th id="T_22f16_level0_col7" class="col_heading level0 col7" >Écologiste - NUPES</th>
#       <th id="T_22f16_level0_col8" class="col_heading level0 col8" >Non inscrit</th>
#       <th id="T_22f16_level0_col9" class="col_heading level0 col9" >Rassemblement National</th>
#       <th id="T_22f16_level0_col10" class="col_heading level0 col10" >Libertés, Indépendants, Outre-mer et Territoires</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >organe</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22f16_level0_row0" class="row_heading level0 row0" >Démocrate (MoDem et Indépendants)</th>
#       <td id="T_22f16_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_22f16_row0_col1" class="data row0 col1" >93.4%</td>
#       <td id="T_22f16_row0_col2" class="data row0 col2" >60.5%</td>
#       <td id="T_22f16_row0_col3" class="data row0 col3" >96.5%</td>
#       <td id="T_22f16_row0_col4" class="data row0 col4" >23.7%</td>
#       <td id="T_22f16_row0_col5" class="data row0 col5" >23.5%</td>
#       <td id="T_22f16_row0_col6" class="data row0 col6" >33.1%</td>
#       <td id="T_22f16_row0_col7" class="data row0 col7" >30.4%</td>
#       <td id="T_22f16_row0_col8" class="data row0 col8" >37.9%</td>
#       <td id="T_22f16_row0_col9" class="data row0 col9" >30.9%</td>
#       <td id="T_22f16_row0_col10" class="data row0 col10" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_22f16_level0_row1" class="row_heading level0 row1" >Horizons et apparentés</th>
#       <td id="T_22f16_row1_col0" class="data row1 col0" >93.4%</td>
#       <td id="T_22f16_row1_col1" class="data row1 col1" >nan%</td>
#       <td id="T_22f16_row1_col2" class="data row1 col2" >60.0%</td>
#       <td id="T_22f16_row1_col3" class="data row1 col3" >93.4%</td>
#       <td id="T_22f16_row1_col4" class="data row1 col4" >23.1%</td>
#       <td id="T_22f16_row1_col5" class="data row1 col5" >22.0%</td>
#       <td id="T_22f16_row1_col6" class="data row1 col6" >32.0%</td>
#       <td id="T_22f16_row1_col7" class="data row1 col7" >29.0%</td>
#       <td id="T_22f16_row1_col8" class="data

# %%
organes_pca = pd.read_csv('out/organes_pca.csv')

organes_pca
# Out:
#                                               libelle      axe 1      axe 2  \
# 0                                  Écologiste - NUPES -15.861192  -8.962629
# 1   La France insoumise - Nouvelle Union Populaire... -18.195686  -8.284161
# 2   Socialistes et apparentés (membre de l’intergr... -11.725753  -5.530954
# 3            Gauche démocrate et républicaine - NUPES -10.833742  -3.864243
# 4                   Démocrate (MoDem et Indépendants)  11.967708  -1.401537
# 5                              Horizons et apparentés  11.211491  -1.290768
# 6                                         Renaissance  13.744716  -1.252989
# 7    Libertés, Indépendants, Outre-mer et Territoires  -4.841635  -0.627983
# 8                                         Non inscrit  -3.991444   1.488039
# 9                                    Les Républicains   1.432160   4.147781
# 10                             Rassemblement National -10.761715  12.981919
#
#                                                @xmlns  \
# 0   http://schemas.assemblee-nationale.fr/referentiel
# 1   http://schemas.assemblee-nationale.fr/referentiel
# 2   http://schemas.assemblee-nationale.fr/referentiel
# 3   http://schemas.assemblee-nationale.fr/referentiel
# 4   http://schemas.assemblee-nationale.fr/referentiel
# 5   http://schemas.assemblee-nationale.fr/referentiel
# 6   http://schemas.assemblee-nationale.fr/referentiel
# 7   http://schemas.assemblee-nationale.fr/referentiel
# 8   http://schemas.assemblee-nationale.fr/referentiel
# 9   http://schemas.assemblee-nationale.fr/referentiel
# 10  http://schemas.assemblee-nationale.fr/referentiel
#
#                                    @xmlns:xsi             @xsi:type codeType  \
# 0   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 1   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 2   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 3   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 4   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 5   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 6   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 7   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 8   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 9   http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
# 10  http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type       GP
#
#                                        libelleEdition  libelleAbrege  \
# 0                        du groupe Écologiste - NUPES  Ecolo - NUPES
# 1   du groupe La France insoumise - Nouvelle Union...    LFI - NUPES
# 2   du groupe Socialistes et apparentés (membre de...            SOC
# 3   du groupe de la Gauche démocrate et républicai...    GDR - NUPES
# 4         du groupe Démocrate (MoDem et Indépendants)            Dem
# 5                    du groupe Horizons et apparentés            HOR
# 6                               du groupe Renaissance             RE
# 7   du groupe Libertés, Indépendants, Outre-mer et...           LIOT
# 8                            des députés non inscrits             NI
# 9                          du groupe Les Républicains             LR
# 10                   du groupe Rassemblement National             RN
#
#    libelleAbrev  ...           regime  legislature  \
# 0         ECOLO  ...  5ème République         16.0
# 1     LFI-NUPES  ...  5ème République         16.0
# 2           SOC  ...  5ème République         16.0
# 3     GDR-NUPES  ...  5ème République         16.0
# 4           DEM  ...  5ème République         16.0
# 5           HOR  ...  5ème République         16.0
# 6            RE  ...  5ème République         16.0
# 7          LIOT  ...  5ème République         16.0
# 8            NI  ...  5ème République         16.0
# 9            LR  ...  5ème République         16.0
# 10           RN  ...  5ème République         16.0
#
#                                      secretariat listePays  regimeJuridique  \
# 0   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 1   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 2   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 3   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 4   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 5   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 6   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 7   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 8   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 9   {'secretaire01': None, 'secretaire02': None}       NaN              NaN
# 10  {'secretaire01': None, 'secretaire02': None}       NaN              NaN
#
#    siteInternet  nombreReunionsAnnuelles  positionPolitique  preseance  \
# 0           NaN                      NaN         Opposition        8.0
# 1           NaN                      NaN         Opposition        3.0
# 2           NaN                      NaN         Opposition        6.0
# 3           NaN                      NaN         Opposition        9.0
# 4           NaN                      NaN        Minoritaire        5.0
# 5           NaN                      NaN        Minoritaire        7.0
# 6           NaN                      NaN        Majoritaire        1.0
# 7           NaN                      NaN         Opposition       10.0
# 8           NaN                      NaN                NaN       99.0
# 9           NaN                      NaN         Opposition        4.0
# 10          NaN                      NaN         Opposition        2.0
#
#     couleurAssociee
# 0           #77AA79
# 1           #E42313
# 2           #DF84B5
# 3           #991414
# 4           #CE5215
# 5           #32B3CA
# 6           #61468F
# 7           #F8D434
# 8           #8D949A
# 9           #4565AD
# 10          #35495E
#
# [11 rows x 23 columns]

# %%
(
    covotes[organes_pca.libelle].loc[organes_pca.libelle]
    .style
        .background_gradient(
            cmap='PiYG',
        )
)
# Out:
# <style type="text/css">
# #T_7caf5_row0_col0, #T_7caf5_row1_col1, #T_7caf5_row2_col2, #T_7caf5_row3_col3, #T_7caf5_row4_col4, #T_7caf5_row5_col5, #T_7caf5_row6_col6, #T_7caf5_row7_col7, #T_7caf5_row8_col8, #T_7caf5_row9_col9, #T_7caf5_row10_col10 {
#   background-color: #276419;
#   color: #f1f1f1;
# }
# #T_7caf5_row0_col1 {
#   background-color: #a1d26a;
#   color: #000000;
# }
# #T_7caf5_row0_col2 {
#   background-color: #bde38d;
#   color: #000000;
# }
# #T_7caf5_row0_col3 {
#   background-color: #d4edb3;
#   color: #000000;
# }
# #T_7caf5_row0_col4, #T_7caf5_row3_col8, #T_7caf5_row3_col10 {
#   background-color: #c01879;
#   color: #f1f1f1;
# }
# #T_7caf5_row0_col5, #T_7caf5_row9_col3, #T_7caf5_row10_col0 {
#   background-color: #bd1777;
#   color: #f1f1f1;
# }
# #T_7caf5_row0_col6, #T_7caf5_row2_col10, #T_7caf5_row10_col4 {
#   background-color: #c2197a;
#   color: #f1f1f1;
# }
# #T_7caf5_row0_col7, #T_7caf5_row7_col10, #T_7caf5_row10_col1 {
#   background-color: #d75ea1;
#   color: #f1f1f1;
# }
# #T_7caf5_row0_col8, #T_7caf5_row0_col9 {
#   background-color: #9b075c;
#   color: #f1f1f1;
# }
# #T_7caf5_row0_col10, #T_7caf5_row8_col1, #T_7caf5_row10_col2 {
#   background-color: #b51370;
#   color: #f1f1f1;
# }
# #T_7caf5_row1_col0 {
#   background-color: #aeda7a;
#   color: #000000;
# }
# #T_7caf5_row1_col2, #T_7caf5_row3_col1 {
#   background-color: #ddf1c1;
#   color: #000000;
# }
# #T_7caf5_row1_col3 {
#   background-color: #dff2c4;
#   color: #000000;
# }
# #T_7caf5_row1_col4, #T_7caf5_row1_col5, #T_7caf5_row1_col6, #T_7caf5_row1_col8, #T_7caf5_row1_col9, #T_7caf5_row3_col4, #T_7caf5_row5_col0, #T_7caf5_row5_col1, #T_7caf5_row5_col2, #T_7caf5_row5_col7, #T_7caf5_row5_col10, #T_7caf5_row6_col3, #T_7caf5_row6_col7, #T_7caf5_row6_col10, #T_7caf5_row8_col2, #T_7caf5_row9_col0 {
#   background-color: #8e0152;
#   color: #f1f1f1;
# }
# #T_7caf5_row1_col7 {
#   background-color: #c62080;
#   color: #f1f1f1;
# }
# #T_7caf5_row1_col10, #T_7caf5_row8_col7 {
#   background-color: #b91574;
#   color: #f1f1f1;
# }
# #T_7caf5_row2_col0 {
#   background-color: #b7e085;
#   color: #000000;
# }
# #T_7caf5_row2_col1 {
#   background-color: #c7e89f;
#   color: #000000;
# }
# #T_7caf5_row2_col3 {
#   background-color: #e9f5d6;
#   color: #000000;
# }
# #T_7caf5_row2_col4, #T_7caf5_row2_col5, #T_7caf5_row2_col6 {
#   background-color: #cb3289;
#   color: #f1f1f1;
# }
# #T_7caf5_row2_col7 {
#   background-color: #df79b0;
#   color: #f1f1f1;
# }
# #T_7caf5_row2_col8, #T_7caf5_row9_col7 {
#   background-color: #ac0f6a;
#   color: #f1f1f1;
# }
# #T_7caf5_row2_col9 {
#   background-color: #b71472;
#   color: #f1f1f1;
# }
# #T_7caf5_row3_col0 {
#   background-color: #e2f3ca;
#   color: #000000;
# }
# #T_7caf5_row3_col2 {
#   background-color: #f2f6ec;
#   color: #000000;
# }
# #T_7caf5_row3_col5, #T_7caf5_row4_col3, #T_7caf5_row4_col7 {
#   background-color: #940457;
#   color: #f1f1f1;
# }
# #T_7caf5_row3_col6, #T_7caf5_row5_col3, #T_7caf5_row6_col1, #T_7caf5_row6_col2, #T_7caf5_row8_col0 {
#   background-color: #900254;
#   color: #f1f1f1;
# }
# #T_7caf5_row3_col7, #T_7caf5_row10_col3 {
#   background-color: #d861a2;
#   color: #f1f1f1;
# }
# #T_7caf5_row3_col9 {
#   background-color: #9f095f;
#   color: #f1f1f1;
# }
# #T_7caf5_row4_col0, #T_7caf5_row4_col2 {
#   background-color: #99065a;
#   color: #f1f1f1;
# }
# #T_7caf5_row4_col1 {
#   background-color: #970559;
#   color: #f1f1f1;
# }
# #T_7caf5_row4_col5, #T_7caf5_row5_col6, #T_7caf5_row6_col5 {
#   background-color: #468a20;
#   color: #f1f1f1;
# }
# #T_7caf5_row4_col6, #T_7caf5_row6_col4 {
#   background-color: #37781c;
#   color: #f1f1f1;
# }
# #T_7caf5_row4_col8 {
#   background-color: #cf4191;
#   color: #f1f1f1;
# }
# #T_7caf5_row4_col9 {
#   background-color: #f9eef4;
#   color: #000000;
# }
# #T_7caf5_row4_col10, #T_7caf5_row6_col0, #T_7caf5_row9_col2 {
#   background-color: #920355;
#   color: #f1f1f1;
# }
# #T_7caf5_row5_col4 {
#   background-color: #488c20;
#   color: #f1f1f1;
# }
# #T_7caf5_row5_col8 {
#   background-color: #d5579d;
#   color: #f1f1f1;
# }
# #T_7caf5_row5_col9 {
#   background-color: #faecf3;
#   color: #000000;
# }
# #T_7caf5_row6_col8 {
#   background-color: #ca2f88;
#   color: #f1f1f1;
# }
# #T_7caf5_row6_col9 {
#   background-color: #faebf3;
#   color: #000000;
# }
# #T_7caf5_row7_col0 {
#   background-color: #efb0d6;
#   color: #000000;
# }
# #T_7caf5_row7_col1 {
#   background-color: #f1b7da;
#   color: #000000;
# }
# #T_7caf5_row7_col2 {
#   background-color: #f0b2d7;
#   color: #000000;
# }
# #T_7caf5_row7_col3 {
#   background-color: #f7cbe4;
#   color: #000000;
# }
# #T_7caf5_row7_col4, #T_7caf5_row7_col6 {
#   background-color: #e181b5;
#   color: #f1f1f1;
# }
# #T_7caf5_row7_col5 {
#   background-color: #e283b7;
#   color: #f1f1f1;
# }
# #T_7caf5_row7_col8, #T_7caf5_row8_col5 {
#   background-color: #e388ba;
#   color: #f1f1f1;
# }
# #T_7caf5_row7_col9 {
#   background-color: #e07eb3;
#   color: #f1f1f1;
# }
# #T_7caf5_row8_col3 {
#   background-color: #d14895;
#   color: #f1f1f1;
# }
# #T_7caf5_row8_col4 {
#   background-color: #db6ca8;
#   color: #f1f1f1;
# }
# #T_7caf5_row8_col6 {
#   background-color: #d965a4;
#   color: #f1f1f1;
# }
# #T_7caf5_row8_col9 {
#   background-color: #fbd9ec;
#   color: #000000;
# }
# #T_7caf5_row8_col10 {
#   background-color: #eda8d1;
#   color: #000000;
# }
# #T_7caf5_row9_col1 {
#   background-color: #b1116d;
#   color: #f1f1f1;
# }
# #T_7caf5_row9_col4, #T_7caf5_row9_col6 {
#   background-color: #f8f3f6;
#   color: #000000;
# }
# #T_7caf5_row9_col5 {
#   background-color: #f8f4f6;
#   color: #000000;
# }
# #T_7caf5_row9_col8 {
#   background-color: #fbd8eb;
#   color: #000000;
# }
# #T_7caf5_row9_col10 {
#   background-color: #f5c2e0;
#   color: #000000;
# }
# #T_7caf5_row10_col5, #T_7caf5_row10_col6 {
#   background-color: #c51d7e;
#   color: #f1f1f1;
# }
# #T_7caf5_row10_col7 {
#   background-color: #a80d66;
#   color: #f1f1f1;
# }
# #T_7caf5_row10_col8 {
#   background-color: #f2b8db;
#   color: #000000;
# }
# #T_7caf5_row10_col9 {
#   background-color: #f8cee6;
#   color: #000000;
# }
# </style>
# <table id="T_7caf5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >organe</th>
#       <th id="T_7caf5_level0_col0" class="col_heading level0 col0" >Écologiste - NUPES</th>
#       <th id="T_7caf5_level0_col1" class="col_heading level0 col1" >La France insoumise - Nouvelle Union Populaire écologique et sociale</th>
#       <th id="T_7caf5_level0_col2" class="col_heading level0 col2" >Socialistes et apparentés (membre de l’intergroupe NUPES)</th>
#       <th id="T_7caf5_level0_col3" class="col_heading level0 col3" >Gauche démocrate et républicaine - NUPES</th>
#       <th id="T_7caf5_level0_col4" class="col_heading level0 col4" >Démocrate (MoDem et Indépendants)</th>
#       <th id="T_7caf5_level0_col5" class="col_heading level0 col5" >Horizons et apparentés</th>
#       <th id="T_7caf5_level0_col6" class="col_heading level0 col6" >Renaissance</th>
#       <th id="T_7caf5_level0_col7" class="col_heading level0 col7" >Libertés, Indépendants, Outre-mer et Territoires</th>
#       <th id="T_7caf5_level0_col8" class="col_heading level0 col8" >Non inscrit</th>
#       <th id="T_7caf5_level0_col9" class="col_heading level0 col9" >Les Républicains</th>
#       <th id="T_7caf5_level0_col10" class="col_heading level0 col10" >Rassemblement National</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7caf5_level0_row0" class="row_heading level0 row0" >Écologiste - NUPES</th>
#       <td id="T_7caf5_row0_col0" class="data row0 col0" >1504</td>
#       <td id="T_7caf5_row0_col1" class="data row0 col1" >1200</td>
#       <td id="T_7caf5_row0_col2" class="data row0 col2" >1184</td>
#       <td id="T_7caf5_row0_col3" class="data row0 col3" >1085</td>
#       <td id="T_7caf5_row0_col4" class="data row0 col4" >457</td>
#       <td id="T_7caf5_row0_col5" class="data row0 col5" >436</td>
#       <td id="T_7caf5_row0_col6" class="data row0 col6" >447</td>
#       <td id="T_7caf5_row0_col7" class="data row0 col7" >747</td>
#       <td id="T_7caf5_row0_col8" class="data row0 col8" >440</td>
#       <td id="T_7caf5_row0_col9" class="data row0 col9" >435</td>
#       <td id="T_7caf5_row0_col10" class="data row0 col10" >529</td>
#     </tr>
#     <tr>
#       <th id="T_7caf5_level0_row1" class="row_heading level0 row1" >La France insoumise - Nouvelle Union Populaire écologique et sociale</th>
#       <td id="T_7caf5_row1_col0" class="data row1 col0" >1200</td>
#       <td id="T_7caf5_row1_col1"

# %%
covotes[organes_pca.libelle].loc[organes_pca.libelle].to_csv('out/covotes-organes.csv')

# %%
(
    covotes[organes_pca.libelle].loc[organes_pca.libelle]
    .div(
        len(alignements.index), axis=0
    )
    .replace(1, np.nan)
    .style
        .format('{:,.1%}'.format)
        .background_gradient(
            cmap='PiYG',
            # vmin=0,
            # vmax=1
            axis=1
        )
)
# Out:
# <style type="text/css">
# #T_762e8_row0_col0, #T_762e8_row1_col1, #T_762e8_row2_col2, #T_762e8_row3_col3, #T_762e8_row4_col4, #T_762e8_row5_col5, #T_762e8_row6_col6, #T_762e8_row7_col7, #T_762e8_row8_col8, #T_762e8_row9_col9, #T_762e8_row10_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_762e8_row0_col1, #T_762e8_row1_col0, #T_762e8_row2_col0, #T_762e8_row3_col0, #T_762e8_row4_col6, #T_762e8_row5_col4, #T_762e8_row5_col6, #T_762e8_row6_col4, #T_762e8_row7_col2, #T_762e8_row8_col9, #T_762e8_row9_col4, #T_762e8_row10_col9 {
#   background-color: #276419;
#   color: #f1f1f1;
# }
# #T_762e8_row0_col2, #T_762e8_row9_col6 {
#   background-color: #2e6d1b;
#   color: #f1f1f1;
# }
# #T_762e8_row0_col3, #T_762e8_row10_col8 {
#   background-color: #66a731;
#   color: #f1f1f1;
# }
# #T_762e8_row0_col4, #T_762e8_row2_col4 {
#   background-color: #9d085e;
#   color: #f1f1f1;
# }
# #T_762e8_row0_col5, #T_762e8_row0_col9, #T_762e8_row1_col5, #T_762e8_row2_col8, #T_762e8_row3_col6, #T_762e8_row4_col1, #T_762e8_row4_col3, #T_762e8_row5_col1, #T_762e8_row6_col1, #T_762e8_row7_col5, #T_762e8_row8_col1, #T_762e8_row9_col1, #T_762e8_row10_col5 {
#   background-color: #8e0152;
#   color: #f1f1f1;
# }
# #T_762e8_row0_col6, #T_762e8_row2_col9, #T_762e8_row5_col3 {
#   background-color: #970559;
#   color: #f1f1f1;
# }
# #T_762e8_row0_col7, #T_762e8_row1_col7 {
#   background-color: #fde2f0;
#   color: #000000;
# }
# #T_762e8_row0_col8, #T_762e8_row1_col6, #T_762e8_row2_col5, #T_762e8_row2_col6, #T_762e8_row6_col3, #T_762e8_row7_col6 {
#   background-color: #900254;
#   color: #f1f1f1;
# }
# #T_762e8_row0_col10 {
#   background-color: #ca2f88;
#   color: #f1f1f1;
# }
# #T_762e8_row1_col2, #T_762e8_row2_col1 {
#   background-color: #4c9121;
#   color: #f1f1f1;
# }
# #T_762e8_row1_col3, #T_762e8_row7_col0, #T_762e8_row9_col8 {
#   background-color: #6bac34;
#   color: #f1f1f1;
# }
# #T_762e8_row1_col4 {
#   background-color: #9b075c;
#   color: #f1f1f1;
# }
# #T_762e8_row1_col8, #T_762e8_row4_col0 {
#   background-color: #c2197a;
#   color: #f1f1f1;
# }
# #T_762e8_row1_col9 {
#   background-color: #bd1777;
#   color: #f1f1f1;
# }
# #T_762e8_row1_col10 {
#   background-color: #e58dbe;
#   color: #f1f1f1;
# }
# #T_762e8_row2_col3 {
#   background-color: #91c857;
#   color: #000000;
# }
# #T_762e8_row2_col7 {
#   background-color: #fce5f1;
#   color: #000000;
# }
# #T_762e8_row2_col10, #T_762e8_row6_col10 {
#   background-color: #c62080;
#   color: #f1f1f1;
# }
# #T_762e8_row3_col1 {
#   background-color: #34741c;
#   color: #f1f1f1;
# }
# #T_762e8_row3_col2 {
#   background-color: #488c20;
#   color: #f1f1f1;
# }
# #T_762e8_row3_col4 {
#   background-color: #99065a;
#   color: #f1f1f1;
# }
# #T_762e8_row3_col5, #T_762e8_row10_col6 {
#   background-color: #920355;
#   color: #f1f1f1;
# }
# #T_762e8_row3_col7 {
#   background-color: #eff6e4;
#   color: #000000;
# }
# #T_762e8_row3_col8 {
#   background-color: #e48bbc;
#   color: #f1f1f1;
# }
# #T_762e8_row3_col9 {
#   background-color: #cd3a8d;
#   color: #f1f1f1;
# }
# #T_762e8_row3_col10, #T_762e8_row10_col3 {
#   background-color: #eca6cf;
#   color: #000000;
# }
# #T_762e8_row4_col2, #T_762e8_row6_col2 {
#   background-color: #cc368b;
#   color: #f1f1f1;
# }
# #T_762e8_row4_col5, #T_762e8_row6_col5 {
#   background-color: #36761c;
#   color: #f1f1f1;
# }
# #T_762e8_row4_col7, #T_762e8_row6_col7 {
#   background-color: #e388ba;
#   color: #f1f1f1;
# }
# #T_762e8_row4_col8 {
#   background-color: #dd73ac;
#   color: #f1f1f1;
# }
# #T_762e8_row4_col9, #T_762e8_row6_col9 {
#   background-color: #f6f7f5;
#   color: #000000;
# }
# #T_762e8_row4_col10, #T_762e8_row5_col0, #T_762e8_row6_col0 {
#   background-color: #c41a7c;
#   color: #f1f1f1;
# }
# #T_762e8_row5_col2 {
#   background-color: #ce3d8f;
#   color: #f1f1f1;
# }
# #T_762e8_row5_col7, #T_762e8_row10_col1 {
#   background-color: #e590bf;
#   color: #f1f1f1;
# }
# #T_762e8_row5_col8 {
#   background-color: #e795c3;
#   color: #000000;
# }
# #T_762e8_row5_col9 {
#   background-color: #f1f6ea;
#   color: #000000;
# }
# #T_762e8_row5_col10 {
#   background-color: #c72482;
#   color: #f1f1f1;
# }
# #T_762e8_row6_col8 {
#   background-color: #db6ca8;
#   color: #f1f1f1;
# }
# #T_762e8_row7_col1 {
#   background-color: #f5f7f2;
#   color: #000000;
# }
# #T_762e8_row7_col3 {
#   background-color: #64a52f;
#   color: #f1f1f1;
# }
# #T_762e8_row7_col4, #T_762e8_row9_col3 {
#   background-color: #b3126f;
#   color: #f1f1f1;
# }
# #T_762e8_row7_col8 {
#   background-color: #fddeee;
#   color: #000000;
# }
# #T_762e8_row7_col9 {
#   background-color: #eda8d1;
#   color: #000000;
# }
# #T_762e8_row7_col10, #T_762e8_row8_col3 {
#   background-color: #e692c1;
#   color: #000000;
# }
# #T_762e8_row8_col0 {
#   background-color: #b1116d;
#   color: #f1f1f1;
# }
# #T_762e8_row8_col2 {
#   background-color: #d14895;
#   color: #f1f1f1;
# }
# #T_762e8_row8_col4 {
#   background-color: #fad6ea;
#   color: #000000;
# }
# #T_762e8_row8_col5 {
#   background-color: #faeaf2;
#   color: #000000;
# }
# #T_762e8_row8_col6 {
#   background-color: #f4c1df;
#   color: #000000;
# }
# #T_762e8_row8_col7 {
#   background-color: #e4f4cd;
#   color: #000000;
# }
# #T_762e8_row8_col10 {
#   background-color: #7dba40;
#   color: #f1f1f1;
# }
# #T_762e8_row9_col0 {
#   background-color: #ac0f6a;
#   color: #f1f1f1;
# }
# #T_762e8_row9_col2 {
#   background-color: #d4539b;
#   color: #f1f1f1;
# }
# #T_762e8_row9_col5 {
#   background-color: #2d6b1a;
#   color: #f1f1f1;
# }
# #T_762e8_row9_col7 {
#   background-color: #f9eff4;
#   color: #000000;
# }
# #T_762e8_row9_col10 {
#   background-color: #88c24c;
#   color: #000000;
# }
# #T_762e8_row10_col0 {
#   background-color: #e283b7;
#   color: #f1f1f1;
# }
# #T_762e8_row10_col2 {
#   background-color: #eeadd4;
#   color: #000000;
# }
# #T_762e8_row10_col4 {
#   background-color: #9f095f;
#   color: #f1f1f1;
# }
# #T_762e8_row10_col7 {
#   background-color: #f3f6ed;
#   color: #000000;
# }
# </style>
# <table id="T_762e8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >organe</th>
#       <th id="T_762e8_level0_col0" class="col_heading level0 col0" >Écologiste - NUPES</th>
#       <th id="T_762e8_level0_col1" class="col_heading level0 col1" >La France insoumise - Nouvelle Union Populaire écologique et sociale</th>
#       <th id="T_762e8_level0_col2" class="col_heading level0 col2" >Socialistes et apparentés (membre de l’intergroupe NUPES)</th>
#       <th id="T_762e8_level0_col3" class="col_heading level0 col3" >Gauche démocrate et républicaine - NUPES</th>
#       <th id="T_762e8_level0_col4" class="col_heading level0 col4" >Démocrate (MoDem et Indépendants)</th>
#       <th id="T_762e8_level0_col5" class="col_heading level0 col5" >Horizons et apparentés</th>
#       <th id="T_762e8_level0_col6" class="col_heading level0 col6" >Renaissance</th>
#       <th id="T_762e8_level0_col7" class="col_heading level0 col7" >Libertés, Indépendants, Outre-mer et Territoires</th>
#       <th id="T_762e8_level0_col8" class="col_heading level0 col8" >Non inscrit</th>
#       <th id="T_762e8_level0_col9" class="col_heading level0 col9" >Les Républicains</th>
#       <th id="T_762e8_level0_col10" class="col_heading level0 col10" >Rassemblement National</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_762e8_level0_row0" class="row_heading level0 row0" >Écologiste - NUPES</th>
#       <td id="T_762e8_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_762e8_row0_col1" class="data row0 col1" >79.8%</td>
#       <td id="T_762e8_row0_col2" class="data row0 col2" >78.7%</td>
#       <td id="T_762e8_row0_col3" class="data row0 col3" >72.1%</td>
#       <td id="T_762e8_row0_col4" class="data row0 col4" >30.4%</td>
#       <td id="T_762e8_row0_col5" class="data row0 col5" >29.0%</td>
#       <td id="T_762e8_row0_col6" class="data row0 col6" >29.7%</td>
#       <td id="T_762e8_row0_col7" class="data row0 col7" >49.7%</td>
#       <td id="T_762e8_row0_col8" class="data row0 col8" >29.3%</td>
#       <td id="T_762e8_row0_col9" class="data row0 col9" >28.9%</td>
#       <td id="T_762e8_row0_col10" class="data row0 col10" >35.2%</td>
#     </tr>
#     <tr>
#       <th id="T_762e8_level0_row1" class="row_heading level0 row1" >La France insoumise - Nouvelle Union Populaire écologique et sociale</th>
#       <td id="T_762e8_row1_col0" class="data row1 col0" >79.8%</td>
#       <td id="T_762e8_row1_col1" class="data row1 col1" >nan%</td>
#       <td id="T_762e8_row1_col2" class="data ro
