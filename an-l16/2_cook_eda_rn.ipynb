# %%
import pandas as pd

# %%
organes = pd.read_csv('out/organes.csv')
acteurs = pd.read_csv('out/acteurs.csv')
amendements = pd.read_csv("out/amendements.csv")
reunions = pd.read_csv('out/reunions.csv')
interventions = pd.read_csv('out/interventions.csv')
scrutins = pd.read_csv('out/scrutins.csv')
votes = pd.read_csv('out/votes.csv')

# %%
reunions = (
    reunions
    .set_index('uid')
)

# %%
scrutins = (
    scrutins
    .assign(
        identiques = lambda df: df.objet.str.contains('identique'),
        amendement = lambda df: df.objet.str.contains('amendement'),
        sous_amendement = lambda df: df.objet.str.contains('sous-amendement')
    )
    .join(reunions[['cr']], on='seance')
    .assign(
        url_scrutin = lambda df: df.uid.apply(lambda id: f'https://www2.assemblee-nationale.fr/scrutins/detail/(legislature)/16/(num)/{id.replace("VTANR5L16V", "")}'),
        url_seance = lambda df: df.cr.apply(lambda id: f'https://www.assemblee-nationale.fr/dyn/16/comptes-rendus/seance/{id}'),
    )
)

scrutins
# Out:
#                  uid                                              objet  \
# 0     VTANR5L16V1709  l'article 10 du projet de loi relatif à la pro...
# 1      VTANR5L16V703  l'amendement n° 1419 (rect.) de M. Jumel à l'a...
# 2     VTANR5L16V1359  l'amendement n° 93 de Mme Engrand à l'article ...
# 3      VTANR5L16V353  la première partie du projet de loi de finance...
# 4      VTANR5L16V646  l'amendement n° 124 de M. Chenu après l'articl...
# ...              ...                                                ...
# 1853   VTANR5L16V844  l'article premier de la proposition de loi vis...
# 1854   VTANR5L16V901  l'amendement n° 8 de M. Bovet à l'article prem...
# 1855  VTANR5L16V1008  l'amendement n° 3606 de Mme Amiot et les amend...
# 1856  VTANR5L16V1458  l'amendement n° 9 de Mme Paris à l'article pre...
# 1857   VTANR5L16V452  l'amendement n° 1438 de Mme Le Pen à l'article...
#
#                           type        date                  seance    sort  \
# 0     scrutin public ordinaire  2023-05-30  RUANR5L16S2023IDS27081  adopté
# 1     scrutin public ordinaire  2022-12-08  RUANR5L16S2023IDS26604  rejeté
# 2     scrutin public ordinaire  2023-03-30  RUANR5L16S2023IDS26945  rejeté
# 3     scrutin public ordinaire  2022-10-20  RUANR5L16S2023IDS26405  rejeté
# 4     scrutin public ordinaire  2022-11-29  RUANR5L16S2023IDS26560  rejeté
# ...                        ...         ...                     ...     ...
# 1853  scrutin public ordinaire  2023-01-18  RUANR5L16S2023IDS26691  adopté
# 1854  scrutin public ordinaire  2023-01-31  RUANR5L16S2023IDS26758  rejeté
# 1855  scrutin public ordinaire  2023-02-16  RUANR5L16S2023IDS26797  rejeté
# 1856  scrutin public ordinaire  2023-05-04  RUANR5L16S2023IDS27022  rejeté
# 1857  scrutin public ordinaire  2022-10-28  RUANR5L16S2023IDS26422  rejeté
#
#       identiques  amendement  sous_amendement                     cr  \
# 0          False       False            False  CRSANR5L16S2023O1N252
# 1          False        True            False  CRSANR5L16S2023O1N090
# 2          False        True            False  CRSANR5L16S2023O1N199
# 3          False       False            False  CRSANR5L16S2023O1N028
# 4          False        True            False  CRSANR5L16S2023O1N074
# ...          ...         ...              ...                    ...
# 1853       False       False            False  CRSANR5L16S2023O1N121
# 1854       False        True            False  CRSANR5L16S2023O1N129
# 1855        True        True            False  CRSANR5L16S2023O1N151
# 1856       False        True            False  CRSANR5L16S2023O1N222
# 1857       False        True            False  CRSANR5L16S2023O1N040
#
#                                             url_scrutin  \
# 0     https://www2.assemblee-nationale.fr/scrutins/d...
# 1     https://www2.assemblee-nationale.fr/scrutins/d...
# 2     https://www2.assemblee-nationale.fr/scrutins/d...
# 3     https://www2.assemblee-nationale.fr/scrutins/d...
# 4     https://www2.assemblee-nationale.fr/scrutins/d...
# ...                                                 ...
# 1853  https://www2.assemblee-nationale.fr/scrutins/d...
# 1854  https://www2.assemblee-nationale.fr/scrutins/d...
# 1855  https://www2.assemblee-nationale.fr/scrutins/d...
# 1856  https://www2.assemblee-nationale.fr/scrutins/d...
# 1857  https://www2.assemblee-nationale.fr/scrutins/d...
#
#                                              url_seance
# 0     https://www.assemblee-nationale.fr/dyn/16/comp...
# 1     https://www.assemblee-nationale.fr/dyn/16/comp...
# 2     https://www.assemblee-nationale.fr/dyn/16/comp...
# 3     https://www.assemblee-nationale.fr/dyn/16/comp...
# 4     https://www.assemblee-nationale.fr/dyn/16/comp...
# ...                                                 ...
# 1853  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1854  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1855  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1856  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1857  https://www.assemblee-nationale.fr/dyn/16/comp...
#
# [1858 rows x 12 columns]

# %%
groupe = (
    organes
    .query('libelleAbrev == "RN" and codeType ==  "GP"')
)

groupe.uid
# Out:
# 236    PO800520
# Name: uid, dtype: object

# %%
deputes = (
    votes
    .query('organe == @groupe.uid.iloc[0]')
    .groupby('acteurRef')
    .agg({
        'scrutin': 'count'
    })
    .join(acteurs.set_index('uid'))
    .sort_values('scrutin', ascending=False)
    .dropna(subset=['nom'])
)

deputes
# Out:
#            scrutin       nom     prenom  civ
# acteurRef
# PA793166      1311  Dessigny    Jocelyn   M.
# PA794638      1293   Catteau     Victor   M.
# PA795900      1290   Hamelet     Marine  Mme
# PA794954      1229    Salmon     Emeric   M.
# PA793928      1220      Diaz     Edwige  Mme
# ...            ...       ...        ...  ...
# PA794354       380   Laporte     Hélène  Mme
# PA720468       376     Chenu  Sébastien   M.
# PA796110       327   Hébrard      Joris   M.
# PA794030       291     Jolly     Alexis   M.
# PA796114         4    Jaouen  Catherine  Mme
#
# [90 rows x 4 columns]

# %%
scrutins
# Out:
#                  uid                                              objet  \
# 0     VTANR5L16V1709  l'article 10 du projet de loi relatif à la pro...
# 1      VTANR5L16V703  l'amendement n° 1419 (rect.) de M. Jumel à l'a...
# 2     VTANR5L16V1359  l'amendement n° 93 de Mme Engrand à l'article ...
# 3      VTANR5L16V353  la première partie du projet de loi de finance...
# 4      VTANR5L16V646  l'amendement n° 124 de M. Chenu après l'articl...
# ...              ...                                                ...
# 1853   VTANR5L16V844  l'article premier de la proposition de loi vis...
# 1854   VTANR5L16V901  l'amendement n° 8 de M. Bovet à l'article prem...
# 1855  VTANR5L16V1008  l'amendement n° 3606 de Mme Amiot et les amend...
# 1856  VTANR5L16V1458  l'amendement n° 9 de Mme Paris à l'article pre...
# 1857   VTANR5L16V452  l'amendement n° 1438 de Mme Le Pen à l'article...
#
#                           type        date                  seance    sort  \
# 0     scrutin public ordinaire  2023-05-30  RUANR5L16S2023IDS27081  adopté
# 1     scrutin public ordinaire  2022-12-08  RUANR5L16S2023IDS26604  rejeté
# 2     scrutin public ordinaire  2023-03-30  RUANR5L16S2023IDS26945  rejeté
# 3     scrutin public ordinaire  2022-10-20  RUANR5L16S2023IDS26405  rejeté
# 4     scrutin public ordinaire  2022-11-29  RUANR5L16S2023IDS26560  rejeté
# ...                        ...         ...                     ...     ...
# 1853  scrutin public ordinaire  2023-01-18  RUANR5L16S2023IDS26691  adopté
# 1854  scrutin public ordinaire  2023-01-31  RUANR5L16S2023IDS26758  rejeté
# 1855  scrutin public ordinaire  2023-02-16  RUANR5L16S2023IDS26797  rejeté
# 1856  scrutin public ordinaire  2023-05-04  RUANR5L16S2023IDS27022  rejeté
# 1857  scrutin public ordinaire  2022-10-28  RUANR5L16S2023IDS26422  rejeté
#
#       identiques  amendement  sous_amendement                     cr  \
# 0          False       False            False  CRSANR5L16S2023O1N252
# 1          False        True            False  CRSANR5L16S2023O1N090
# 2          False        True            False  CRSANR5L16S2023O1N199
# 3          False       False            False  CRSANR5L16S2023O1N028
# 4          False        True            False  CRSANR5L16S2023O1N074
# ...          ...         ...              ...                    ...
# 1853       False       False            False  CRSANR5L16S2023O1N121
# 1854       False        True            False  CRSANR5L16S2023O1N129
# 1855        True        True            False  CRSANR5L16S2023O1N151
# 1856       False        True            False  CRSANR5L16S2023O1N222
# 1857       False        True            False  CRSANR5L16S2023O1N040
#
#                                             url_scrutin  \
# 0     https://www2.assemblee-nationale.fr/scrutins/d...
# 1     https://www2.assemblee-nationale.fr/scrutins/d...
# 2     https://www2.assemblee-nationale.fr/scrutins/d...
# 3     https://www2.assemblee-nationale.fr/scrutins/d...
# 4     https://www2.assemblee-nationale.fr/scrutins/d...
# ...                                                 ...
# 1853  https://www2.assemblee-nationale.fr/scrutins/d...
# 1854  https://www2.assemblee-nationale.fr/scrutins/d...
# 1855  https://www2.assemblee-nationale.fr/scrutins/d...
# 1856  https://www2.assemblee-nationale.fr/scrutins/d...
# 1857  https://www2.assemblee-nationale.fr/scrutins/d...
#
#                                              url_seance
# 0     https://www.assemblee-nationale.fr/dyn/16/comp...
# 1     https://www.assemblee-nationale.fr/dyn/16/comp...
# 2     https://www.assemblee-nationale.fr/dyn/16/comp...
# 3     https://www.assemblee-nationale.fr/dyn/16/comp...
# 4     https://www.assemblee-nationale.fr/dyn/16/comp...
# ...                                                 ...
# 1853  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1854  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1855  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1856  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1857  https://www.assemblee-nationale.fr/dyn/16/comp...
#
# [1858 rows x 12 columns]

# %%
scrutins_uniques_rn = (
    scrutins
    .query('~identiques')
    .query('objet.str.contains("|".join(@deputes.nom))')
)

scrutins_uniques_rn
# Out:
#                  uid                                              objet  \
# 2     VTANR5L16V1359  l'amendement n° 93 de Mme Engrand à l'article ...
# 4      VTANR5L16V646  l'amendement n° 124 de M. Chenu après l'articl...
# 8     VTANR5L16V1135  l'amendement n° 95 de Mme Loir après l'article...
# 16     VTANR5L16V754  l'amendement n° 209 de Mme Alexandra Masson à ...
# 24    VTANR5L16V1498  l'amendement n° 70 de Mme Parmentier après l'a...
# ...              ...                                                ...
# 1847  VTANR5L16V1634  l'amendement n° 541 de Mme Colombier à l'artic...
# 1851    VTANR5L16V30  l'amendement n° 682 de M. Catteau à l'article ...
# 1854   VTANR5L16V901  l'amendement n° 8 de M. Bovet à l'article prem...
# 1856  VTANR5L16V1458  l'amendement n° 9 de Mme Paris à l'article pre...
# 1857   VTANR5L16V452  l'amendement n° 1438 de Mme Le Pen à l'article...
#
#                           type        date                  seance    sort  \
# 2     scrutin public ordinaire  2023-03-30  RUANR5L16S2023IDS26945  rejeté
# 4     scrutin public ordinaire  2022-11-29  RUANR5L16S2023IDS26560  rejeté
# 8     scrutin public ordinaire  2023-03-07  RUANR5L16S2023IDS26860  rejeté
# 16    scrutin public ordinaire  2022-12-12  RUANR5L16S2023IDS26617  rejeté
# 24    scrutin public ordinaire  2023-05-10  RUANR5L16S2023IDS27040  rejeté
# ...                        ...         ...                     ...     ...
# 1847  scrutin public ordinaire  2023-05-25  RUANR5L16S2023IDS27075  rejeté
# 1851  scrutin public ordinaire  2022-07-19  RUANR5L16S2022IDS26206  rejeté
# 1854  scrutin public ordinaire  2023-01-31  RUANR5L16S2023IDS26758  rejeté
# 1856  scrutin public ordinaire  2023-05-04  RUANR5L16S2023IDS27022  rejeté
# 1857  scrutin public ordinaire  2022-10-28  RUANR5L16S2023IDS26422  rejeté
#
#       identiques  amendement  sous_amendement                     cr  \
# 2          False        True            False  CRSANR5L16S2023O1N199
# 4          False        True            False  CRSANR5L16S2023O1N074
# 8          False        True            False  CRSANR5L16S2023O1N170
# 16         False        True            False  CRSANR5L16S2023O1N096
# 24         False        True            False  CRSANR5L16S2023O1N230
# ...          ...         ...              ...                    ...
# 1847       False        True            False  CRSANR5L16S2023O1N246
# 1851       False        True            False  CRSANR5L16S2022E1N009
# 1854       False        True            False  CRSANR5L16S2023O1N129
# 1856       False        True            False  CRSANR5L16S2023O1N222
# 1857       False        True            False  CRSANR5L16S2023O1N040
#
#                                             url_scrutin  \
# 2     https://www2.assemblee-nationale.fr/scrutins/d...
# 4     https://www2.assemblee-nationale.fr/scrutins/d...
# 8     https://www2.assemblee-nationale.fr/scrutins/d...
# 16    https://www2.assemblee-nationale.fr/scrutins/d...
# 24    https://www2.assemblee-nationale.fr/scrutins/d...
# ...                                                 ...
# 1847  https://www2.assemblee-nationale.fr/scrutins/d...
# 1851  https://www2.assemblee-nationale.fr/scrutins/d...
# 1854  https://www2.assemblee-nationale.fr/scrutins/d...
# 1856  https://www2.assemblee-nationale.fr/scrutins/d...
# 1857  https://www2.assemblee-nationale.fr/scrutins/d...
#
#                                              url_seance
# 2     https://www.assemblee-nationale.fr/dyn/16/comp...
# 4     https://www.assemblee-nationale.fr/dyn/16/comp...
# 8     https://www.assemblee-nationale.fr/dyn/16/comp...
# 16    https://www.assemblee-nationale.fr/dyn/16/comp...
# 24    https://www.assemblee-nationale.fr/dyn/16/comp...
# ...                                                 ...
# 1847  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1851  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1854  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1856  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1857  https://www.assemblee-nationale.fr/dyn/16/comp...
#
# [280 rows x 12 columns]

# %%
scrutins_uniques_rn_amd = (
    scrutins
    .query('~identiques')
    .query('~sous_amendement')
    .query('objet.str.contains("|".join(@deputes.nom))')
)

scrutins_uniques_rn_amd
# Out:
#                  uid                                              objet  \
# 2     VTANR5L16V1359  l'amendement n° 93 de Mme Engrand à l'article ...
# 4      VTANR5L16V646  l'amendement n° 124 de M. Chenu après l'articl...
# 8     VTANR5L16V1135  l'amendement n° 95 de Mme Loir après l'article...
# 16     VTANR5L16V754  l'amendement n° 209 de Mme Alexandra Masson à ...
# 24    VTANR5L16V1498  l'amendement n° 70 de Mme Parmentier après l'a...
# ...              ...                                                ...
# 1847  VTANR5L16V1634  l'amendement n° 541 de Mme Colombier à l'artic...
# 1851    VTANR5L16V30  l'amendement n° 682 de M. Catteau à l'article ...
# 1854   VTANR5L16V901  l'amendement n° 8 de M. Bovet à l'article prem...
# 1856  VTANR5L16V1458  l'amendement n° 9 de Mme Paris à l'article pre...
# 1857   VTANR5L16V452  l'amendement n° 1438 de Mme Le Pen à l'article...
#
#                           type        date                  seance    sort  \
# 2     scrutin public ordinaire  2023-03-30  RUANR5L16S2023IDS26945  rejeté
# 4     scrutin public ordinaire  2022-11-29  RUANR5L16S2023IDS26560  rejeté
# 8     scrutin public ordinaire  2023-03-07  RUANR5L16S2023IDS26860  rejeté
# 16    scrutin public ordinaire  2022-12-12  RUANR5L16S2023IDS26617  rejeté
# 24    scrutin public ordinaire  2023-05-10  RUANR5L16S2023IDS27040  rejeté
# ...                        ...         ...                     ...     ...
# 1847  scrutin public ordinaire  2023-05-25  RUANR5L16S2023IDS27075  rejeté
# 1851  scrutin public ordinaire  2022-07-19  RUANR5L16S2022IDS26206  rejeté
# 1854  scrutin public ordinaire  2023-01-31  RUANR5L16S2023IDS26758  rejeté
# 1856  scrutin public ordinaire  2023-05-04  RUANR5L16S2023IDS27022  rejeté
# 1857  scrutin public ordinaire  2022-10-28  RUANR5L16S2023IDS26422  rejeté
#
#       identiques  amendement  sous_amendement                     cr  \
# 2          False        True            False  CRSANR5L16S2023O1N199
# 4          False        True            False  CRSANR5L16S2023O1N074
# 8          False        True            False  CRSANR5L16S2023O1N170
# 16         False        True            False  CRSANR5L16S2023O1N096
# 24         False        True            False  CRSANR5L16S2023O1N230
# ...          ...         ...              ...                    ...
# 1847       False        True            False  CRSANR5L16S2023O1N246
# 1851       False        True            False  CRSANR5L16S2022E1N009
# 1854       False        True            False  CRSANR5L16S2023O1N129
# 1856       False        True            False  CRSANR5L16S2023O1N222
# 1857       False        True            False  CRSANR5L16S2023O1N040
#
#                                             url_scrutin  \
# 2     https://www2.assemblee-nationale.fr/scrutins/d...
# 4     https://www2.assemblee-nationale.fr/scrutins/d...
# 8     https://www2.assemblee-nationale.fr/scrutins/d...
# 16    https://www2.assemblee-nationale.fr/scrutins/d...
# 24    https://www2.assemblee-nationale.fr/scrutins/d...
# ...                                                 ...
# 1847  https://www2.assemblee-nationale.fr/scrutins/d...
# 1851  https://www2.assemblee-nationale.fr/scrutins/d...
# 1854  https://www2.assemblee-nationale.fr/scrutins/d...
# 1856  https://www2.assemblee-nationale.fr/scrutins/d...
# 1857  https://www2.assemblee-nationale.fr/scrutins/d...
#
#                                              url_seance
# 2     https://www.assemblee-nationale.fr/dyn/16/comp...
# 4     https://www.assemblee-nationale.fr/dyn/16/comp...
# 8     https://www.assemblee-nationale.fr/dyn/16/comp...
# 16    https://www.assemblee-nationale.fr/dyn/16/comp...
# 24    https://www.assemblee-nationale.fr/dyn/16/comp...
# ...                                                 ...
# 1847  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1851  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1854  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1856  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1857  https://www.assemblee-nationale.fr/dyn/16/comp...
#
# [269 rows x 12 columns]

# %%
scrutins_uniques_rn.to_csv('out/rn_amedements_uniques.csv', index=False)

# %%
scrutins_uniques_rn.sort.value_counts()
# Out:
# rejeté    276
# adopté      4
# Name: sort, dtype: int64

# %%
scrutins_uniques_rn.query('sort == "adopté"')
# Out:
#                  uid                                              objet  \
# 401   VTANR5L16V1270  l'amendement n° 757 de M. Lopez-Liguori à l'ar...
# 996   VTANR5L16V1594  l'amendement n° 1771 de M. Gonzalez à l'articl...
# 1059  VTANR5L16V1633  l'amendement n° 1605 de M. Blanchet à l'articl...
# 1515  VTANR5L16V1269  le sous-amendement n° 789 de M. Bothorel à l'a...
#
#                           type        date                  seance    sort  \
# 401   scrutin public ordinaire  2023-03-23  RUANR5L16S2023IDS26890  adopté
# 996   scrutin public ordinaire  2023-05-23  RUANR5L16S2023IDS27070  adopté
# 1059  scrutin public ordinaire  2023-05-25  RUANR5L16S2023IDS27075  adopté
# 1515  scrutin public ordinaire  2023-03-23  RUANR5L16S2023IDS26890  adopté
#
#       identiques  amendement  sous_amendement                     cr  \
# 401        False        True            False  CRSANR5L16S2023O1N188
# 996        False        True            False  CRSANR5L16S2023O1N241
# 1059       False        True            False  CRSANR5L16S2023O1N246
# 1515       False        True             True  CRSANR5L16S2023O1N188
#
#                                             url_scrutin  \
# 401   https://www2.assemblee-nationale.fr/scrutins/d...
# 996   https://www2.assemblee-nationale.fr/scrutins/d...
# 1059  https://www2.assemblee-nationale.fr/scrutins/d...
# 1515  https://www2.assemblee-nationale.fr/scrutins/d...
#
#                                              url_seance
# 401   https://www.assemblee-nationale.fr/dyn/16/comp...
# 996   https://www.assemblee-nationale.fr/dyn/16/comp...
# 1059  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1515  https://www.assemblee-nationale.fr/dyn/16/comp...

# %%
votes_rn_pour = (
    votes
    .query('scrutin.isin(@scrutins_uniques_rn.uid)')
    #.query('scrutin != "VTANR5L16V1269"')
    .query('organe != @groupe.uid.iloc[0]')
    .query('position == "pour"')
    .join(acteurs.set_index('uid'), on='acteurRef')
    .join(organes.set_index('uid')['libelleAbrev'], on='organe')
)

votes_rn_pour
# Out:
#        acteurRef mandatRef  parDelegation position    organe        date  \
# 597     PA718884  PM796218          False     pour  PO800508  2022-11-29
# 598     PA793508  PM796371          False     pour  PO800508  2022-11-29
# 654     PA719608  PM796593          False     pour  PO793087  2022-11-29
# 1417    PA330240  PM796155          False     pour  PO800508  2023-03-07
# 1418    PA606098  PM796449          False     pour  PO800508  2023-03-07
# ...          ...       ...            ...      ...       ...         ...
# 346666  PA720586  PM797088          False     pour  PO800508  2023-01-31
# 346667  PA267324  PM797538          False     pour  PO800508  2023-01-31
# 346668  PA719318  PM796470          False     pour  PO800508  2023-01-31
# 346669  PA794994  PM797232          False     pour  PO800508  2023-01-31
# 346681  PA721046  PM797769          False     pour  PO800532  2023-01-31
#
#                scrutin groupe_majorite            nom        prenom  civ  \
# 597      VTANR5L16V646      abstention  Bazin-Malgras       Valérie  Mme
# 598      VTANR5L16V646      abstention        Brigand        Hubert   M.
# 654      VTANR5L16V646            pour         Ménard    Emmanuelle  Mme
# 1417    VTANR5L16V1135            pour         Ciotti          Éric   M.
# 1418    VTANR5L16V1135            pour        Marleix       Olivier   M.
# ...                ...             ...            ...           ...  ...
# 346666   VTANR5L16V901            pour          Vatin        Pierre   M.
# 346667   VTANR5L16V901            pour       Gaultier  Jean-Jacques   M.
# 346668   VTANR5L16V901            pour       Anthoine    Emmanuelle  Mme
# 346669   VTANR5L16V901            pour        Portier     Alexandre   M.
# 346681   VTANR5L16V901            pour        Bassire      Nathalie  Mme
#
#        libelleAbrev
# 597              LR
# 598              LR
# 654              NI
# 1417             LR
# 1418             LR
# ...             ...
# 346666           LR
# 346667           LR
# 346668           LR
# 346669           LR
# 346681         LIOT
#
# [1192 rows x 12 columns]

# %%
(
    votes
    .query('scrutin.isin(@scrutins_uniques_rn.uid)')
    #.query('scrutin != "VTANR5L16V1269"')
    .query('organe != @groupe.uid.iloc[0]')
    .query('position == "pour"')
    .join(acteurs.set_index('uid'), on='acteurRef')
    .join(organes.set_index('uid')['libelleAbrev'], on='organe')
)
# Out:
#        acteurRef mandatRef  parDelegation position    organe        date  \
# 597     PA718884  PM796218          False     pour  PO800508  2022-11-29
# 598     PA793508  PM796371          False     pour  PO800508  2022-11-29
# 654     PA719608  PM796593          False     pour  PO793087  2022-11-29
# 1417    PA330240  PM796155          False     pour  PO800508  2023-03-07
# 1418    PA606098  PM796449          False     pour  PO800508  2023-03-07
# ...          ...       ...            ...      ...       ...         ...
# 346666  PA720586  PM797088          False     pour  PO800508  2023-01-31
# 346667  PA267324  PM797538          False     pour  PO800508  2023-01-31
# 346668  PA719318  PM796470          False     pour  PO800508  2023-01-31
# 346669  PA794994  PM797232          False     pour  PO800508  2023-01-31
# 346681  PA721046  PM797769          False     pour  PO800532  2023-01-31
#
#                scrutin groupe_majorite            nom        prenom  civ  \
# 597      VTANR5L16V646      abstention  Bazin-Malgras       Valérie  Mme
# 598      VTANR5L16V646      abstention        Brigand        Hubert   M.
# 654      VTANR5L16V646            pour         Ménard    Emmanuelle  Mme
# 1417    VTANR5L16V1135            pour         Ciotti          Éric   M.
# 1418    VTANR5L16V1135            pour        Marleix       Olivier   M.
# ...                ...             ...            ...           ...  ...
# 346666   VTANR5L16V901            pour          Vatin        Pierre   M.
# 346667   VTANR5L16V901            pour       Gaultier  Jean-Jacques   M.
# 346668   VTANR5L16V901            pour       Anthoine    Emmanuelle  Mme
# 346669   VTANR5L16V901            pour        Portier     Alexandre   M.
# 346681   VTANR5L16V901            pour        Bassire      Nathalie  Mme
#
#        libelleAbrev
# 597              LR
# 598              LR
# 654              NI
# 1417             LR
# 1418             LR
# ...             ...
# 346666           LR
# 346667           LR
# 346668           LR
# 346669           LR
# 346681         LIOT
#
# [1192 rows x 12 columns]

# %%
(
    votes_rn_pour
    .libelleAbrev
    .value_counts()
)
# Out:
# LR           590
# NI           166
# LIOT         120
# RE           108
# DEM           59
# SOC           46
# HOR           33
# GDR-NUPES     30
# ECOLO         24
# LFI-NUPES     16
# Name: libelleAbrev, dtype: int64

# %%
votes_rn_pour.to_csv('out/rn_amendements_pour.csv', index=False)

# %%
(
    votes
    .query('scrutin.isin(@scrutins_uniques_rn.uid)')
    .query('organe != @groupe.uid.iloc[0]')
    .join(acteurs.set_index('uid'), on='acteurRef')
    .join(organes.set_index('uid')['libelleAbrev'], on='organe')
    .pivot_table(
        index='libelleAbrev',
        columns='position',
        values='acteurRef',
        aggfunc='count'
    )
)
# Out:
# position      abstention  contre  pour
# libelleAbrev
# DEM                   26    3992    59
# ECOLO                100    1134    24
# GDR-NUPES             86     350    30
# HOR                   24    2106    33
# LFI-NUPES            296    2159    16
# LIOT                 130     316   120
# LR                   424     822   590
# NI                    40      59   166
# RE                    17   15808   108
# SOC                   67     913    46

# %%
deputes_decomptes = (
    votes_rn_pour
    .groupby('acteurRef')
    .agg({
        'scrutin': 'count',
        'nom': 'first',
        'libelleAbrev': 'first'
    })
    .sort_values('scrutin', ascending=False)
)

deputes_decomptes
# Out:
#            scrutin              nom libelleAbrev
# acteurRef
# PA719608       141           Ménard           NI
# PA720630        41            Minot           LR
# PA721816        32          Boucard           LR
# PA793476        30           Dubois           LR
# PA267429        26          Cinieri           LR
# ...            ...              ...          ...
# PA720256         1          Bannier          DEM
# PA720354         1          Jacques           RE
# PA720422         1       Quatennens           NI
# PA793190         1  Heydel Grillere           RE
# PA609520         1          Pompili           RE
#
# [268 rows x 3 columns]

# %%
deputes_decomptes.to_csv('out/rn_deputes_pour_count.csv')

# %%
from bs4 import BeautifulSoup

def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    cleaned_text = soup.get_text()
    return cleaned_text

# %%
import numpy as np

# %%
amendements = (
    amendements
    .join(organes.set_index('uid')['libelleAbrev'], on='organe')
    .join(reunions[['cr']], on='seance')
    .assign(
        url_seance = lambda df: df.cr.apply(lambda id: f'https://www.assemblee-nationale.fr/dyn/16/comptes-rendus/seance/{id}'),
        dispositif_plaintext = lambda df: df.dispositif.fillna('').apply(lambda x: strip_html_tags(x))
    )
)

amendements
# Out:
#                                       id numero               texte  \
# 0      AMANR5L16PO791932B0324P0D1N000002      2    PIONANR5L16B0324
# 1      AMANR5L16PO419610B0324P0D1N000014   CE14    PIONANR5L16B0324
# 2      AMANR5L16PO791932B0324P0D1N000009      9    PIONANR5L16B0324
# 3      AMANR5L16PO419610B0324P0D1N000018   CE18    PIONANR5L16B0324
# 4      AMANR5L16PO419610B0324P0D1N000007    CE7    PIONANR5L16B0324
# ...                                  ...    ...                 ...
# 86661  AMANR5L16PO791932B0950P0D1N000018     18  PRJLANR5L16BTC0950
# 86662  AMANR5L16PO791932B0950P0D1N000026     26  PRJLANR5L16BTC0950
# 86663  AMANR5L16PO791932B0950P0D1N000007      7  PRJLANR5L16BTC0950
# 86664  AMANR5L16PO791932B0950P0D1N000005      5  PRJLANR5L16BTC0950
# 86665  AMANR5L16PO791932B0950P0D1N000008      8  PRJLANR5L16BTC0950
#
#       signataire    organe                                         dispositif  \
# 0       PA795730  PO800538  <p style="text-align: justify;">Supprimer cet ...
# 1       PA795164  PO800490  <p style="text-align: justify;">Le III de l'ar...
# 2       PA794678  PO800520  <p style="text-align: justify;">Dans un d&#233...
# 3       PA795164  PO800490  <p style="text-align: justify;">Apr&#232;s l&#...
# 4       PA794146  PO800526  <p style="text-align: justify;">&#192; compter...
# ...          ...       ...                                                ...
# 86661   PA795438  PO800490                                                NaN
# 86662   PA795438  PO800490                                                NaN
# 86663   PA722142  PO800490                                                NaN
# 86664   PA720892  PO800490                                                NaN
# 86665   PA720892  PO800490                                                NaN
#
#       seance    sort discussion_commune discussion_identique libelleAbrev  \
# 0        NaN     NaN                NaN                  NaN           RE
# 1        NaN  Rejeté                NaN                  NaN    LFI-NUPES
# 2        NaN     NaN                NaN                  NaN           RN
# 3        NaN   Tombé                NaN                  NaN    LFI-NUPES
# 4        NaN  Rejeté                NaN                  NaN        ECOLO
# ...      ...     ...                ...                  ...          ...
# 86661    NaN     NaN                NaN                  NaN    LFI-NUPES
# 86662    NaN     NaN                NaN                  NaN    LFI-NUPES
# 86663    NaN     NaN                NaN                  NaN    LFI-NUPES
# 86664    NaN     NaN                NaN                  NaN    LFI-NUPES
# 86665    NaN     NaN                NaN                  NaN    LFI-NUPES
#
#         cr                                         url_seance  \
# 0      NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
# 1      NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
# 2      NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
# 3      NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
# 4      NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
# ...    ...                                                ...
# 86661  NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
# 86662  NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
# 86663  NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
# 86664  NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
# 86665  NaN  https://www.assemblee-nationale.fr/dyn/16/comp...
#
#                                     dispositif_plaintext
# 0                                Supprimer cet article.
# 1      Le III de l'article 17-1 de la loi n° 89-462 d...
# 2      Dans un délai de six mois à compter de la prom...
# 3      Après l’alinéa 5, insérer les quatre alinéas s...
# 4      À compter de la promulgation de la présente lo...
# ...                                                  ...
# 86661
# 86662
# 86663
# 86664
# 86665
#
# [86666 rows x 14 columns]

# %%
(
    amendements
    .query('not seance.isna()')
)
# Out:
#                                       id numero             texte signataire  \
# 28     AMANR5L16PO791932B1268P0D1N000016     16  PRJLANR5L16B1268   PA794410
# 29     AMANR5L16PO791932B1268P0D1N000010     10  PRJLANR5L16B1268   PA793708
# 33     AMANR5L16PO791932B1268P0D1N000013     13  PRJLANR5L16B1268   PA794478
# 39     AMANR5L16PO791932B1268P0D1N000014     14  PRJLANR5L16B1268   PA794478
# 43     AMANR5L16PO791932B1268P0D1N000007      7  PRJLANR5L16B1268     PA1567
# ...                                  ...    ...               ...        ...
# 86568  AMANR5L16PO791932B0760P0D1N003858   3858  PRJLANR5L16B0760   PA794938
# 86613  AMANR5L16PO791932B0760P0D1N006857   6857  PRJLANR5L16B0760   PA793444
# 86625  AMANR5L16PO791932B0760P0D1N005565   5565  PRJLANR5L16B0760   PA720892
# 86627  AMANR5L16PO791932B0760P0D1N006114   6114  PRJLANR5L16B0760   PA793736
# 86628  AMANR5L16PO791932B0760P0D1N012643  12643  PRJLANR5L16B0760   PA795438
#
#          organe                                         dispositif  \
# 28     PO800508  <p style="text-align: justify;">Supprimer cet ...
# 29     PO800526  <p style="text-align: justify;">Supprimer cet ...
# 33     PO800490  <p style="text-align: justify;">Supprimer cet ...
# 39     PO800490  <p style="text-align: justify;">Supprimer cet ...
# 43     PO800496  <p style="text-align: justify;">Supprimer cet ...
# ...         ...                                                ...
# 86568  PO800490  <p>I.&#160;&#8211;&#160;1&#176; Il est institu...
# 86613  PO800490  <p>I.&#160;&#8211;&#160;1&#176; Il est institu...
# 86625  PO800490  <p style="text-align: justify;">I. &#8211; Apr...
# 86627  PO800490  <p style="text-align: justify;">Le troisi&#232...
# 86628  PO800490  <p style="text-align: justify;">&#160;</p><p>I...
#
#                        seance         sort  \
# 28     RUANR5L16S2023IDS27159  Non soutenu
# 29     RUANR5L16S2023IDS27159       Rejeté
# 33     RUANR5L16S2023IDS27159       Rejeté
# 39     RUANR5L16S2023IDS27159       Rejeté
# 43     RUANR5L16S2023IDS27159       Rejeté
# ...                       ...          ...
# 86568  RUANR5L16S2023IDS26802       Rejeté
# 86613  RUANR5L16S2023IDS26802       Rejeté
# 86625  RUANR5L16S2023IDS26796       Rejeté
# 86627  RUANR5L16S2023IDS26797       Rejeté
# 86628  RUANR5L16S2023IDS26803       Rejeté
#
#                                       discussion_commune  \
# 28                                                   NaN
# 29                                                   NaN
# 33                                                   NaN
# 39                                                   NaN
# 43                                                   NaN
# ...                                                  ...
# 86568  {'idDiscussion': '20591', 'typePosition': 'Mil...
# 86613  {'idDiscussion': '20591', 'typePosition': 'Mil...
# 86625                                                NaN
# 86627  {'idDiscussion': '20539', 'typePosition': 'Mil...
# 86628  {'idDiscussion': '20597', 'typePosition': 'Mil...
#
#                                     discussion_identique libelleAbrev  \
# 28     {'idDiscussion': '63470', 'typePosition': 'Der...           LR
# 29     {'idDiscussion': '63476', 'typePosition': 'Mil...        ECOLO
# 33     {'idDiscussion': '63471', 'typePosition': 'Der...    LFI-NUPES
# 39     {'idDiscussion': '63476', 'typePosition': 'Der...    LFI-NUPES
# 43     {'idDiscussion': '63476', 'typePosition': 'Pre...          SOC
# ...                                                  ...          ...
# 86568  {'idDiscussion': '61897', 'typePosition': 'Mil...    LFI-NUPES
# 86613  {'idDiscussion': '61888', 'typePosition': 'Mil...    LFI-NUPES
# 86625  {'idDiscussion': '59530', 'typePosition': 'Mil...    LFI-NUPES
# 86627  {'idDiscussion': '60604', 'typePosition': 'Mil...    LFI-NUPES
# 86628  {'idDiscussion': '62023', 'typePosition': 'Der...    LFI-NUPES
#
#                           cr  \
# 28     CRSANR5L16S2023O1N258
# 29     CRSANR5L16S2023O1N258
# 33     CRSANR5L16S2023O1N258
# 39     CRSANR5L16S2023O1N258
# 43     CRSANR5L16S2023O1N258
# ...                      ...
# 86568  CRSANR5L16S2023O1N153
# 86613  CRSANR5L16S2023O1N153
# 86625  CRSANR5L16S2023O1N150
# 86627  CRSANR5L16S2023O1N151
# 86628  CRSANR5L16S2023O1N154
#
#                                               url_seance  \
# 28     https://www.assemblee-nationale.fr/dyn/16/comp...
# 29     https://www.assemblee-nationale.fr/dyn/16/comp...
# 33     https://www.assemblee-nationale.fr/dyn/16/comp...
# 39     https://www.assemblee-nationale.fr/dyn/16/comp...
# 43     https://www.assemblee-nationale.fr/dyn/16/comp...
# ...                                                  ...
# 86568  https://www.assemblee-nationale.fr/dyn/16/comp...
# 86613  https://www.assemblee-nationale.fr/dyn/16/comp...
# 86625  https://www.assemblee-nationale.fr/dyn/16/comp...
# 86627  https://www.assemblee-nationale.fr/dyn/16/comp...
# 86628  https://www.assemblee-nationale.fr/dyn/16/comp...
#
#                                     dispositif_plaintext
# 28                                Supprimer cet article.
# 29                                Supprimer cet article.
# 33                                Supprimer cet article.
# 39                                Supprimer cet article.
# 43                                Supprimer cet article.
# ...                                                  ...
# 86568  I. – 1° Il est institué une contribution sur l...
# 86613  I. – 1° Il est institué une contribution sur l...
# 86625  I. – Après la section 13 du chapitre VII du ti...
# 86627  Le troisième alinéa de l’article L. 241‑3 du c...
# 86628   I. – A. – Il est institué une contribution ad...
#
# [16339 rows x 14 columns]

# %%
organes_pca = pd.read_csv('out/organes_pca.csv')

#organes_pca

# %%
amendements_sort_table = (
    amendements
    #.query('~seance.isna()')
    # .query('discussion_identique.isna()')
    # .query('discussion_commune.isna()')
    #.query('sort.isin(["Adopté", "Rejeté"])')
    #.query('sort != "Tombé"')
    .pivot_table(
        index='libelleAbrev',
        columns='sort',
        values='id',
        aggfunc='count'
    )
    .loc[organes_pca.libelleAbrev]
)

(
    amendements_sort_table
    .assign(
        Total = lambda df: df.sum(axis=1)
    )
)
# Out:
# sort          Adopté  Non soutenu  Rejeté  Retiré  Tombé  Total
# libelleAbrev
# ECOLO            229          149    1925     125    283   2711
# LFI-NUPES        230           61    4835     336    457   5919
# SOC              408          120    1996     225    344   3093
# GDR-NUPES        133          210     841      59    177   1420
# DEM              554          202     263     213    186   1418
# RE              2658          518     414     423    393   4406
# HOR              389           72     141     149    102    853
# LIOT             245          338     740     196    176   1695
# NI                 9          109     263      23    108    512
# LR               515         1974    2525     433    944   6391
# RN               122          120    2475     272    649   3638

# %%
(
    amendements_sort_table
    .assign(
        Total = lambda df: df.sum(axis=1)
    )
    .sum()
)
# Out:
# sort
# Adopté          5492
# Non soutenu     3873
# Rejeté         16418
# Retiré          2454
# Tombé           3819
# Total          32056
# dtype: int64

# %%
(
    amendements_sort_table
    [["Adopté", "Rejeté"]]
    .plot
    .barh(
        stacked=True
    )
)
# Out:
# <Axes: ylabel='libelleAbrev'>

# %%
(
    amendements_sort_table
    [["Adopté", "Rejeté"]]
    .pipe(lambda df: df.div(df.sum(axis=1), axis=0))
    # .plot
    # .barh(
    #     stacked=True
    # )
)
# Out:
# sort            Adopté    Rejeté
# libelleAbrev
# ECOLO         0.106314  0.893686
# LFI-NUPES     0.045410  0.954590
# SOC           0.169717  0.830283
# GDR-NUPES     0.136550  0.863450
# DEM           0.678091  0.321909
# RE            0.865234  0.134766
# HOR           0.733962  0.266038
# LIOT          0.248731  0.751269
# NI            0.033088  0.966912
# LR            0.169408  0.830592
# RN            0.046977  0.953023

# %%
(
    amendements_sort_table
    [["Adopté", "Rejeté"]]
    .pipe(lambda df: df.div(df.sum(axis=1), axis=0))
    .plot
    .barh(
        stacked=True
    )
)
# Out:
# <Axes: ylabel='libelleAbrev'>

# %%
def find_scrutin(amendement):
    result = (
        scrutins
        .query('cr == @amendement.cr')
        .query('objet.str.contains(@amendement.numero, regex=False)')
    )
    
    if (len(result) > 0):
        return result.uid.to_list()[0]
    else:
        return np.nan

amendements_rn_seances = (
    amendements
    .query('libelleAbrev == "RN"')
    .query('not seance.isna()')
    .query('discussion_commune.isna()')
    .query('discussion_identique.isna()')
    .set_index('id')
    .assign(
# AMANR5L16PO791932B0760P0D1N014248    Compléter l’alinéa 6 par la phrase suivante :«...
# AMANR5L16PO791932B0760P0D1N019146    Le Gouvernement remet au Parlement, d’ici au 1...
#
#                                     scrutin_pred
# id
# AMANR5L16PO791932BTC0912P0D1N000040          NaN
# AMANR5L16PO791932BTC0912P0D1N000041          NaN
# AMANR5L16PO791932B1011P0D1N000094            NaN
# AMANR5L16PO791932BTC0909P0D1N000065          NaN
# AMANR5L16PO791932BTC0909P0D1N000066          NaN
# ...                                          ...
# AMANR5L16PO791932B0760P0D1N014222            NaN
# AMANR5L16PO791932B0760P0D1N014243            NaN
# AMANR5L16PO791932B0760P0D1N020085            NaN
# AMANR5L16PO791932B0760P0D1N014248            NaN
# AMANR5L16PO791932B0760P0D1N019146            NaN
#
# [1056 rows x 14 columns]

# %%
amendements_rn_seances.to_csv('out/rn_amendements.csv', index=False)

# %%
interventions = (
    interventions
    .join(reunions[['cr']], on='seance')
    .assign(
        url_seance = lambda df: df.cr.apply(lambda id: f'https://www.assemblee-nationale.fr/dyn/16/comptes-rendus/seance/{id}'),
    )
    .assign(
        url_intervention = lambda df: df.url_seance+'#'+df.id_syceron.astype(str),
    )
)

interventions
# Out:
#         id_syceron    acteur        code_grammaire code_style    stime  \
# 0          2845790  PA721908          OUV_SEAN_2_1     NORMAL   919.71
# 1          2845795  PA721908  ODJ_APPEL_DISCUSSION     NORMAL   922.29
# 2          2845797  PA721908      PAROLE_GENERIQUE     NORMAL   931.96
# 3          2845798  PA719472      PAROLE_GENERIQUE     NORMAL   957.22
# 4          2845799  PA642847     INTERRUPTION_1_10     NORMAL   981.52
# ...            ...       ...                   ...        ...      ...
# 156971     2944887  PA793382     INTERRUPTION_1_10     NORMAL  9539.76
# 156972     2944889  PA720908     SCRUT_PUB_ADT_1_2     NORMAL  9549.08
# 156973     2944891  PA720908     SCRUT_PUB_ADT_1_4     NORMAL  9554.61
# 156974     2944893  PA720908          FIN_SEAN_1_0     NORMAL  9555.48
# 156975     2944896  PA720908          FIN_SEAN_2_1     NORMAL  9590.09
#
#                                                     texte  \
# 0                                 La séance est ouverte.
# 1       L’ordre du jour appelle la discussion, sur le ...
# 2       La parole est à M. Jean-Renvé Cazeneuve, rap...
# 3       Je suis ravi de vous présenter les conclusion...
# 4                                            Un Lorrain !
# ...                                                   ...
# 156971     Et c’est d’acheter du charbon à l’Allemagne ?
# 156972             Je mets aux voix l’amendement n  3039.
# 156973  Voici le résultat du scrutin :         Nombre...
# 156974  La suite de la discussion est renvoyée à la ...
# 156975  Prochaine séance, demain, à neuf heures :  Q...
#
#                         seance  mots                     cr  \
# 0       RUANR5L16S2022IDS26244     4  CRSANR5L16S2022E1N032
# 1       RUANR5L16S2022IDS26244    27  CRSANR5L16S2022E1N032
# 2       RUANR5L16S2022IDS26244    13  CRSANR5L16S2022E1N032
# 3       RUANR5L16S2022IDS26244    87  CRSANR5L16S2022E1N032
# 4       RUANR5L16S2022IDS26244     3  CRSANR5L16S2022E1N032
# ...                        ...   ...                    ...
# 156971  RUANR5L16S2023IDS26598     8  CRSANR5L16S2023O1N083
# 156972  RUANR5L16S2023IDS26598     8  CRSANR5L16S2023O1N083
# 156973  RUANR5L16S2023IDS26598   170  CRSANR5L16S2023O1N083
# 156974  RUANR5L16S2023IDS26598    11  CRSANR5L16S2023O1N083
# 156975  RUANR5L16S2023IDS26598    16  CRSANR5L16S2023O1N083
#
#                                                url_seance  \
# 0       https://www.assemblee-nationale.fr/dyn/16/comp...
# 1       https://www.assemblee-nationale.fr/dyn/16/comp...
# 2       https://www.assemblee-nationale.fr/dyn/16/comp...
# 3       https://www.assemblee-nationale.fr/dyn/16/comp...
# 4       https://www.assemblee-nationale.fr/dyn/16/comp...
# ...                                                   ...
# 156971  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156972  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156973  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156974  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156975  https://www.assemblee-nationale.fr/dyn/16/comp...
#
#                                          url_intervention
# 0       https://www.assemblee-nationale.fr/dyn/16/comp...
# 1       https://www.assemblee-nationale.fr/dyn/16/comp...
# 2       https://www.assemblee-nationale.fr/dyn/16/comp...
# 3       https://www.assemblee-nationale.fr/dyn/16/comp...
# 4       https://www.assemblee-nationale.fr/dyn/16/comp...
# ...                                                   ...
# 156971  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156972  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156973  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156974  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156975  https://www.assemblee-nationale.fr/dyn/16/comp...
#
# [156976 rows x 11 columns]

# %%
interventions_rn = (
    interventions
    .query('acteur.isin(@deputes.index)')
    .join(deputes[['nom', 'civ']], on='acteur')
)

interventions_rn
# Out:
#         id_syceron    acteur     code_grammaire code_style    stime  \
# 250        2846125  PA794954   PAROLE_GENERIQUE     NORMAL  4479.19
# 252        2846190  PA794954   PAROLE_GENERIQUE     NORMAL  4494.44
# 254        2846129  PA794954   PAROLE_GENERIQUE     NORMAL  4516.35
# 258        2846131  PA794954   PAROLE_GENERIQUE     NORMAL  4530.05
# 288        2846198  PA794562   PAROLE_GENERIQUE     NORMAL  5393.41
# ...            ...       ...                ...        ...      ...
# 156962     2944883  PA793382   PAROLE_GENERIQUE     NORMAL  9384.75
# 156964     2945096  PA795778   PAROLE_GENERIQUE     NORMAL  9410.20
# 156966     2945099  PA795778   PAROLE_GENERIQUE     NORMAL  9466.82
# 156969     2944941  PA793382  INTERRUPTION_1_10     NORMAL  9500.31
# 156971     2944887  PA793382  INTERRUPTION_1_10     NORMAL  9539.76
#
#                                                     texte  \
# 250     Comme hier, l’extrême gauche, la NUPES  oubli...
# 252     Certes, celles-ci sont maigres, mais la motion...
# 254     Monsieur le ministre Attal, je vous mets au de...
# 258     Nous avons fait beaucoup de propositions, que ...
# 288     Sur le fondement de l’article 70-3. Je souhait...
# ...                                                   ...
# 156962  Cela vaut aussi pour d’autres collègues. Le s...
# 156964  Vous ne m’avez pas répondu, madame Pannier-Ru...
# 156966  ...tandis qu’un mix avec moins d’énergies ren...
# 156969         Honteux ! Vous êtes malhonnête, madame !
# 156971     Et c’est d’acheter du charbon à l’Allemagne ?
#
#                         seance  mots                     cr  \
# 250     RUANR5L16S2022IDS26244    31  CRSANR5L16S2022E1N032
# 252     RUANR5L16S2022IDS26244    53  CRSANR5L16S2022E1N032
# 254     RUANR5L16S2022IDS26244    38  CRSANR5L16S2022E1N032
# 258     RUANR5L16S2022IDS26244    30  CRSANR5L16S2022E1N032
# 288     RUANR5L16S2022IDS26244    39  CRSANR5L16S2022E1N032
# ...                        ...   ...                    ...
# 156962  RUANR5L16S2023IDS26598    38  CRSANR5L16S2023O1N083
# 156964  RUANR5L16S2023IDS26598   157  CRSANR5L16S2023O1N083
# 156966  RUANR5L16S2023IDS26598    54  CRSANR5L16S2023O1N083
# 156969  RUANR5L16S2023IDS26598     7  CRSANR5L16S2023O1N083
# 156971  RUANR5L16S2023IDS26598     8  CRSANR5L16S2023O1N083
#
#                                                url_seance  \
# 250     https://www.assemblee-nationale.fr/dyn/16/comp...
# 252     https://www.assemblee-nationale.fr/dyn/16/comp...
# 254     https://www.assemblee-nationale.fr/dyn/16/comp...
# 258     https://www.assemblee-nationale.fr/dyn/16/comp...
# 288     https://www.assemblee-nationale.fr/dyn/16/comp...
# ...                                                   ...
# 156962  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156964  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156966  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156969  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156971  https://www.assemblee-nationale.fr/dyn/16/comp...
#
#                                          url_intervention  \
# 250     https://www.assemblee-nationale.fr/dyn/16/comp...
# 252     https://www.assemblee-nationale.fr/dyn/16/comp...
# 254     https://www.assemblee-nationale.fr/dyn/16/comp...
# 258     https://www.assemblee-nationale.fr/dyn/16/comp...
# 288     https://www.assemblee-nationale.fr/dyn/16/comp...
# ...                                                   ...
# 156962  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156964  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156966  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156969  https://www.assemblee-nationale.fr/dyn/16/comp...
# 156971  https://www.assemblee-nationale.fr/dyn/16/comp...
#
#                         nom civ
# 250                  Salmon  M.
# 252                  Salmon  M.
# 254                  Salmon  M.
# 258                  Salmon  M.
# 288                 Ballard  M.
# ...                     ...  ..
# 156962  Taché de la Pagerie  M.
# 156964               Tanguy  M.
# 156966               Tanguy  M.
# 156969  Taché de la Pagerie  M.
# 156971  Taché de la Pagerie  M.
#
# [19491 rows x 13 columns]

# %%
interventions_rn.to_csv('out/rn_interventions.csv', index=False)

# %%
interventions_rn_stats = (
    interventions_rn
    .assign(
        parole = lambda df: df.code_grammaire.str.contains('PAROLE'),
        interruption = lambda df: df.code_grammaire.str.contains('INTERRUPTION')
    )
    .groupby('nom')
    .agg({
        'civ' : 'first', 
        'mots': ['sum', 'mean'],
        'texte': ['count'],
        'seance': lambda s: len(s.unique()),
        'parole': 'sum',
        'interruption': 'sum'
    })
    .sort_values(('mots', 'sum'), ascending=False)
)

interventions_rn_stats
# Out:
#                         civ    mots             texte   seance parole  \
#                       first     sum        mean count <lambda>    sum
# nom
# Chenu                    M.  102950   20.499801  5022      106   2957
# Laporte                 Mme   76744   19.355359  3965       42   2594
# Tanguy                   M.   62503   71.350457   876      108    528
# Jacobelli                M.   32243   30.736892  1049      128    284
# Le Pen                  Mme   31050   62.100000   500       81    298
# ...                     ...     ...         ...   ...      ...    ...
# Beaurain                 M.    1038   31.454545    33       18      6
# Frigout                 Mme    1018  127.250000     8        4      8
# Bovet                    M.    1006   91.454545    11        6      9
# Girard                   M.     817  163.400000     5        4      4
# Da Conceicao Carvalho   Mme     593  148.250000     4        2      4
#
#                       interruption
#                                sum
# nom
# Chenu                          555
# Laporte                        224
# Tanguy                         348
# Jacobelli                      765
# Le Pen                         202
# ...                            ...
# Beaurain                        27
# Frigout                          0
# Bovet                            2
# Girard                           1
# Da Conceicao Carvalho            0
#
# [88 rows x 7 columns]

# %%
interventions_rn_stats.to_csv('out/rn_interventions_stats.csv')

# %%
deputes.civ.value_counts().div(len(deputes))
# Out:
# M.     0.622222
# Mme    0.377778
# Name: civ, dtype: float64

# %%
interventions_rn_stats_civ = (
    interventions_rn
    .assign(
        parole = lambda df: df.code_grammaire.str.contains('PAROLE'),
        interruption = lambda df: df.code_grammaire.str.contains('INTERRUPTION')
    )
    .groupby('civ')
    .agg({
        'mots': ['sum', 'mean'],
        'texte': ['count'],
        'seance': lambda s: len(s.unique()),
        'parole': 'sum',
        'interruption': 'sum'
    })
)

interventions_rn_stats_civ
# Out:
#        mots            texte   seance parole interruption
#         sum      mean  count <lambda>    sum          sum
# civ
# M.   598194  44.97023  13302      302   6834         4956
# Mme  261244  42.21102   6189      257   3986         1056

# %%
interventions_rn_stats_civ_pct = (
    interventions_rn_stats_civ
    .div(
        interventions_rn_stats_civ.sum()
    )
)

interventions_rn_stats_civ_pct
# Out:
#          mots               texte   seance    parole interruption
#           sum      mean     count <lambda>       sum          sum
# civ
# M.   0.696029  0.515825  0.682469  0.54025  0.631608     0.824351
# Mme  0.303971  0.484175  0.317531  0.45975  0.368392     0.175649

# %%
(
    interventions
    .join(acteurs.set_index('uid'), on='acteur')
    .assign(
        parole = lambda df: df.code_grammaire.str.contains('PAROLE'),
        interruption = lambda df: df.code_grammaire.str.contains('INTERRUPTION')
    )
    .groupby('civ')
    .agg({
        'mots': ['sum', 'mean'],
        'texte': ['count'],
        'seance': lambda s: len(s.unique()),
        'parole': 'sum',
        'interruption': 'sum'
    })
    .pipe(
        lambda df: (
            df
            .div(df.sum())
        )
    )
)
# Out:
#          mots               texte   seance    parole interruption
#           sum      mean     count <lambda>       sum          sum
# civ
# M.   0.612773  0.585858  0.527997      0.5  0.508468     0.723191
# Mme  0.387227  0.414142  0.472003      0.5  0.491532     0.276809
