# %%
import pandas as pd

# %%
votes = pd.read_csv('out/votes.csv')
organes = (pd.read_csv('out/organes.csv'))

# %%
total = (
    votes
    .groupby('acteurRef')
    .agg({
        'scrutin': 'count'
    })
    .sort_values('scrutin', ascending = False)
)

total
# Out:
#            scrutin
# acteurRef
# PA795934      1190
# PA717379      1184
# PA719608      1125
# PA721710      1123
# PA721482      1102
# ...            ...
# PA720960        61
# PA2952          38
# PA695100        38
# PA822617        22
# PA721908         1
#
# [580 rows x 1 columns]

# %%
loyautes = (
    votes
    .assign(
        divergence_groupe = lambda df: df.position != df.groupe_majorite
    )
    .groupby('acteurRef')
    .agg({
        'divergence_groupe': 'sum'
    })
    .join(total)
    .assign(
        loyaute = lambda df: df.divergence_groupe / df.scrutin
    )
    .sort_values('loyaute')
)

loyautes
# Out:
#            divergence_groupe  scrutin   loyaute
# acteurRef
# PA721024                   0      711  0.000000
# PA588884                   0      235  0.000000
# PA794886                   0      493  0.000000
# PA606639                   0      178  0.000000
# PA795950                   0      802  0.000000
# ...                      ...      ...       ...
# PA718850                  74      360  0.205556
# PA605069                  97      398  0.243719
# PA942                    106      386  0.274611
# PA719138                  81      271  0.298893
# PA266788                  21       66  0.318182
#
# [580 rows x 3 columns]

# %%
loyautes.to_csv('out/loyautes.csv')

# %%
(
    loyautes
    .join(
        votes.set_index('acteurRef')[['organe']]
    )
    .reset_index()
    [['loyaute', 'organe']]
    .plot
    .box(
        by="organe",
        #ylim=[0,1]
    )
)
# Out:
# loyaute    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
organes = (pd.read_csv('out/organes.csv'))

# %%
nupes = (
    organes
    .query('libelle.str.contains("NUPES") or libelle.str.contains("France insoumise")')
)

nupes
# Out:
#                                                 @xmlns
# 133  http://schemas.assemblee-nationale.fr/referentiel  \
# 262  http://schemas.assemblee-nationale.fr/referentiel
# 291  http://schemas.assemblee-nationale.fr/referentiel
# 598  http://schemas.assemblee-nationale.fr/referentiel
#
#                                     @xmlns:xsi             @xsi:type
# 133  http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type  \
# 262  http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type
# 291  http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type
# 598  http://www.w3.org/2001/XMLSchema-instance  GroupePolitique_type
#
#           uid codeType                                            libelle
# 133  PO800490       GP  La France insoumise - Nouvelle Union Populaire...  \
# 262  PO800496       GP  Socialistes et apparentés (membre de l’intergr...
# 291  PO800526       GP                                 Écologiste - NUPES
# 598  PO800502       GP           Gauche démocrate et républicaine - NUPES
#
#                                         libelleEdition  libelleAbrege
# 133  du groupe La France insoumise - Nouvelle Union...    LFI - NUPES  \
# 262  du groupe Socialistes et apparentés (membre de...            SOC
# 291                       du groupe Écologiste - NUPES  Ecolo - NUPES
# 598  du groupe de la Gauche démocrate et républicai...    GDR - NUPES
#
#     libelleAbrev                                             viMoDe  ...
# 133    LFI-NUPES  {'dateDebut': '2022-06-28', 'dateAgrement': No...  ...  \
# 262          SOC  {'dateDebut': '2022-06-28', 'dateAgrement': No...  ...
# 291        ECOLO  {'dateDebut': '2022-06-28', 'dateAgrement': No...  ...
# 598    GDR-NUPES  {'dateDebut': '2022-06-28', 'dateAgrement': No...  ...
#
#               regime  legislature
# 133  5ème République         16.0  \
# 262  5ème République         16.0
# 291  5ème République         16.0
# 598  5ème République         16.0
#
#                                       secretariat  listePays regimeJuridique
# 133  {'secretaire01': None, 'secretaire02': None}        NaN             NaN  \
# 262  {'secretaire01': None, 'secretaire02': None}        NaN             NaN
# 291  {'secretaire01': None, 'secretaire02': None}        NaN             NaN
# 598  {'secretaire01': None, 'secretaire02': None}        NaN             NaN
#
#     siteInternet nombreReunionsAnnuelles positionPolitique  preseance
# 133          NaN                     NaN        Opposition        3.0  \
# 262          NaN                     NaN        Opposition        6.0
# 291          NaN                     NaN        Opposition        8.0
# 598          NaN                     NaN        Opposition        9.0
#
#     couleurAssociee
# 133         #E42313
# 262         #DF84B5
# 291         #77AA79
# 598         #991414
#
# [4 rows x 22 columns]

# %%
(
    loyautes
    .join(
        votes.set_index('acteurRef')[['organe']]
    )
    .reset_index()
    [['loyaute', 'organe']]
    .query('organe.isin(@nupes.uid)')
    .assign(
        organe = lambda df: df.join(nupes.set_index('uid'), on='organe')[['libelle']]
    )
    .plot
    .box(
        by="organe",
        vert=False
    )
)
# Out:
# loyaute    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
(
    loyautes
    .join(
        votes.set_index('acteurRef')[['organe']]
    )
    .reset_index()
    [['loyaute', 'organe']]
    .query('organe.isin(@nupes.uid)')
    .assign(
        organe = lambda df: df.join(nupes.set_index('uid'), on='organe')[['libelle']]
    )
    .groupby('organe')
    .mean()
    .rsub(1)
)
# Out:
#                                                      loyaute
# organe
# Gauche démocrate et républicaine - NUPES            0.971067
# La France insoumise - Nouvelle Union Populaire ...  0.993172
# Socialistes et apparentés (membre de l’intergro...  0.972289
# Écologiste - NUPES                                  0.973204

# %%
(
    loyautes
    .join(
        votes.set_index('acteurRef')[['organe']]
    )
    .reset_index()
    [['loyaute', 'organe']]
    #.query('organe.isin(@nupes.uid)')
    .assign(
        organe = lambda df: df.join(organes.set_index('uid'), on='organe')[['libelle']]
    )
    .groupby('organe')
    .mean()
    .rsub(1)
)
# Out:
#                                                      loyaute
# organe
# Démocrate (MoDem et Indépendants)                   0.974305
# Gauche démocrate et républicaine - NUPES            0.971067
# Horizons et apparentés                              0.979560
# La France insoumise - Nouvelle Union Populaire ...  0.993172
# Les Républicains                                    0.899639
# Libertés, Indépendants, Outre-mer et Territoires    0.820079
# Non inscrit                                         0.911016
# Rassemblement National                              0.986666
# Renaissance                                         0.990600
# Socialistes et apparentés (membre de l’intergro...  0.972289
# Écologiste - NUPES                                  0.973204

# %%
alignements = (
    votes
    .query('organe.isin(@nupes.uid)')
    .groupby(['scrutin', 'organe'])
    .agg({
        'groupe_majorite': 'first'
    })
    .reset_index()
    .assign(
        organe = lambda df: df.join(nupes.set_index('uid'), on='organe')[['libelle']]
    )
    .pivot_table(
        index="scrutin",
        columns="organe",
        values="groupe_majorite",
        aggfunc= lambda x: x
    )
    .assign(
        alignement= lambda df: df.eq(df.iloc[:, 0], axis=0).all(1)
    )
    #.join(votes.set_index('scrutin')[['date']].drop_duplicates())
    #.query('~alignement')
)

alignements
# Out:
# organe         Gauche démocrate et républicaine - NUPES
# scrutin
# VTANR5L16V1                                        pour  \
# VTANR5L16V10                                     contre
# VTANR5L16V100                                      pour
# VTANR5L16V1000                                     pour
# VTANR5L16V1001                                     pour
# ...                                                 ...
# VTANR5L16V995                                      pour
# VTANR5L16V996                                      pour
# VTANR5L16V997                                      pour
# VTANR5L16V998                                      pour
# VTANR5L16V999                                      pour
#
# organe         La France insoumise - Nouvelle Union Populaire écologique et sociale
# scrutin
# VTANR5L16V1                                                  pour                    \
# VTANR5L16V10                                           abstention
# VTANR5L16V100                                                pour
# VTANR5L16V1000                                               pour
# VTANR5L16V1001                                               pour
# ...                                                           ...
# VTANR5L16V995                                                pour
# VTANR5L16V996                                                pour
# VTANR5L16V997                                                pour
# VTANR5L16V998                                                pour
# VTANR5L16V999                                                pour
#
# organe         Socialistes et apparentés (membre de l’intergroupe NUPES)
# scrutin
# VTANR5L16V1                                                  pour         \
# VTANR5L16V10                                               contre
# VTANR5L16V100                                                pour
# VTANR5L16V1000                                               pour
# VTANR5L16V1001                                               pour
# ...                                                           ...
# VTANR5L16V995                                                pour
# VTANR5L16V996                                                pour
# VTANR5L16V997                                                pour
# VTANR5L16V998                                                pour
# VTANR5L16V999                                                pour
#
# organe         Écologiste - NUPES  alignement
# scrutin
# VTANR5L16V1                  pour        True
# VTANR5L16V10               contre       False
# VTANR5L16V100                pour        True
# VTANR5L16V1000               pour        True
# VTANR5L16V1001               pour        True
# ...                           ...         ...
# VTANR5L16V995                pour        True
# VTANR5L16V996                pour        True
# VTANR5L16V997                pour        True
# VTANR5L16V998                pour        True
# VTANR5L16V999                pour        True
#
# [1491 rows x 5 columns]

# %%
alignements.to_csv('out/alignements-nupes.csv')

# %%
(
    alignements
    .query('~alignement')
    #.to_csv('out/alignement-false.csv')
)
# Out:
# organe         Gauche démocrate et républicaine - NUPES
# scrutin
# VTANR5L16V10                                     contre  \
# VTANR5L16V1007                                      NaN
# VTANR5L16V1013                                     pour
# VTANR5L16V1018                                     pour
# VTANR5L16V1020                                      NaN
# ...                                                 ...
# VTANR5L16V970                                abstention
# VTANR5L16V977                                      pour
# VTANR5L16V980                                abstention
# VTANR5L16V985                                    contre
# VTANR5L16V988                                abstention
#
# organe         La France insoumise - Nouvelle Union Populaire écologique et sociale
# scrutin
# VTANR5L16V10                                           abstention                    \
# VTANR5L16V1007                                             contre
# VTANR5L16V1013                                         abstention
# VTANR5L16V1018                                               pour
# VTANR5L16V1020                                         abstention
# ...                                                           ...
# VTANR5L16V970                                          abstention
# VTANR5L16V977                                                pour
# VTANR5L16V980                                          abstention
# VTANR5L16V985                                          abstention
# VTANR5L16V988                                              contre
#
# organe         Socialistes et apparentés (membre de l’intergroupe NUPES)
# scrutin
# VTANR5L16V10                                               contre         \
# VTANR5L16V1007                                                NaN
# VTANR5L16V1013                                               pour
# VTANR5L16V1018                                               pour
# VTANR5L16V1020                                                NaN
# ...                                                           ...
# VTANR5L16V970                                              contre
# VTANR5L16V977                                          abstention
# VTANR5L16V980                                                 NaN
# VTANR5L16V985                                              contre
# VTANR5L16V988                                                pour
#
# organe         Écologiste - NUPES  alignement
# scrutin
# VTANR5L16V10               contre       False
# VTANR5L16V1007         abstention       False
# VTANR5L16V1013               pour       False
# VTANR5L16V1018         abstention       False
# VTANR5L16V1020         abstention       False
# ...                           ...         ...
# VTANR5L16V970          abstention       False
# VTANR5L16V977                pour       False
# VTANR5L16V980                 NaN       False
# VTANR5L16V985              contre       False
# VTANR5L16V988              contre       False
#
# [642 rows x 5 columns]

# %%
scrutins = pd.read_csv('out/scrutins.csv')

# %%
alignements_complet = (
    alignements
    .join(scrutins.set_index('uid'))
    .assign(
        motion_censure = lambda df: df.objet.str.contains('motion de censure')
    )
    #.query("motion_censure")
    .sort_values('date')
)

alignements_complet
# Out:
#                Gauche démocrate et républicaine - NUPES
# scrutin
# VTANR5L16V1                                        pour  \
# VTANR5L16V2                                        pour
# VTANR5L16V5                                        pour
# VTANR5L16V4                                      contre
# VTANR5L16V13                                     contre
# ...                                                 ...
# VTANR5L16V1489                                      NaN
# VTANR5L16V1495                                   contre
# VTANR5L16V1502                                      NaN
# VTANR5L16V1503                                     pour
# VTANR5L16V1504                               abstention
#
#                La France insoumise - Nouvelle Union Populaire écologique et sociale
# scrutin
# VTANR5L16V1                                                  pour                    \
# VTANR5L16V2                                                  pour
# VTANR5L16V5                                                  pour
# VTANR5L16V4                                                contre
# VTANR5L16V13                                               contre
# ...                                                           ...
# VTANR5L16V1489                                               pour
# VTANR5L16V1495                                             contre
# VTANR5L16V1502                                             contre
# VTANR5L16V1503                                             contre
# VTANR5L16V1504                                             contre
#
#                Socialistes et apparentés (membre de l’intergroupe NUPES)
# scrutin
# VTANR5L16V1                                                  pour         \
# VTANR5L16V2                                                  pour
# VTANR5L16V5                                                contre
# VTANR5L16V4                                                  pour
# VTANR5L16V13                                           abstention
# ...                                                           ...
# VTANR5L16V1489                                             contre
# VTANR5L16V1495                                               pour
# VTANR5L16V1502                                                NaN
# VTANR5L16V1503                                                NaN
# VTANR5L16V1504                                             contre
#
#                Écologiste - NUPES  alignement
# scrutin
# VTANR5L16V1                  pour        True  \
# VTANR5L16V2                  pour        True
# VTANR5L16V5                  pour       False
# VTANR5L16V4                contre       False
# VTANR5L16V13               contre       False
# ...                           ...         ...
# VTANR5L16V1489               pour       False
# VTANR5L16V1495               pour       False
# VTANR5L16V1502               pour       False
# VTANR5L16V1503               pour       False
# VTANR5L16V1504             contre       False
#
#                                                             objet
# scrutin
# VTANR5L16V1     la motion de censure déposée en application de...  \
# VTANR5L16V2     la motion de rejet préalable, déposée par Mme ...
# VTANR5L16V5     l'amendement de suppression n° 15 de M. Di Fil...
# VTANR5L16V4     l'article premier du projet de loi maintenant ...
# VTANR5L16V13    l'article 2 du projet de loi maintenant provis...
# ...                                                           ...
# VTANR5L16V1489  l'amendement n° 3 de Mme Maximi à l'article un...
# VTANR5L16V1495  l'article unique de la proposition de loi visa...
# VTANR5L16V1502  l'amendement n° 20 (rect.) du Gouvernement et ...
# VTANR5L16V1503  l'ensemble de la proposition de loi visant à f...
# VTANR5L16V1504  la proposition de résolution visant à lutter c...
#
#                                     type        date  motion_censure
# scrutin
# VTANR5L16V1      scrutin public solennel  2022-07-11            True
# VTANR5L16V2     scrutin public ordinaire  2022-07-11           False
# VTANR5L16V5     scrutin public ordinaire  2022-07-12           False
# VTANR5L16V4     scrutin public ordinaire  2022-07-12           False
# VTANR5L16V13    scrutin public ordinaire  2022-07-12           False
# ...                                  ...         ...             ...
# VTANR5L16V1489  scrutin public ordinaire  2023-05-10           False
# VTANR5L16V1495  scrutin public ordinaire  2023-05-10           False
# VTANR5L16V1502  scrutin public ordinaire  2023-05-11           False
# VTANR5L16V1503  scrutin public ordinaire  2023-05-11           False
# VTANR5L16V1504  scrutin public ordinaire  2023-05-11           False
#
# [1491 rows x 9 columns]

# %%
alignements_complet.to_csv('out/alignements.csv')
