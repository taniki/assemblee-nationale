# %%
# !rm -rf downloads

# %%
# !mkdir downloads

# %%
# !rm -rf data

# %%
# !mkdir data

# %%
# !wget -P downloads http://data.assemblee-nationale.fr/static/openData/repository/15/amo/deputes_senateurs_ministres_legislature/AMO20_dep_sen_min_tous_mandats_et_organes_XV.json.zip
# Out:
# --2023-05-15 22:21:08--  http://data.assemblee-nationale.fr/static/openData/repository/15/amo/deputes_senateurs_ministres_legislature/AMO20_dep_sen_min_tous_mandats_et_organes_XV.json.zip
# Resolving data.assemblee-nationale.fr (data.assemblee-nationale.fr)... 46.105.202.26
# Connecting to data.assemblee-nationale.fr (data.assemblee-nationale.fr)|46.105.202.26|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://data.assemblee-nationale.fr/static/openData/repository/15/amo/deputes_senateurs_ministres_legislature/AMO20_dep_sen_min_tous_mandats_et_organes_XV.json.zip [following]
# --2023-05-15 22:21:09--  https://data.assemblee-nationale.fr/static/openData/repository/15/amo/deputes_senateurs_ministres_legislature/AMO20_dep_sen_min_tous_mandats_et_organes_XV.json.zip
# Connecting to data.assemblee-nationale.fr (data.assemblee-nationale.fr)|46.105.202.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !unzip downloads/AMO20_dep_sen_min_tous_mandats_et_organes_XV.json.zip -d data
# Out:
# Archive:  downloads/AMO20_dep_sen_min_tous_mandats_et_organes_XV.json.zip
#   inflating: data/json/acteur/PA774313.json
#   inflating: data/json/acteur/PA720916.json
#   inflating: data/json/acteur/PA267785.json
#   inflating: data/json/acteur/PA337633.json
#   inflating: data/json/acteur/PA720830.json
#   inflating: data/json/acteur/PA736165.json
#   inflating: data/json/acteur/PA607155.json
#   inflating: data/json/acteur/PA429864.json
#   inflating: data/json/acteur/PA721726.json
#   inflating: data/json/acteur/PA2074.json
#   inflating: data/json/acteur/PA775272.json
#   inflating: data/json/acteur/PA607193.json
#   inflating: data/json/acteur/PA267042.json
#   inflating: data/json/acteur/PA695100.json
#   inflating: data/json/acteur/PA785193.json
#   inflating: data/json/acteur/PA720030.json
#   inflating: data/json/acteur/PA429896.json
#   inflating: data/json/acteur/PA719866.json
#   inflating: data/json/acteur/PA608083.json
#   inflating: data/json/acteur/PA720772.json
# ...

# %%
# !wget -P downloads http://data.assemblee-nationale.fr/static/openData/repository/15/loi/scrutins/Scrutins_XV.json.zip
# Out:
# --2023-05-15 22:23:52--  http://data.assemblee-nationale.fr/static/openData/repository/15/loi/scrutins/Scrutins_XV.json.zip
# Resolving data.assemblee-nationale.fr (data.assemblee-nationale.fr)... 46.105.202.26
# Connecting to data.assemblee-nationale.fr (data.assemblee-nationale.fr)|46.105.202.26|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://data.assemblee-nationale.fr/static/openData/repository/15/loi/scrutins/Scrutins_XV.json.zip [following]
# --2023-05-15 22:23:52--  https://data.assemblee-nationale.fr/static/openData/repository/15/loi/scrutins/Scrutins_XV.json.zip
# Connecting to data.assemblee-nationale.fr (data.assemblee-nationale.fr)|46.105.202.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9202661 (8.8M) [application/zip]
# Saving to: ‘downloads/Scrutins_XV.json.zip’
#
# Scrutins_XV.json.zi 100%[===================>]   8.78M  1.31MB/s    in 7.5s
#
# ...

# %%
# !unzip downloads/Scrutins_XV.json.zip -d data
# Out:
# Archive:  downloads/Scrutins_XV.json.zip
#   inflating: data/json/VTANR5L15V2944.json
#   inflating: data/json/VTANR5L15V3415.json
#   inflating: data/json/VTANR5L15V1761.json
#   inflating: data/json/VTANR5L15V2292.json
#   inflating: data/json/VTANR5L15V158.json
#   inflating: data/json/VTANR5L15V1529.json
#   inflating: data/json/VTANR5L15V989.json
#   inflating: data/json/VTANR5L15V3252.json
#   inflating: data/json/VTANR5L15V2835.json
#   inflating: data/json/VTANR5L15V1757.json
#   inflating: data/json/VTANR5L15V1921.json
#   inflating: data/json/VTANR5L15V1033.json
#   inflating: data/json/VTANR5L15V1952.json
#   inflating: data/json/VTANR5L15V1635.json
#   inflating: data/json/VTANR5L15V1881.json
#   inflating: data/json/VTANR5L15V3216.json
#   inflating: data/json/VTANR5L15V4173.json
#   inflating: data/json/VTANR5L15V231.json
#   inflating: data/json/VTANR5L15V34.json
#   inflating: data/json/VTANR5L15V1152.json
#   inflating: data/json/VTANR5L15V1353.json
# ...
